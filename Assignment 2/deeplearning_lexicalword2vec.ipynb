# %%
import numpy as np 
import pandas as pd
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.corpus import stopwords
from nltk.classify import SklearnClassifier
import matplotlib.pyplot as plt
import string
import re
from collections import Counter
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\KIRHIKAGURUMURTHY\AppData\Roaming\nltk_data..
# [nltk_data]     .
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\KIRHIKAGURUMURTHY\AppData\Roaming\nltk_data..
# [nltk_data]     .
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df = pd.read_csv('FinalTweetList.csv')
df.columns=['tweet','sentiment','bank']
stopword = nltk.corpus.stopwords.words('english')
ps = nltk.PorterStemmer()
wn = nltk.WordNetLemmatizer()

# %%
#find all banks - first list out all words beginning with @
def find(text):
    list = re.findall("[@]\w+", text)
    return list
df['@'] = (df['tweet']).apply(lambda x: find(x))
df.head()
# Out:
#                                                tweet      sentiment bank  \
# 0  @AxisBankSupport 18..233.... is permanently bu...    displeasure  NaN
# 1  @TheOfficialSBI 3 hours in line,still waiting....    displeasure  NaN
# 2  @HDFCBank_Cares Both the ATM machines here in ...    displeasure  NaN
# 3  @ICICIBank Thanks icici bank I got case in you...  miscellaneous  NaN
# 4  @RBI In Assam all banks are exchanging 4000/- ...    displeasure  NaN
#
#                                @
# 0             [@AxisBankSupport]
# 1              [@TheOfficialSBI]
# 2     [@HDFCBank_Cares, @sanatm]
# 3  [@ICICIBank, @TheOfficialSBI]
# 4        [@RBI, @TheOfficialSBI]

# %%
#frequency of words beginning with @
#As we need testing data of 500 values we will only take the banks specified in more than 500 rows in the datset - upon analysing we see that 
#these are - SBI,Axis,HDFC,Kotak and ICICI
lis=df['@'].to_list()
flat = [y for x in lis for y in x]
count = Counter(flat)
count.most_common()
# Out:
# [('@TheOfficialSBI', 2468),
#  ('@HDFCBank_Cares', 928),
#  ('@ICICIBank_Care', 893),
#  ('@KotakBankLtd', 691),
#  ('@AxisBankSupport', 562),
#  ('@RBI', 481),
#  ('@ICICIBank', 448),
#  ('@HDFC_Bank', 364),
#  ('@arunjaitley', 315),
#  ('@narendramodi', 312),
#  ('@bankofbaroda', 268),
#  ('@AxisBank', 262),
#  ('@PMOIndia', 248),
#  ('@FinMinIndia', 144),
#  ('@udaykotak', 82),
#  ('@abndnkmtr', 41),
#  ('@YESBANK', 36),
#  ('@mdpnb', 27),
#  ('@SBICard_Connect', 24),
#  ('@ndtv', 23),
#  ('@IDBI_Bank', 22),
#  ('@BJP4India', 20),
#  ('@TimesNow', 19),
#  ('@DasShaktikanta', 19),
#  ('@mediacrooks', 18),
#  ('@suchetadalal', 17),
#  ('@chandakochhar', 16),
#  ('@aajtak', 16),
#  ('@htTweets', 15),
#  ('@timesofindia', 14),
#  ('@ZeeNews', 14),
#  ('@HDFCBankNews', 13),
#  ('@ArvindKejriwal', 13),
#  ('@CKforCleanIndia', 13),
#  ('@theofficialsbi', 13),
#  ('@neha_aks', 13),
#  ('@CNBCTV18Live', 13),
#  ('@MyIndusIndBank', 12),
#  ('@karishmakotak', 12),
#  ('@OfficeOfRG', 12),
#  ('@sudhirchaudhary', 11),
#  ('@arjunrammeghwal', 11),
#  ('@INCIndia', 11),
#  ('@ANI_news', 11),
#  ('@DelhiPolice', 10),
#  ('@sbi', 10),
#  ('@Bankofindia_BOI', 10),
#  ('@CMofKarnataka', 10),
#  ('@rsprasad', 10),
#  ('@narendramodi_in', 10),
#  ('@gmail', 10),
#  ('@sankrant', 10),
#  ('@Citi', 9),
#  ('@HDFCLIFE', 9),
#  ('@ETNOWlive', 9),
#  ('@adhia03', 9),
#  ('@Indiapnb', 9),
#  ('@vikramwkarve', 8),
#  ('@SushmaSwaraj', 8),
#  ('@abpnewstv', 8),
#  ('@centerofright', 8),
#  ('@PIB_India', 8),
#  ('@UrjitPatelRBI', 8),
#  ('@NewsX', 8),
#  ('@TajinderBagga', 8),
#  ('@ZeeNewsHindi', 8),
#  ('@UfterYou', 8),
#  ('@StanChart', 7),
#  ('@CMOMaharashtra', 7),
#  ('@Paytm', 7),
#  ('@rbi', 7),
#  ('@VijayaBankIndia', 7),
#  ('@PawanDurani', 7),
#  ('@anuyeaah', 6),
#  ('@the_hindu', 6),
#  ('@bainjal', 6),
#  ('@BlueDartTweets', 6),
#  ('@RashtrapatiBhvn', 6),
#  ('@TOIIndiaNews', 6),
#  ('@arjuna04', 6),
#  ('@CVCIndia', 6),
#  ('@Norafatehi', 6),
#  ('@Swamy39', 6),
#  ('@axisbank', 6),
#  ('@anandmahindra', 6),
#  ('@canarabanktweet', 6),
#  ('@CTRavi_BJP', 6),
#  ('@ranjank63', 6),
#  ('@BankofBarodaCEO', 6),
#  ('@Baalkeeg', 6),
#  ('@manakgupta', 6),
#  ('@Chhabiy', 5),
#  ('@sowmyarao_', 5),
#  ('@Citibank', 5),
#  ('@TVMohandasPai', 5),
#  ('@EconomicTimes', 5),
#  ('@pandabythebay', 5),
#  ('@hdfcbank', 5),
#  ('@Finelychopped', 5),
#  ('@PiyushGoyal', 5),
#  ('@CorpBanking', 5),
#  ('@VictoryForNamo', 5),
#  ('@fayedsouza', 5),
#  ('@anilkapur_', 5),
#  ('@VodafoneIN', 5),
#  ('@RBI_India', 5),
#  ('@bsindia', 4),
#  ('@monstermanojit', 4),
#  ('@ConXerv', 4),
#  ('@jayantsinha', 4),
#  ('@IndiaPostOffice', 4),
#  ('@Dev_Fadnavis', 4),
#  ('@BTVI', 4),
#  ('@RadhikaBudhwar', 4),
#  ('@Susmita05787706', 4),
#  ('@ankitnair086', 4),
#  ('@BlrCityPolice', 4),
#  ('@IndianExpress', 4),
#  ('@neerjanni2000', 4),
#  ('@RubikaLiyaquat', 4),
#  ('@AboutIndia', 4),
#  ('@manichejain', 4),
#  ('@CNBC', 4),
#  ('@semubhatt', 4),
#  ('@shilpysinhaET', 4),
#  ('@indiantweeter', 4),
#  ('@vinodkapri', 4),
#  ('@priyank_ks', 4),
#  ('@YouTube', 4),
#  ('@smritimoy', 4),
#  ('@rajnathsingh', 4),
#  ('@AmitShah', 4),
#  ('@manoharparrikar', 4),
#  ('@sanjaynirupam', 4),
#  ('@aakuraj', 4),
#  ('@IndiaToday', 4),
#  ('@monikahalan', 4),
#  ('@MEAIndia', 4),
#  ('@rahulkanwal', 4),
#  ('@bantasavrait', 4),
#  ('@CybercrimeCID', 3),
#  ('@UnionBankTweets', 3),
#  ('@spsurana', 3),
#  ('@centralbank_in', 3),
#  ('@HMOIndia', 3),
#  ('@rajatguleria9', 3),
#  ('@UPI_NPCI', 3),
#  ('@loosebool', 3),
#  ('@OrientalBank', 3),
#  ('@PrashantBarot1', 3),
#  ('@panchali_', 3),
#  ('@shiladitya', 3),
#  ('@rtripathi6', 3),
#  ('@GulPanag', 3),
#  ('@IncomeTaxIndia', 3),
#  ('@Su52k', 3),
#  ('@farahzai', 3),
#  ('@babita_kar', 3),
#  ('@GappistanRadio', 3),
#  ('@raj142004', 3),
#  ('@UCOBankCare', 3),
#  ('@guwahaticity', 3),
#  ('@aajtaknews', 3),
#  ('@AmanKayamHai_ET', 3),
#  ('@Breathedreamgo', 3),
#  ('@dixitsatish5', 3),
#  ('@theVtheM', 3),
#  ('@NagpalManoj', 3),
#  ('@bharathb1000', 3),
#  ('@NeerajHDFCBank', 3),
#  ('@ICICIPruLife', 3),
#  ('@sbbj_bank', 3),
#  ('@nildeore', 3),
#  ('@b50', 3),
#  ('@srirambjp', 3),
#  ('@kavyashree_p819', 3),
#  ('@Indemb_Muscat', 3),
#  ('@Lalit__Yadav', 3),
#  ('@sarbanandsonwal', 3),
#  ('@SahilBulla', 3),
#  ('@idea_cares', 3),
#  ('@BigBazaar', 3),
#  ('@alok_bhatt', 3),
#  ('@a_r_j_u_n', 3),
#  ('@Upsunson', 3),
#  ('@NashikNews', 3),
#  ('@ETBrandEquity', 3),
#  ('@FederalBankLtd', 3),
#  ('@sujeetmishra', 3),
#  ('@ConsumerReports', 3),
#  ('@muglikar_', 3),
#  ('@im_nindak', 3),
#  ('@goyalsanjeev', 3),
#  ('@ICICI_Direct', 3),
#  ('@Sootradhar', 3),
#  ('@nice', 3),
#  ('@axisbanksupport', 3),
#  ('@BankingOmbud', 3),
#  ('@KotakJifi', 3),
#  ('@powaiinfo', 2),
#  ('@sunil_malpotra', 2),
#  ('@madhu_sahoo', 2),
#  ('@princesurana', 2),
#  ('@WorldBank', 2),
#  ('@paytm', 2),
#  ('@imTejasBarot', 2),
#  ('@KotakbankLtd', 2),
#  ('@Cybercellindia', 2),
#  ('@TheHindu', 2),
#  ('@icicibank', 2),
#  ('@DCBBank', 2),
#  ('@MaccharManJr', 2),
#  ('@manishkinhikar', 2),
#  ('@imeerage', 2),
#  ('@ksmkkbookscom', 2),
#  ('@saurabh_chande', 2),
#  ('@KARMENDRAKUMAR', 2),
#  ('@sidgsh1', 2),
#  ('@NewIndianXpress', 2),
#  ('@sona2905', 2),
#  ('@ndtvindia', 2),
#  ('@HDFCBANK_Cares', 2),
#  ('@abpanandatv', 2),
#  ('@Raminations', 2),
#  ('@IDFC_Bank', 2),
#  ('@DG_PIB', 2),
#  ('@BJP4Delhi', 2),
#  ('@UN', 2),
#  ('@royabhijit71', 2),
#  ('@ranganaathan', 2),
#  ('@asraghunath', 2),
#  ('@chetanjkabra', 2),
#  ('@KishoreKar', 2),
#  ('@aiims_newdelhi', 2),
#  ('@MoHFW_INDIA', 2),
#  ('@unionbankofIN', 2),
#  ('@Indianoverseasb', 2),
#  ('@RahulMalkaunsh', 2),
#  ('@vdynthn', 2),
#  ('@genirajeev', 2),
#  ('@7am', 2),
#  ('@Shaas14', 2),
#  ('@vinodunny', 2),
#  ('@saikanomie', 2),
#  ('@JDforall', 2),
#  ('@RBIgovernor', 2),
#  ('@RShivshankar', 2),
#  ('@kai52vai', 2),
#  ('@munshi_jee', 2),
#  ('@nitintp', 2),
#  ('@PLEKarnataka', 2),
#  ('@adgpi', 2),
#  ('@livemint', 2),
#  ('@kashif_ahmedk', 2),
#  ('@kotaksync', 2),
#  ('@Vidyadarc', 2),
#  ('@pateriya_kapil', 2),
#  ('@yadavakhilesh', 2),
#  ('@bhatnaturally', 2),
#  ('@ArjunVagale', 2),
#  ('@Outlookindia', 2),
#  ('@6', 2),
#  ('@SIRBLOFELD', 2),
#  ('@ashkronos', 2),
#  ('@uddhavthackeray', 2),
#  ('@rockingramola', 2),
#  ('@BJP4Bengal', 2),
#  ('@pbhushan1', 2),
#  ('@SrikantKumarGh1', 2),
#  ('@moneycontrolcom', 2),
#  ('@WithCongress', 2),
#  ('@journalistreyaz', 2),
#  ('@RISHIKUMSAGAR', 2),
#  ('@BuddySolar', 2),
#  ('@hdfcbank_cares', 2),
#  ('@airtelindia', 2),
#  ('@sutirtharoy', 2),
#  ('@delhi_lawyer', 2),
#  ('@ParinSays', 2),
#  ('@nawinraja', 2),
#  ('@IamNAVED', 2),
#  ('@thej', 2),
#  ('@Vivekchandan', 2),
#  ('@nistula', 2),
#  ('@HomeLoansByHDFC', 2),
#  ('@DIFC', 2),
#  ('@brakoo', 2),
#  ('@AskAnshul', 2),
#  ('@singhvarun', 2),
#  ('@Dev2Girish', 2),
#  ('@anuragkumarlko', 2),
#  ('@MumbaiPolice', 2),
#  ('@RelianceMobile', 2),
#  ('@raja_sen', 2),
#  ('@YuvaSambalpur', 2),
#  ('@commoner_lawyer', 2),
#  ('@TRAI', 2),
#  ('@bihar_police', 2),
#  ('@ayush_dzire', 2),
#  ('@theofficialSBI', 2),
#  ('@321ynnus', 2),
#  ('@MobiKwik', 2),
#  ('@rajanvichare', 2),
#  ('@indianbanksorg', 2),
#  ('@indianbankers', 2),
#  ('@indianbanks', 2),
#  ('@vikasbha', 2),
#  ('@ICICIBANK', 2),
#  ('@iamChetanSinha', 2),
#  ('@gujjugabbar', 2),
#  ('@ajantriks', 2),
#  ('@CitibankIN', 2),
#  ('@ls2008', 2),
#  ('@AxisBankOffers', 2),
#  ('@heeraman98', 2),
#  ('@sushilizzat', 2),
#  ('@varunkrish', 2),
#  ('@icicibank_care', 2),
#  ('@rameem81', 2),
#  ('@AamAadmiParty', 2),
#  ('@_swaroop', 2),
#  ('@bomrochd', 2),
#  ('@VishweshwarBhat', 2),
#  ('@northern', 2),
#  ('@SimplyHimanshuR', 2),
#  ('@Sarthakviews', 2),
#  ('@javeeddgpup', 2),
#  ('@Uppolice', 2),
#  ('@dudeitsaalok', 2),
#  ('@abpnewshindi', 2),
#  ('@SuratPolice', 2),
#  ('@RajivMessage', 2),
#  ('@MVenkaiahNaidu', 2),
#  ('@sureshpprabhu', 2),
#  ('@strawsInTheWind', 2),
#  ('@ankushmn', 2),
#  ('@AAamireta', 2),
#  ('@drharshvardhan', 2),
#  ('@Jha__Pooja', 2),
#  ('@SBIBanks', 2),
#  ('@devangdream', 2),
#  ('@manojsinhabjp', 2),
#  ('@MrCollarOutfits', 2),
#  ('@CMMadhyaPradesh', 2),
#  ('@sanjoyb17', 2),
#  ('@iSushilPandey', 2),
#  ('@PBidasar', 2),
#  ('@agarwal_malvika', 2),
#  ('@klalgurnani', 2),
#  ('@ANINewsUP', 2),
#  ('@GauravSingal', 2),
#  ('@giveawayvimax', 2),
#  ('@rajeshkalra', 2),
#  ('@RajeshTamret', 2),
#  ('@ArunbajpaiRajan', 2),
#  ('@sachin_0707', 2),
#  ('@RajatSharmaLive', 2),
#  ('@Yadu4ever', 2),
#  ('@STATEBANK_CARES', 2),
#  ('@sec', 2),
#  ('@subrataiam', 2),
#  ('@allahabadbank4u', 2),
#  ('@waquaralamkhan', 2),
#  ('@ramachandra1047', 2),
#  ('@GACL', 2),
#  ('@Truth4win', 2),
#  ('@anilkohli54', 2),
#  ('@FreeChargeCares', 2),
#  ('@BBCWorld', 2),
#  ('@CNNnews18', 2),
#  ('@RatanSharda55', 2),
#  ('@PPSINGH5736', 2),
#  ('@Allahabad_Bank', 2),
#  ('@swachhbharat', 2),
#  ('@priyashmita', 2),
#  ('@RaviKrTomar', 2),
#  ('@RumanaNazarali', 2),
#  ('@divyanshuu', 2),
#  ('@paritosh2608', 2),
#  ('@ukyrem', 2),
#  ('@TCS', 2),
#  ('@DY365', 2),
#  ('@ankit1534', 2),
#  ('@StaffoAceFerns', 2),
#  ('@robinkansara', 2),
#  ('@AshishSBhardwaj', 2),
#  ('@OneindiaKannada', 2),
#  ('@mgnayak5', 2),
#  ('@pmoindia', 2),
#  ('@shwetajha_', 2),
#  ('@AcmatixJoshi', 2),
#  ('@nsitharaman', 2),
#  ('@sanatm', 1),
#  ('@ajitsinghs', 1),
#  ('@Pankushjindal', 1),
#  ('@saket71', 1),
#  ('@Shehla_Rashid', 1),
#  ('@tejujoshi31', 1),
#  ('@Tarun260', 1),
#  ('@Aryanwarlord', 1),
#  ('@kapadwanj', 1),
#  ('@MindSphere_IN', 1),
#  ('@AmhiDombivlikar', 1),
#  ('@DnsBank', 1),
#  ('@vineetjaintimes', 1),
#  ('@axisbank275', 1),
#  ('@EnggJourno', 1),
#  ('@indian8money', 1),
#  ('@n', 1),
#  ('@peekayteee', 1),
#  ('@alhaz_sidhva', 1),
#  ('@imVkohli', 1),
#  ('@AskCiti', 1),
#  ('@Kashmir_Monitor', 1),
#  ('@parikshitkmr', 1),
#  ('@thehindubiz', 1),
#  ('@DipakKhuthia', 1),
#  ('@naren', 1),
#  ('@faizanshaikh4u', 1),
#  ('@Khoslarajat10', 1),
#  ('@rituraj_prht', 1),
#  ('@ArunArungupta05', 1),
#  ('@Sn3haAgrawal', 1),
#  ('@narendramodisbi', 1),
#  ('@Max_Gupta', 1),
#  ('@pandeypankaj20', 1),
#  ('@Jinaymodi', 1),
#  ('@ikhan0784', 1),
#  ('@lagerfortwo', 1),
#  ('@SMahankali', 1),
#  ('@tejinderbagga', 1),
#  ('@mildwave', 1),
#  ('@romanaisarkhan', 1),
#  ('@c0nvey', 1),
#  ('@rokade_rahul', 1),
#  ('@prernatutors', 1),
#  ('@ajavgal', 1),
#  ('@YeshwanthKini', 1),
#  ('@ETVMadhyaprades', 1),
#  ('@paavanshukla', 1),
#  ('@kiran_patniak', 1),
#  ('@ndtvindiaDeposit', 1),
#  ('@krunalhp', 1),
#  ('@KotakBankL', 1),
#  ('@AuthorNilesh', 1),
#  ('@akota', 1),
#  ('@SANDIPC08579182', 1),
#  ('@parthshah88', 1),
#  ('@Bangaloremirror', 1),
#  ('@HDFC', 1),
#  ('@RanjitsinhKase1', 1),
#  ('@shilpitewari', 1),
#  ('@hashPune', 1),
#  ('@karandeep1', 1),
#  ('@ashprak', 1),
#  ('@digibank', 1),
#  ('@sbicareers', 1),
#  ('@vishalgondal', 1),
#  ('@rajeevdubey', 1),
#  ('@ThereyouG', 1),
#  ('@WilliamVJacob', 1),
#  ('@sunilsharma161', 1),
#  ('@Uday846845', 1),
#  ('@Jiggy_wan21', 1),
#  ('@vish107', 1),
#  ('@ragunathwg', 1),
#  ('@dir_ed', 1),
#  ('@sangitamehtaET', 1),
#  ('@royab', 1),
#  ('@bhakat_m', 1),
#  ('@Bharat_Putra', 1),
#  ('@upadh', 1),
#  ('@iimudpr', 1),
#  ('@NewspointTv', 1),
#  ('@aniruddhg1', 1),
#  ('@kotakbankltd', 1),
#  ('@currentu', 1),
#  ('@TheVijayMallya', 1),
#  ('@jeremycorbyn', 1),
#  ('@EU', 1),
#  ('@MyLoveNamo', 1),
#  ('@arunjaitl', 1),
#  ('@20Sheenu', 1),
#  ('@theburugula', 1),
#  ('@UCOBANKHO', 1),
#  ('@Gaddadaari', 1),
#  ('@gautamsohoni', 1),
#  ('@dipunair', 1),
#  ('@andnkmtr', 1),
#  ('@ravihanda', 1),
#  ('@themucktalif', 1),
#  ('@rashmibansal', 1),
#  ('@naveenk_vin', 1),
#  ('@DrMahi89', 1),
#  ('@chennai', 1),
#  ('@masala_chaas', 1),
#  ('@pune', 1),
#  ('@littleyums', 1),
#  ('@sabbir_india', 1),
#  ('@gouravgv', 1),
#  ('@GenomicKarma', 1),
#  ('@write2kill', 1),
#  ('@ad9820', 1),
#  ('@CareSBI', 1),
#  ('@prasannasb1', 1),
#  ('@maktrixster', 1),
#  ('@HSBC', 1),
#  ('@chandanbeta1487', 1),
#  ('@sharanpoovanna', 1),
#  ('@mallik_muzammil', 1),
#  ('@patilbrij', 1),
#  ('@iamchetansinha', 1),
#  ('@sureshkpujari', 1),
#  ('@Singham_Bhavani', 1),
#  ('@realDonaldTrump', 1),
#  ('@HemantM78454623', 1),
#  ('@kmgnath', 1),
#  ('@sardanarohit', 1),
#  ('@nandita_zee', 1),
#  ('@anuraagmuskaan', 1),
#  ('@innocentlyloud', 1),
#  ('@nikhilaj', 1),
#  ('@vishalathink', 1),
#  ('@vijaygup', 1),
#  ('@ktkbankltd', 1),
#  ('@deepakmsharma1', 1),
#  ('@Efma_news', 1),
#  ('@orphean_warbler', 1),
#  ('@cash', 1),
#  ('@Shilpiisinghh', 1),
#  ('@sheetal_walia', 1),
#  ('@shaykhar', 1),
#  ('@CNN', 1),
#  ('@schmmuck', 1),
#  ('@thomson_v', 1),
#  ('@waseem0761', 1),
#  ('@IASassociation', 1),
#  ('@IPS_Association', 1),
#  ('@dhruvrastogi04', 1),
#  ('@15mohit', 1),
#  ('@RuchaPatkar', 1),
#  ('@mazhyasarkhime', 1),
#  ('@SURJAYAKKI', 1),
#  ('@BirsaDasgupta', 1),
#  ('@KameeniChhori', 1),
#  ('@advantej_', 1),
#  ('@sandipmangukiy4', 1),
#  ('@Daniel1235gd', 1),
#  ('@ankurmodi5491', 1),
#  ('@kunalkamra88', 1),
#  ('@s0ulbuzz', 1),
#  ('@SUBHASKUMAR', 1),
#  ('@LocalCircles', 1),
#  ('@Amit_sri1912', 1),
#  ('@kuntalpanja', 1),
#  ('@Rashtravadi007', 1),
#  ('@siddhan97108044', 1),
#  ('@colorsherlock', 1),
#  ('@CoffeePenCamera', 1),
#  ('@Manoj1108Manoj', 1),
#  ('@harpreetsubhi', 1),
#  ('@HDFCBank_Offers', 1),
#  ('@anksumads', 1),
#  ('@yashwecan', 1),
#  ('@PrabhuChawla', 1),
#  ('@gogarkrish', 1),
#  ('@BankMysore', 1),
#  ('@Mitalishah121', 1),
#  ('@1ab6b0199324490', 1),
#  ('@GauravGogoiAsm', 1),
#  ('@arwa_husain', 1),
#  ('@ajayiyer15', 1),
#  ('@missuniversedb', 1),
#  ('@UnifSpirit', 1),
#  ('@swetsarika', 1),
#  ('@jha_siddhus94', 1),
#  ('@i', 1),
#  ('@monsun14', 1),
#  ('@RajnishTuli', 1),
#  ('@AKohli03', 1),
#  ('@Adidev2394', 1),
#  ('@MyIndusIn', 1),
#  ('@sumeetgupta1971', 1),
#  ('@shabbarvhora', 1),
#  ('@chandankr', 1),
#  ('@AmitAryans1', 1),
#  ('@jntd11', 1),
#  ('@asheeshchawla', 1),
#  ('@new', 1),
#  ('@TrustingINDIA', 1),
#  ('@ShreeLaxmiArt', 1),
#  ('@sharalayanandan', 1),
#  ('@FarhanNadaf', 1),
#  ('@ishan_vipul', 1),
#  ('@ssnehra101015', 1),
#  ('@vardh4377', 1),
#  ('@kelekachilka', 1),
#  ('@scroll_in', 1),
#  ('@cakeaberry1', 1),
#  ('@chinmaytrivedi', 1),
#  ('@tallstories', 1),
#  ('@HSBC_IN', 1),
#  ('@kabandisaikia', 1),
#  ('@Why', 1),
#  ('@SMungantiwar', 1),
#  ('@Aryavarta_', 1),
#  ('@chuenchenliu', 1),
#  ('@TheRahulMehra', 1),
#  ('@VaidyaPriyam', 1),
#  ('@rajthakre', 1),
#  ('@AnupamPkher', 1),
#  ('@Paritos007', 1),
#  ('@lady_naarad', 1),
#  ('@_Murali', 1),
#  ('@palashgoorha', 1),
#  ('@jetairways', 1),
#  ('@abhay_runwal', 1),
#  ('@KetanDialani', 1),
#  ('@Ppanks_G', 1),
#  ('@Mayank1551984', 1),
#  ('@sadiqueanj', 1),
#  ('@rjraunac', 1),
#  ('@RajivranjanjJha', 1),
#  ('@sonal_31559', 1),
#  ('@vadapoche', 1),
#  ('@rajeshn22', 1),
#  ('@karan1407', 1),
#  ('@jgdaditya', 1),
#  ('@PrannoyRoyNDTV', 1),
#  ('@Vedmishra9', 1),
#  ('@Piyush26490275', 1),
#  ('@8527672044', 1),
#  ('@BeingReva', 1),
#  ('@nakulsaxena786', 1),
#  ('@MamataOfficial', 1),
#  ('@mvslsv', 1),
#  ('@ashirwadmittal', 1),
#  ('@hardik9900', 1),
#  ('@binodpks', 1),
#  ('@Reliance_MF', 1),
#  ('@hussainq11', 1),
#  ('@PrashantmET', 1),
#  ('@ADHVAYAM', 1),
#  ('@viralv1', 1),
#  ('@kittumaheshwari', 1),
#  ('@bibhasdn', 1),
#  ('@nawiedj', 1),
#  ('@Circle_India', 1),
#  ('@swamiram96', 1),
#  ('@sjsrathore', 1),
#  ('@banksyndicate', 1),
#  ('@sureshkkedia', 1),
#  ('@mid_day', 1),
#  ('@Only_Chirag', 1),
#  ('@Ssuujjaayy11', 1),
#  ('@Sachzzz', 1),
#  ('@IndianEmbassyUS', 1),
#  ('@naukarshah', 1),
#  ('@kiranruled', 1),
#  ('@travellerAmit', 1),
#  ('@DhruvSonagra', 1),
#  ('@akshaypandt', 1),
#  ('@ICICIBan', 1),
#  ('@linganikhil8', 1),
#  ('@uttara66', 1),
#  ('@drshraddha16', 1),
#  ('@dna', 1),
#  ('@jagograhakjago', 1),
#  ('@VikasDatta', 1),
#  ('@amazonIN', 1),
#  ('@me_indian', 1),
#  ('@indiatvnews', 1),
#  ('@HinduHangout', 1),
#  ('@sunandavashisht', 1),
#  ('@mantraventures', 1),
#  ('@gauravvkchawla', 1),
#  ('@rohansippy', 1),
#  ('@SaraswatBank', 1),
#  ('@SVC_Bank', 1),
#  ('@sajid70143', 1),
#  ('@VaibhavWrites', 1),
#  ('@AnupamSSaroj', 1),
#  ('@manjunathreddys', 1),
#  ('@pnb', 1),
#  ('@raveendrakumaar', 1),
#  ('@Imtiyaz46799784', 1),
#  ('@sagar13d', 1),
#  ('@tistathinks', 1),
#  ('@AxisDirect_In', 1),
#  ('@spbhattacharya', 1),
#  ('@reply', 1),
#  ('@mayankpratap773', 1),
#  ('@AxisBan', 1),
#  ('@TOIMumbai', 1),
#  ('@h_s1ngh', 1),
#  ('@h_boob1', 1),
#  ('@keshri_niraj', 1),
#  ('@kirantare', 1),
#  ('@mehralovey', 1),
#  ('@BadServiceNews', 1),
#  ('@srikanthgadgay', 1),
#  ('@abndrkmtr', 1),
#  ('@nthiru28', 1),
#  ('@therealakbarr', 1),
#  ('@samyagdrsti', 1),
#  ('@aniltewatia', 1),
#  ('@nigam_shishir', 1),
#  ('@MengiKuldip', 1),
#  ('@CNBCTV18News', 1),
#  ('@followme_ParagP', 1),
#  ('@nambiarmahesh', 1),
#  ('@naweliprachi', 1),
#  ('@Maharashtra1tv', 1),
#  ('@MahaPolice', 1),
#  ('@kznair', 1),
#  ('@saritanarang01', 1),
#  ('@SAnju_ShoorA', 1),
#  ('@Mayankshl47', 1),
#  ('@godfatherrohin', 1),
#  ('@hingane', 1),
#  ('@mrsfunnybones', 1),
#  ('@devduttmyth', 1),
#  ('@avirooksen', 1),
#  ('@ashwinsanghi', 1),
#  ('@agranpapilot3', 1),
#  ('@Soumitradas1991', 1),
#  ('@RBenjaminips1', 1),
#  ('@rushdiexplains', 1),
#  ('@KAMALsSUTRA', 1),
#  ('@RitaG74', 1),
#  ('@Umashankar35', 1),
#  ('@somnath1978', 1),
#  ('@venuvakeel', 1),
#  ('@I_yam_nendu', 1),
#  ('@ashokkmrsingh', 1),
#  ('@Praveenksh', 1),
#  ('@godavar', 1),
#  ('@abidbakshi', 1),
#  ('@paritoshchoubey', 1),
#  ('@dilshad', 1),
#  ('@aschauhan26', 1),
#  ('@periyakulam', 1),
#  ('@PNBMetlife1', 1),
#  ('@AmitVaani', 1),
#  ('@Rjkartik', 1),
#  ('@StinkiestBrain', 1),
#  ('@harshalkar', 1),
#  ('@tourismgoi', 1),
#  ('@PostOfficeIndia', 1),
#  ('@incredibleindia', 1),
#  ('@dr_maheshsharma', 1),
#  ('@my_rajasthan', 1),
#  ('@IMFNews', 1),
#  ('@Digamber', 1),
#  ('@ishq1010', 1),
#  ('@KaustubhRedkar', 1),
#  ('@skv_india', 1),
#  ('@financialombuds', 1),
#  ('@ipravinn', 1),
#  ('@thesandeepm', 1),
#  ('@pankajjha_', 1),
#  ('@vdube82', 1),
#  ('@anvil67978', 1),
#  ('@Write2Manmohan', 1),
#  ('@AskRaushan', 1),
#  ('@salonishuklaET', 1),
#  ('@kapsology', 1),
#  ('@gautam_adani', 1),
#  ('@bank_ofindia', 1),
#  ('@manjunath_mc', 1),
#  ('@kshitijladia', 1),
#  ('@shubh_pittu', 1),
#  ('@VocesNihili', 1),
#  ('@ETVUPLIVE', 1),
#  ('@SumitSsksh', 1),
#  ('@DrYash_Sonawane', 1),
#  ('@animesh1870', 1),
#  ('@adapaavi', 1),
#  ('@AnupamSaraph', 1),
#  ('@VenuSpeak', 1),
#  ('@Stupidosaur', 1),
#  ('@IndianOilcl', 1),
#  ('@JhaSanjay', 1),
#  ('@Bharat_Lohani', 1),
#  ('@ArvindKejriwalYou', 1),
#  ('@rajivanand', 1),
#  ('@NewshoundPoonam', 1),
#  ('@ajitkdubey', 1),
#  ('@macharajarao', 1),
#  ('@Eenadu_English', 1),
#  ('@Kr_Divyaprakash', 1),
#  ('@makemytripcare', 1),
#  ('@AmazonIN', 1),
#  ('@MVayeda', 1),
#  ('@sanjeetguru', 1),
#  ('@AndhraPradeshCM', 1),
#  ('@JaiTDP', 1),
#  ('@AvinashaSharma', 1),
#  ('@rabkabanda101', 1),
#  ('@dailyo_', 1),
#  ('@AKMODI11', 1),
#  ('@ashishcool1988', 1),
#  ('@prashantsriv1', 1),
#  ('@jitu_01324', 1),
#  ('@narendram', 1),
#  ('@helmetgirlbndra', 1),
#  ('@BlueDart_Help', 1),
#  ('@vinayprakash58', 1),
#  ('@Netra', 1),
#  ('@OmanObserver', 1),
#  ('@avinav2712', 1),
#  ('@ICICIPruMF', 1),
#  ('@iMac_too', 1),
#  ('@OhYesAsh4U', 1),
#  ('@ProAMTraider', 1),
#  ('@beingneerajrana', 1),
#  ('@amitaryans1', 1),
#  ('@kkumarkg', 1),
#  ('@ShamanOfJava', 1),
#  ('@niraj_mishra1', 1),
#  ('@DrKumarVishwas', 1),
#  ('@ersawankumar', 1),
#  ('@myasheen', 1),
#  ('@Mdsabedbhuyan', 1),
#  ('@ImMegafan', 1),
#  ('@poojamakhija', 1),
#  ('@sbiINTOUCH', 1),
#  ('@ArtofLiving', 1),
#  ('@snobfielder', 1),
#  ('@anshu_nitrkl', 1),
#  ('@thakkargopal', 1),
#  ('@nynmohanty', 1),
#  ('@21century_kant', 1),
#  ('@ranwijay', 1),
#  ('@The', 1),
#  ('@kalkihprashar', 1),
#  ('@NativeThoughts', 1),
#  ('@MRVChennai', 1),
#  ('@Geniustweeet', 1),
#  ('@kutchikamikaze', 1),
#  ('@Babluooo28312', 1),
#  ('@Embassy', 1),
#  ('@venkatchandu55', 1),
#  ('@PMO_India', 1),
#  ('@hariprasadholla', 1),
#  ('@vnbohra', 1),
#  ('@j0shiG', 1),
#  ('@Hina80819981', 1),
#  ('@Kavit4', 1),
#  ('@RKUMAR198011', 1),
#  ('@kuldeep_vermas', 1),
#  ('@afsanacutie', 1),
#  ('@nainitalbank', 1),
#  ('@Eaglesiar', 1),
#  ('@Ramesh673S', 1),
#  ('@AceofSpades_001', 1),
#  ('@kimchemicals', 1),
#  ('@mojorojo', 1),
#  ('@Bengaluruitebiz', 1),
#  ('@DeepXP', 1),
#  ('@anubhavdas', 1),
#  ('@AshTheWiz', 1),
#  ('@RCommCare', 1),
#  ('@rockykumar62', 1),
#  ('@gargpankaj2002', 1),
#  ('@PranavDate', 1),
#  ('@KannadaGrahaka', 1),
#  ('@narsingh_ptl', 1),
#  ('@TheOfficialSBi', 1),
#  ('@smriti_k17', 1),
#  ('@kottayimavoor', 1),
#  ('@AakashP72776330', 1),
#  ('@ICICIBank_Car', 1),
#  ('@MEmaaduddin', 1),
#  ('@haripra03373147', 1),
#  ('@diamondantoo', 1),
#  ('@TRA_Research', 1),
#  ('@Axi', 1),
#  ('@shreyishere', 1),
#  ('@GauravKPaul', 1),
#  ('@pshrivastava_tw', 1),
#  ('@99acresIndia', 1),
#  ('@CMOGuj', 1),
#  ('@calmchandan', 1),
#  ('@dhavalgandhi007', 1),
#  ('@BT_India', 1),
#  ('@iamniteshj', 1),
#  ('@AvnishAxis', 1),
#  ('@dilipkpandey', 1),
#  ('@sarikajohari', 1),
#  ('@GKanudawala', 1),
#  ('@makeperceptions', 1),
#  ('@MissFurioso', 1),
#  ('@Bankofbaroda', 1),
#  ('@Mimansa_Zee', 1),
#  ('@avasthiaditi', 1),
#  ('@prakjham', 1),
#  ('@TopGear534', 1),
#  ('@bankingombusman', 1),
#  ('@sanjaybaboo', 1),
#  ('@psinhajha', 1),
#  ('@finminindia', 1),
#  ('@SunilRGowda16', 1),
#  ('@IndiathinkOrg', 1),
#  ('@rishibagree', 1),
#  ('@Techtrail', 1),
#  ('@akanksharedhu', 1),
#  ('@11nov2016', 1),
#  ('@skyunleased', 1),
#  ('@Subhajit_K9472', 1),
#  ('@Vicky_291989', 1),
#  ('@AdvancedBharat', 1),
#  ('@ishu03', 1),
#  ('@zanbamn', 1),
#  ('@nilavachowdhury', 1),
#  ('@flyingvikas129', 1),
#  ('@llManishll', 1),
#  ('@Newalipore', 1),
#  ('@akhileshsharma1', 1),
#  ('@DrGPradhan', 1),
#  ('@ashishbadshah', 1),
#  ('@joy_dutta1', 1),
#  ('@AK_Bhosale', 1),
#  ('@sunshine_chat', 1),
#  ('@Jjo_Mojo', 1),
#  ('@SohoRoadBID', 1),
#  ('@NidhiChib', 1),
#  ('@KotakIndia', 1),
#  ('@chaitanya21688', 1),
#  ('@iswara1984', 1),
#  ('@Mahipalpur_branch', 1),
#  ('@arunishas', 1),
#  ('@ankit_abpnews', 1),
#  ('@_DigitalIndia', 1),
#  ('@imarun_11', 1),
#  ('@NPCI_NPCI', 1),
#  ('@nitin_sarohival', 1),
#  ('@vgiroti', 1),
#  ('@drsanjaysoni', 1),
#  ('@ashuvaani', 1),
#  ('@frittzeegirl', 1),
#  ('@Pratik_Bhartia', 1),
#  ('@debayanc3', 1),
#  ('@kaw_shivani', 1),
#  ('@ukkuru', 1),
#  ('@sandip_rail', 1),
#  ('@UttarandhraNow', 1),
#  ('@diparashar', 1),
#  ('@pmenviro', 1),
#  ('@PRATIMA_03', 1),
#  ('@DevelopedSurat', 1),
#  ('@PMOInd', 1),
#  ('@1', 1),
#  ('@Hungry_Old_Man', 1),
#  ('@RaviMohanSriva7', 1),
#  ('@vaibhav_vyas', 1),
#  ('@Gravim71', 1),
#  ('@SANDHUHARKIRAT', 1),
#  ('@ShahnawazBJP', 1),
#  ('@shuchi_modi', 1),
#  ('@bond_aj', 1),
#  ('@SureshGkumar88', 1),
#  ('@shaswatidas', 1),
#  ('@WreckdFx', 1),
#  ('@giddyja', 1),
#  ('@arunjait', 1),
#  ('@SurbhiJain03', 1),
#  ('@Nsel_Victim', 1),
#  ('@bimal_pr', 1),
#  ('@sbi_india', 1),
#  ('@Narendramodi_PM', 1),
#  ('@Vicky_Digitech', 1),
#  ('@join2tarun', 1),
#  ('@vikasdh', 1),
#  ('@ankurdpathak', 1),
#  ('@rajanbatra7765', 1),
#  ('@yesbank4', 1),
#  ('@Firki_', 1),
#  ('@kamessubbaraman', 1),
#  ('@RA', 1),
#  ('@harshaperla', 1),
#  ('@madhumachi', 1),
#  ('@onilaraj', 1),
#  ('@vikcse59', 1),
#  ('@KARUNASHANKEROJ', 1),
#  ('@Visa_IND', 1),
#  ('@andhrabank', 1),
#  ('@airvistara', 1),
#  ('@raju777_praveen', 1),
#  ('@gagkumar', 1),
#  ('@bishu57', 1),
#  ('@MePiyush', 1),
#  ('@ShantonilNag', 1),
#  ('@kaushkrahul', 1),
#  ('@AnilSha88355475', 1),
#  ('@fabcars', 1),
#  ('@AbheekHDFCBank', 1),
#  ('@ishantanujoshi', 1),
#  ('@socialepfo', 1),
#  ('@sejaljobanputra', 1),
#  ...]

# %%
#removing punctuation and converting to lower case
def rmvpuct_lower(text):
    text_lc = "".join([word.lower() for word in text if word not in string.punctuation]) # remove puntuation
    text_rc = re.sub('[0-9]+', '', text_lc)
    return text_rc

df['Tweet_str'] = df['tweet'].apply(lambda x:rmvpuct_lower(x))
df.head()
# Out:
#                                                tweet      sentiment bank  \
# 0  @AxisBankSupport 18..233.... is permanently bu...    displeasure  NaN
# 1  @TheOfficialSBI 3 hours in line,still waiting....    displeasure  NaN
# 2  @HDFCBank_Cares Both the ATM machines here in ...    displeasure  NaN
# 3  @ICICIBank Thanks icici bank I got case in you...  miscellaneous  NaN
# 4  @RBI In Assam all banks are exchanging 4000/- ...    displeasure  NaN
#
#                                @  \
# 0             [@AxisBankSupport]
# 1              [@TheOfficialSBI]
# 2     [@HDFCBank_Cares, @sanatm]
# 3  [@ICICIBank, @TheOfficialSBI]
# 4        [@RBI, @TheOfficialSBI]
#
#                                            Tweet_str
# 0  axisbanksupport  is permanently busy  amp  can...
# 1  theofficialsbi  hours in linestill waiting wis...
# 2  hdfcbankcares both the atm machines here in ti...
# 3  icicibank thanks icici bank i got case in your...
# 4  rbi in assam all banks are exchanging  once on...

# %%
#finding bank associated with each tweet
def find_bank(text):
    bnk=re.findall(r"hdfc|axis|sbi|icici|kotak",text)
    return bnk
df['bank'] = (df['Tweet_str']).apply(lambda x: find_bank(x))
df.head()
# Out:
#                                                tweet      sentiment  \
# 0  @AxisBankSupport 18..233.... is permanently bu...    displeasure
# 1  @TheOfficialSBI 3 hours in line,still waiting....    displeasure
# 2  @HDFCBank_Cares Both the ATM machines here in ...    displeasure
# 3  @ICICIBank Thanks icici bank I got case in you...  miscellaneous
# 4  @RBI In Assam all banks are exchanging 4000/- ...    displeasure
#
#                   bank                              @  \
# 0               [axis]             [@AxisBankSupport]
# 1                [sbi]              [@TheOfficialSBI]
# 2               [hdfc]     [@HDFCBank_Cares, @sanatm]
# 3  [icici, icici, sbi]  [@ICICIBank, @TheOfficialSBI]
# 4                [sbi]        [@RBI, @TheOfficialSBI]
#
#                                            Tweet_str
# 0  axisbanksupport  is permanently busy  amp  can...
# 1  theofficialsbi  hours in linestill waiting wis...
# 2  hdfcbankcares both the atm machines here in ti...
# 3  icicibank thanks icici bank i got case in your...
# 4  rbi in assam all banks are exchanging  once on...

# %%
def clean_text(text):
    text_lc = "".join([word.lower() for word in text if word not in string.punctuation]) # remove puntuation
    text_rc = re.sub('[0-9]+', '', text_lc)
    tokens = re.split('\W+', text_rc)    # tokenization
    text = [word for word in tokens if word not in stopword]  # remove stopwords and stemming
    return text
df['Tweet_cleaned'] = df['tweet'].apply(lambda x: clean_text(x))

# %%
def stemming(text):
    text = [ps.stem(word) for word in text]
    return text

df['Tweet_stemmed'] = df['Tweet_cleaned'].apply(lambda x: stemming(x))

def lemmatizer(text):
    text = [wn.lemmatize(word) for word in text]
    return text
df['Tweet_lemmatized_stemmed'] = df['Tweet_stemmed'].apply(lambda x: lemmatizer(x))
df.head()
# Out:
#                                                tweet      sentiment  \
# 0  @AxisBankSupport 18..233.... is permanently bu...    displeasure
# 1  @TheOfficialSBI 3 hours in line,still waiting....    displeasure
# 2  @HDFCBank_Cares Both the ATM machines here in ...    displeasure
# 3  @ICICIBank Thanks icici bank I got case in you...  miscellaneous
# 4  @RBI In Assam all banks are exchanging 4000/- ...    displeasure
#
#                   bank                              @  \
# 0               [axis]             [@AxisBankSupport]
# 1                [sbi]              [@TheOfficialSBI]
# 2               [hdfc]     [@HDFCBank_Cares, @sanatm]
# 3  [icici, icici, sbi]  [@ICICIBank, @TheOfficialSBI]
# 4                [sbi]        [@RBI, @TheOfficialSBI]
#
#                                            Tweet_str  \
# 0  axisbanksupport  is permanently busy  amp  can...
# 1  theofficialsbi  hours in linestill waiting wis...
# 2  hdfcbankcares both the atm machines here in ti...
# 3  icicibank thanks icici bank i got case in your...
# 4  rbi in assam all banks are exchanging  once on...
#
#                                        Tweet_cleaned  \
# 0  [axisbanksupport, permanently, busy, amp, cann...
# 1  [theofficialsbi, hours, linestill, waiting, wi...
# 2  [hdfcbankcares, atm, machines, times, india, n...
# 3  [icicibank, thanks, icici, bank, got, case, at...
# 4  [rbi, assam, banks, exchanging, exchanged, yes...
#
#                                        Tweet_stemmed  \
# 0  [axisbanksupport, perman, busi, amp, cannot, g...
# 1  [theofficialsbi, hour, linestil, wait, wish, u...
# 2  [hdfcbankcar, atm, machin, time, india, noida,...
# 3  [icicibank, thank, icici, bank, got, case, atm...
# 4  [rbi, assam, bank, exchang, exchang, yesterday...
#
#                             Tweet_lemmatized_stemmed
# 0  [axisbanksupport, perman, busi, amp, cannot, g...
# 1  [theofficialsbi, hour, linestil, wait, wish, u...
# 2  [hdfcbankcar, atm, machin, time, india, noida,...
# 3  [icicibank, thank, icici, bank, got, case, atm...
# 4  [rbi, assam, bank, exchang, exchang, yesterday...

# %%
data=df[['tweet','Tweet_str','Tweet_stemmed','sentiment','bank']]

# %%
from sklearn.preprocessing import LabelEncoder 
from sklearn.preprocessing import OneHotEncoder
le = LabelEncoder() 
data['sentiment']= le.fit_transform(data['sentiment'])

# creating instance of one-hot-encoder
enc = OneHotEncoder(handle_unknown='ignore')
# passing bridge-types-cat column (label encoded values of bridge_types)
enc_df = pd.DataFrame(enc.fit_transform(data[['sentiment']]).toarray())
# merge with main df bridge_df on key values
data = data.join(enc_df)
data
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#                                                   tweet  \
# 0     @AxisBankSupport 18..233.... is permanently bu...
# 1     @TheOfficialSBI 3 hours in line,still waiting....
# 2     @HDFCBank_Cares Both the ATM machines here in ...
# 3     @ICICIBank Thanks icici bank I got case in you...
# 4     @RBI In Assam all banks are exchanging 4000/- ...
# ...                                                 ...
# 5688  @HDFCBank_Cares over 25 calls this week.I gues...
# 5689  @ICICIBank_Care e-Pay slip as system not worki...
# 5690  @TheOfficialSBI staff at Sbi Akaltara branch C...
# 5691  @singhraviranja4 @AxisBankSupport Hi, sorry fo...
# 5692  @TheOfficialSBI @RBI @FinMinIndia an aged man ...
#
#                                               Tweet_str  \
# 0     axisbanksupport  is permanently busy  amp  can...
# 1     theofficialsbi  hours in linestill waiting wis...
# 2     hdfcbankcares both the atm machines here in ti...
# 3     icicibank thanks icici bank i got case in your...
# 4     rbi in assam all banks are exchanging  once on...
# ...                                                 ...
# 5688  hdfcbankcares over  calls this weeki guess ull...
# 5689  icicibankcare epay slip as system not working ...
# 5690  theofficialsbi staff at sbi akaltara branch ch...
# 5691  singhraviranja axisbanksupport hi sorry for th...
# 5692  theofficialsbi rbi finminindia an aged man  th...
#
#                                           Tweet_stemmed  sentiment  \
# 0     [axisbanksupport, perman, busi, amp, cannot, g...          1
# 1     [theofficialsbi, hour, linestil, wait, wish, u...          1
# 2     [hdfcbankcar, atm, machin, time, india, noida,...          1
# 3     [icicibank, thank, icici, bank, got, case, atm...          2
# 4     [rbi, assam, bank, exchang, exchang, yesterday...          1
# ...                                                 ...        ...
# 5688  [hdfcbankcar, call, weeki, guess, ull, dont, t...          1
# 5689  [icicibankcar, epay, slip, system, work, sec, ...          1
# 5690  [theofficialsbi, staff, sbi, akaltara, branch,...          2
# 5691  [singhraviranja, axisbanksupport, hi, sorri, t...          2
# 5692  [theofficialsbi, rbi, finminindia, age, man, t...          1
#
#                       bank    0    1    2
# 0                   [axis]  0.0  1.0  0.0
# 1                    [sbi]  0.0  1.0  0.0
# 2                   [hdfc]  0.0  1.0  0.0
# 3      [icici, icici, sbi]  0.0  0.0  1.0
# 4                    [sbi]  0.0  1.0  0.0
# ...                    ...  ...  ...  ...
# 5688                [hdfc]  0.0  1.0  0.0
# 5689               [icici]  0.0  1.0  0.0
# 5690            [sbi, sbi]  0.0  0.0  1.0
# 5691                [axis]  0.0  0.0  1.0
# 5692  [sbi, sbi, sbi, sbi]  0.0  1.0  0.0
#
# [5693 rows x 8 columns]

# %%
hdfc=data[data.apply(lambda x: 'hdfc' in x['bank'],axis=1)]
axis=data[data.apply(lambda x: 'axis' in x['bank'],axis=1)]
sbi=data[data.apply(lambda x: 'sbi' in x['bank'],axis=1)]
kotak=data[data.apply(lambda x: 'kotak' in x['bank'],axis=1)]
icici=data[data.apply(lambda x: 'icici' in x['bank'],axis=1)]

# %%
hdfc_test =hdfc.iloc[0:500]
hdfc_train=hdfc.iloc[500:]
axis_test =axis.iloc[0:500]
axis_train=axis.iloc[500:]
sbi_test =sbi.iloc[0:500]
sbi_train=sbi.iloc[500:]
kotak_test =kotak.iloc[0:500]
kotak_train=kotak.iloc[500:]
icici_test =icici.iloc[0:500]
icici_train=icici.iloc[500:]

# %%
train_data = pd.concat([hdfc_train,axis_train,sbi_train,kotak_train,icici_train])
test_data=pd.concat([hdfc_test,axis_test,sbi_test,kotak_test,icici_test])

# %%
from sklearn.model_selection import train_test_split
tr=train_data[['Tweet_str','Tweet_stemmed','sentiment']]
tr.rename(columns = {'Tweet_stemmed':'tokens'}, inplace = True)
# Out:
# C:\Users\KIRHIKAGURUMURTHY\anaconda3\lib\site-packages\pandas\core\frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
all_training_words = [word for tokens in tr["tokens"] for word in tokens]
training_sentence_lengths = [len(tokens) for tokens in tr["tokens"]]
TRAINING_VOCAB = sorted(list(set(all_training_words)))
print("%s words total, with a vocabulary size of %s" % (len(all_training_words), len(TRAINING_VOCAB)))
print("Max sentence length is %s" % max(training_sentence_lengths))
# Out:
# 39529 words total, with a vocabulary size of 6104
# Max sentence length is 22

# %%
# Out:
# 3884words total, with a vocabulary size of 1404
# Max sentence length is 21

# %%
from gensim.models import KeyedVectors
from gensim.models import Word2Vec
word2vec_path = 'Word2vec_lexical.model'
word2vec = KeyedVectors.load(word2vec_path)

# %%
from keras.callbacks import ModelCheckpoint
from keras.layers import Dense, Dropout, Reshape, Flatten, concatenate, Input, Conv1D, GlobalMaxPooling1D, Embedding
from keras.layers.recurrent import LSTM,GRU
from keras.models import Sequential
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Model
tokenizer = Tokenizer(num_words=len(TRAINING_VOCAB), lower=True, char_level=False)
tokenizer.fit_on_texts(tr["Tweet_str"].tolist())
training_sequences = tokenizer.texts_to_sequences(tr["Tweet_str"].tolist())
train_word_index = tokenizer.word_index
print("Found %s unique tokens." % len(train_word_index))
train_cnn_data = pad_sequences(training_sequences, maxlen=50)
train_cnn_data
# Out:
# Using TensorFlow backend.
# C:\Users\KIRHIKAGURUMURTHY\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\KIRHIKAGURUMURTHY\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\KIRHIKAGURUMURTHY\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\KIRHIKAGURUMURTHY\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\KIRHIKAGURUMURTHY\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\KIRHIKAGURUMURTHY\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Found 7322 unique tokens.
# array([[   0,    0,    0, ..., 2050, 2051, 3208],
#        [   0,    0,    0, ...,    6,   25,  179],
#        [   0,    0,    0, ...,  531,  167,   84],
#        ...,
#        [   0,    0,    0, ...,   62,   64,   62],
#        [   0,    0,    0, ...,    6,  523,   11],
#        [   0,    0,    0, ...,  376,    4,  297]])

# %%
train_embedding_weights = np.zeros((len(train_word_index)+1, 
 100))
for word,index in train_word_index.items():
 train_embedding_weights[index,:] = word2vec[word] if word in word2vec else np.random.rand(100)
print(train_embedding_weights.shape)
# Out:
# (7323, 100)
# C:\Users\KIRHIKAGURUMURTHY\anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   after removing the cwd from sys.path.
# C:\Users\KIRHIKAGURUMURTHY\anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   after removing the cwd from sys.path.

# %%
embedding_vector_length = 100 
model = Sequential() 
model.add(Embedding(7323, embedding_vector_length, input_length=50)) 
model.add(LSTM(100)) 
model.add(Dense(3, activation='softmax')) 
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam', metrics=['accuracy']) 
print(model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 50, 100)           732300
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 100)               80400
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 303
# =================================================================
# Total params: 813,003
# Trainable params: 813,003
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
"""""model=Sequential()
embedding_layer=Embedding(7323,100,weights=[train_embedding_weights],input_length=50,trainable=False)
model.add(embedding_layer)
model.add(GRU(units=32,dropout=0.2,recurrent_dropout=0.2))
model.add(Dense(3,activation='softmax'))
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])"""

# %%
import numpy as np
VALIDATION_SPLIT=0.2

from keras.utils import to_categorical

indices=np.arange(train_cnn_data.shape[0])
np.random.shuffle(indices)
tweet_pad=train_cnn_data[indices]
sentiment=tr['sentiment'].values
sentiment=sentiment[indices]
num_validation_samples=int(VALIDATION_SPLIT * tweet_pad.shape[0])
X_train_pad=tweet_pad[:-num_validation_samples]
y_train=sentiment[:-num_validation_samples]
#y_train = to_categorical(y_train)
X_test_pad=tweet_pad[-num_validation_samples:]
y_test=sentiment[-num_validation_samples:]
#y_test= to_categorical(y_test)

# %%
# Out:
# Train on 2904 samples, validate on 323 samples
# Epoch 1/4
# 2904/2904 [==============================] - 10s 3ms/step - loss: 0.1286 - acc: 0.9556 - val_loss: 0.6128 - val_acc: 0.7709
# Epoch 2/4
# 2904/2904 [==============================] - 10s 4ms/step - loss: 0.0927 - acc: 0.9720 - val_loss: 0.6932 - val_acc: 0.7564
# Epoch 3/4
# 2904/2904 [==============================] - 10s 4ms/step - loss: 0.1194 - acc: 0.9540 - val_loss: 0.6925 - val_acc: 0.7585
# Epoch 4/4
# 2904/2904 [==============================] - 11s 4ms/step - loss: 0.1211 - acc: 0.9555 - val_loss: 0.6551 - val_acc: 0.7637

# %%
model.fit(X_train_pad,y_train,batch_size=128,epochs=25,validation_data=(X_test_pad,y_test),verbose=2)
# Out:
# WARNING:tensorflow:From C:\Users\KIRHIKAGURUMURTHY\anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 2869 samples, validate on 717 samples
# Epoch 1/25
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-efa0c746f5f2> in <module>
# ----> 1 model.fit(X_train_pad,y_train,batch_size=128,epochs=25,validation_data=(X_test_pad,y_test),verbose=2)
#
# ~\anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# ~\anaconda3\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     194                     ins_batch[i] = ins_batch[i].toarray()
#     195
# --> 196                 outs = fit_function(ins_batch)
#     197                 outs = to_list(outs)
#     198                 for l, o in zip(out_labels, outs):
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\backend.py in __call__(self, inputs)
#    3059         tensor_type = dtypes_module.as_dtype(tensor.dtype)
#    3060         array_vals.append(np.asarray(value,
# -> 3061                                      dtype=tensor_type.as_numpy_dtype))
#    3062
#    3063     if self.feed_dict:
#
# ~\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ValueError: could not convert string to float: 'displeasure'

# %%
#hdfc_score=hdfc_test['Tweet_str']
all_training_words_bank = [word for tokens in test_data["Tweet_stemmed"] for word in tokens]
training_sentence_lengths_bank = [len(tokens) for tokens in test_data["Tweet_stemmed"]]
TRAINING_VOCAB_bank = sorted(list(set(all_training_words_bank)))
tokenizer_bank = Tokenizer(num_words=len(TRAINING_VOCAB_bank), lower=True, char_level=False)
tokenizer_bank.fit_on_texts(test_data["Tweet_str"].tolist())
training_sequences_bank = tokenizer_bank.texts_to_sequences(test_data["Tweet_str"].tolist())
train_word_index_bank = tokenizer_bank.word_index
train_cnn_data_bank = pad_sequences(training_sequences_bank, maxlen=50)
train_cnn_data_bank
pred=model.predict(train_cnn_data_bank)
pred.tolist()
# Out:
# [[0.33920812606811523, 0.33120375871658325, 0.3295881152153015],
#  [0.3331601321697235, 0.3327196538448334, 0.33412015438079834],
#  [0.33361873030662537, 0.33035969734191895, 0.3360215723514557],
#  [0.3300507366657257, 0.3343450427055359, 0.3356042206287384],
#  [0.33302485942840576, 0.3334078788757324, 0.3335673213005066],
#  [0.33828869462013245, 0.33263570070266724, 0.3290756642818451],
#  [0.33001208305358887, 0.33653631806373596, 0.33345159888267517],
#  [0.3362334072589874, 0.3300359845161438, 0.3337306082248688],
#  [0.33003681898117065, 0.33527836203575134, 0.3346847891807556],
#  [0.3321283459663391, 0.3352963924407959, 0.332575261592865],
#  [0.33435893058776855, 0.33319833874702454, 0.3324427306652069],
#  [0.3365986943244934, 0.3300776779651642, 0.3333236873149872],
#  [0.3352299928665161, 0.3339290916919708, 0.33084094524383545],
#  [0.33649322390556335, 0.3319080173969269, 0.3315987288951874],
#  [0.33166077733039856, 0.3331117630004883, 0.33522745966911316],
#  [0.33534446358680725, 0.33268222212791443, 0.3319733440876007],
#  ...]

# %%
#predictions
maxindex=np.argmax(pred,axis=1)
maxindex
pred_sent=maxindex.tolist()
bank_pred=test_data[['Tweet_str']]
bank_pred=bank_pred.reset_index()
del bank_pred['index']
#f_pred=pd.DataFrame(df_pred)
#dfc_pred['sentiment_pred']=df_pred
#dfc_pred""""""
bank_pred['sentiment_score']=pred_sent
bank_pred
#fc_pred['sentiment_pred']=df_pred
#dfc_pred
#dfc_pred.loc[hdfc_pred.sentiment_pred==1,'sentiment_pred']='displeasure'
#dfc_pred.loc[hdfc_pred.sentiment_pred==0,'sentiment_pred']='miscellaneous'
#dfc_pred.loc[hdfc_pred.sentiment_pred==2,'sentiment_pred']='compliment'
#dfc_pred
# Out:
#                                               Tweet_str  sentiment_score
# 0     hdfcbankcares both the atm machines here in ti...                0
# 1     hdfcbank hdfcbankcares received an email sayin...                2
# 2     hdfcbankcares the atm at sector charkop kandiv...                2
# 3     icicibankcare hdfcbankcares axisbank nomoney i...                2
# 4     rt tarun thanks to hdfcbank hdfcbankcares mgmt...                2
# ...                                                 ...              ...
# 2495       icicibankcare thanks atms were working today                0
# 2496  icicibankcare your patna zonal office car loan...                0
# 2497  unfortunately  in queue do not need cash hdfcb...                2
# 2498  icicibankcare chandakochar icicibank dahisar w...                0
# 2499  icicibankcare in kphb area all atms are closed...                0
#
# [2500 rows x 2 columns]

# %%
hdfc_sent_score_df=bank_pred.iloc[0:500,1]
hdfc_sent_score=hdfc_sent_score_df.sum()
print("HDFC Performance index score is :",hdfc_sent_score)
# Out:
# HDFC Performance index score is : 413

# %%
axis_sent_score_df=bank_pred.iloc[500:1000,1]
axis_sent_score=axis_sent_score_df.sum()
print("AXIS Performance index score is :",axis_sent_score)
# Out:
# AXIS Performance index score is : 388

# %%
sbi_sent_score_df=bank_pred.iloc[1000:1500,1]
sbi_sent_score=sbi_sent_score_df.sum()
print("SBI Performance index score is :",sbi_sent_score)
# Out:
# SBI Performance index score is : 398

# %%
kotak_sent_score_df=bank_pred.iloc[1500:2000,1]
kotak_sent_score=kotak_sent_score_df.sum()
print("HDFC Performance index score is :",kotak_sent_score)
# Out:
# HDFC Performance index score is : 403

# %%
icici_sent_score_df=bank_pred.iloc[2000:2500,1]
icici_sent_score=icici_sent_score_df.sum()
print("ICICI Performance index score is :",icici_sent_score)
# Out:
# ICICI Performance index score is : 415

# %%
import pickle
save_classifier = open("DL2.pickle","wb")
pickle.dump(model, save_classifier)
save_classifier.close() #saving the classifier

# %%
classifier_f = open("DL2.pickle", "rb") #loading the saved classifier
classifier = pickle.load(classifier_f)
classifier_f.close()

# %%
# Out:
# 2500/2500 [==============================] - 1s 315us/step
# [3.757430519104004, 0.3968000113964081]

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-181-8bff9f764587> in <module>
#       1 indices_test=np.arange(train_cnn_data_bank.shape[0])
# ----> 2 tweet_pad_held=train_cnn_data_bank[indices]
#       3 sentiment=test_data['sentiment'].values
#       4 sentiment=sentiment[indices]
#
# IndexError: index 2991 is out of bounds for axis 0 with size 2500
