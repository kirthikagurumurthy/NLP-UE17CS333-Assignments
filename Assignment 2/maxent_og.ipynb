# %%
import numpy as np 
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.classify import SklearnClassifier
from wordcloud import WordCloud,STOPWORDS
import matplotlib.pyplot as plt
import string
import re
from collections import Counter
from nltk.stem import WordNetLemmatizer
import pickle

# %%
df = pd.read_csv('FinalTweetList.csv')
df.columns=['tweet','sentiment','bank']
stopword = nltk.corpus.stopwords.words('english')
ps = nltk.PorterStemmer()
wn = nltk.WordNetLemmatizer()

# %%
#find all banks - first list out all words beginning with @
def find(text):
    list = re.findall("[@]\w+", text)
    return list
df['@'] = (df['tweet']).apply(lambda x: find(x))
df.head()
# Out:
#                                                tweet      sentiment bank  \
# 0  @AxisBankSupport 18..233.... is permanently bu...    displeasure  NaN
# 1  @TheOfficialSBI 3 hours in line,still waiting....    displeasure  NaN
# 2  @HDFCBank_Cares Both the ATM machines here in ...    displeasure  NaN
# 3  @ICICIBank Thanks icici bank I got case in you...  miscellaneous  NaN
# 4  @RBI In Assam all banks are exchanging 4000/- ...    displeasure  NaN
#
#                                @
# 0             [@AxisBankSupport]
# 1              [@TheOfficialSBI]
# 2     [@HDFCBank_Cares, @sanatm]
# 3  [@ICICIBank, @TheOfficialSBI]
# 4        [@RBI, @TheOfficialSBI]

# %%
#find frequency of words beginning with @
#As we need testing data of 500 values we will only take the banks specified in more than 500 rows in the datset - upon analysing we see that 
#these are - SBI,Axis,HDFC,Kotak and ICICI
lis=df['@'].to_list()
flat = [y for x in lis for y in x]
count = Counter(flat)
count.most_common()
# Out:
# [('@TheOfficialSBI', 2468),
#  ('@HDFCBank_Cares', 928),
#  ('@ICICIBank_Care', 893),
#  ('@KotakBankLtd', 691),
#  ('@AxisBankSupport', 562),
#  ('@RBI', 481),
#  ('@ICICIBank', 448),
#  ('@HDFC_Bank', 364),
#  ('@arunjaitley', 315),
#  ('@narendramodi', 312),
#  ('@bankofbaroda', 268),
#  ('@AxisBank', 262),
#  ('@PMOIndia', 248),
#  ('@FinMinIndia', 144),
#  ('@udaykotak', 82),
#  ('@abndnkmtr', 41),
#  ('@YESBANK', 36),
#  ('@mdpnb', 27),
#  ('@SBICard_Connect', 24),
#  ('@ndtv', 23),
#  ('@IDBI_Bank', 22),
#  ('@BJP4India', 20),
#  ('@TimesNow', 19),
#  ('@DasShaktikanta', 19),
#  ('@mediacrooks', 18),
#  ('@suchetadalal', 17),
#  ('@chandakochhar', 16),
#  ('@aajtak', 16),
#  ('@htTweets', 15),
#  ('@timesofindia', 14),
#  ('@ZeeNews', 14),
#  ('@HDFCBankNews', 13),
#  ('@ArvindKejriwal', 13),
#  ('@CKforCleanIndia', 13),
#  ('@theofficialsbi', 13),
#  ('@neha_aks', 13),
#  ('@CNBCTV18Live', 13),
#  ('@MyIndusIndBank', 12),
#  ('@karishmakotak', 12),
#  ('@OfficeOfRG', 12),
#  ('@sudhirchaudhary', 11),
#  ('@arjunrammeghwal', 11),
#  ('@INCIndia', 11),
#  ('@ANI_news', 11),
#  ('@DelhiPolice', 10),
#  ('@sbi', 10),
#  ('@Bankofindia_BOI', 10),
#  ('@CMofKarnataka', 10),
#  ('@rsprasad', 10),
#  ('@narendramodi_in', 10),
#  ('@gmail', 10),
#  ('@sankrant', 10),
#  ('@Citi', 9),
#  ('@HDFCLIFE', 9),
#  ('@ETNOWlive', 9),
#  ('@adhia03', 9),
#  ('@Indiapnb', 9),
#  ('@vikramwkarve', 8),
#  ('@SushmaSwaraj', 8),
#  ('@abpnewstv', 8),
#  ('@centerofright', 8),
#  ('@PIB_India', 8),
#  ('@UrjitPatelRBI', 8),
#  ('@NewsX', 8),
#  ('@TajinderBagga', 8),
#  ('@ZeeNewsHindi', 8),
#  ('@UfterYou', 8),
#  ('@StanChart', 7),
#  ('@CMOMaharashtra', 7),
#  ('@Paytm', 7),
#  ('@rbi', 7),
#  ('@VijayaBankIndia', 7),
#  ('@PawanDurani', 7),
#  ('@anuyeaah', 6),
#  ('@the_hindu', 6),
#  ('@bainjal', 6),
#  ('@BlueDartTweets', 6),
#  ('@RashtrapatiBhvn', 6),
#  ('@TOIIndiaNews', 6),
#  ('@arjuna04', 6),
#  ('@CVCIndia', 6),
#  ('@Norafatehi', 6),
#  ('@Swamy39', 6),
#  ('@axisbank', 6),
#  ('@anandmahindra', 6),
#  ('@canarabanktweet', 6),
#  ('@CTRavi_BJP', 6),
#  ('@ranjank63', 6),
#  ('@BankofBarodaCEO', 6),
#  ('@Baalkeeg', 6),
#  ('@manakgupta', 6),
#  ('@Chhabiy', 5),
#  ('@sowmyarao_', 5),
#  ('@Citibank', 5),
#  ('@TVMohandasPai', 5),
#  ('@EconomicTimes', 5),
#  ('@pandabythebay', 5),
#  ('@hdfcbank', 5),
#  ('@Finelychopped', 5),
#  ('@PiyushGoyal', 5),
#  ('@CorpBanking', 5),
#  ('@VictoryForNamo', 5),
#  ('@fayedsouza', 5),
#  ('@anilkapur_', 5),
#  ('@VodafoneIN', 5),
#  ('@RBI_India', 5),
#  ('@bsindia', 4),
#  ('@monstermanojit', 4),
#  ('@ConXerv', 4),
#  ('@jayantsinha', 4),
#  ('@IndiaPostOffice', 4),
#  ('@Dev_Fadnavis', 4),
#  ('@BTVI', 4),
#  ('@RadhikaBudhwar', 4),
#  ('@Susmita05787706', 4),
#  ('@ankitnair086', 4),
#  ('@BlrCityPolice', 4),
#  ('@IndianExpress', 4),
#  ('@neerjanni2000', 4),
#  ('@RubikaLiyaquat', 4),
#  ('@AboutIndia', 4),
#  ('@manichejain', 4),
#  ('@CNBC', 4),
#  ('@semubhatt', 4),
#  ('@shilpysinhaET', 4),
#  ('@indiantweeter', 4),
#  ('@vinodkapri', 4),
#  ('@priyank_ks', 4),
#  ('@YouTube', 4),
#  ('@smritimoy', 4),
#  ('@rajnathsingh', 4),
#  ('@AmitShah', 4),
#  ('@manoharparrikar', 4),
#  ('@sanjaynirupam', 4),
#  ('@aakuraj', 4),
#  ('@IndiaToday', 4),
#  ('@monikahalan', 4),
#  ('@MEAIndia', 4),
#  ('@rahulkanwal', 4),
#  ('@bantasavrait', 4),
#  ('@CybercrimeCID', 3),
#  ('@UnionBankTweets', 3),
#  ('@spsurana', 3),
#  ('@centralbank_in', 3),
#  ('@HMOIndia', 3),
#  ('@rajatguleria9', 3),
#  ('@UPI_NPCI', 3),
#  ('@loosebool', 3),
#  ('@OrientalBank', 3),
#  ('@PrashantBarot1', 3),
#  ('@panchali_', 3),
#  ('@shiladitya', 3),
#  ('@rtripathi6', 3),
#  ('@GulPanag', 3),
#  ('@IncomeTaxIndia', 3),
#  ('@Su52k', 3),
#  ('@farahzai', 3),
#  ('@babita_kar', 3),
#  ('@GappistanRadio', 3),
#  ('@raj142004', 3),
#  ('@UCOBankCare', 3),
#  ('@guwahaticity', 3),
#  ('@aajtaknews', 3),
#  ('@AmanKayamHai_ET', 3),
#  ('@Breathedreamgo', 3),
#  ('@dixitsatish5', 3),
#  ('@theVtheM', 3),
#  ('@NagpalManoj', 3),
#  ('@bharathb1000', 3),
#  ('@NeerajHDFCBank', 3),
#  ('@ICICIPruLife', 3),
#  ('@sbbj_bank', 3),
#  ('@nildeore', 3),
#  ('@b50', 3),
#  ('@srirambjp', 3),
#  ('@kavyashree_p819', 3),
#  ('@Indemb_Muscat', 3),
#  ('@Lalit__Yadav', 3),
#  ('@sarbanandsonwal', 3),
#  ('@SahilBulla', 3),
#  ('@idea_cares', 3),
#  ('@BigBazaar', 3),
#  ('@alok_bhatt', 3),
#  ('@a_r_j_u_n', 3),
#  ('@Upsunson', 3),
#  ('@NashikNews', 3),
#  ('@ETBrandEquity', 3),
#  ('@FederalBankLtd', 3),
#  ('@sujeetmishra', 3),
#  ('@ConsumerReports', 3),
#  ('@muglikar_', 3),
#  ('@im_nindak', 3),
#  ('@goyalsanjeev', 3),
#  ('@ICICI_Direct', 3),
#  ('@Sootradhar', 3),
#  ('@nice', 3),
#  ('@axisbanksupport', 3),
#  ('@BankingOmbud', 3),
#  ('@KotakJifi', 3),
#  ('@powaiinfo', 2),
#  ('@sunil_malpotra', 2),
#  ('@madhu_sahoo', 2),
#  ('@princesurana', 2),
#  ('@WorldBank', 2),
#  ('@paytm', 2),
#  ('@imTejasBarot', 2),
#  ('@KotakbankLtd', 2),
#  ('@Cybercellindia', 2),
#  ('@TheHindu', 2),
#  ('@icicibank', 2),
#  ('@DCBBank', 2),
#  ('@MaccharManJr', 2),
#  ('@manishkinhikar', 2),
#  ('@imeerage', 2),
#  ('@ksmkkbookscom', 2),
#  ('@saurabh_chande', 2),
#  ('@KARMENDRAKUMAR', 2),
#  ('@sidgsh1', 2),
#  ('@NewIndianXpress', 2),
#  ('@sona2905', 2),
#  ('@ndtvindia', 2),
#  ('@HDFCBANK_Cares', 2),
#  ('@abpanandatv', 2),
#  ('@Raminations', 2),
#  ('@IDFC_Bank', 2),
#  ('@DG_PIB', 2),
#  ('@BJP4Delhi', 2),
#  ('@UN', 2),
#  ('@royabhijit71', 2),
#  ('@ranganaathan', 2),
#  ('@asraghunath', 2),
#  ('@chetanjkabra', 2),
#  ('@KishoreKar', 2),
#  ('@aiims_newdelhi', 2),
#  ('@MoHFW_INDIA', 2),
#  ('@unionbankofIN', 2),
#  ('@Indianoverseasb', 2),
#  ('@RahulMalkaunsh', 2),
#  ('@vdynthn', 2),
#  ('@genirajeev', 2),
#  ('@7am', 2),
#  ('@Shaas14', 2),
#  ('@vinodunny', 2),
#  ('@saikanomie', 2),
#  ('@JDforall', 2),
#  ('@RBIgovernor', 2),
#  ('@RShivshankar', 2),
#  ('@kai52vai', 2),
#  ('@munshi_jee', 2),
#  ('@nitintp', 2),
#  ('@PLEKarnataka', 2),
#  ('@adgpi', 2),
#  ('@livemint', 2),
#  ('@kashif_ahmedk', 2),
#  ('@kotaksync', 2),
#  ('@Vidyadarc', 2),
#  ('@pateriya_kapil', 2),
#  ('@yadavakhilesh', 2),
#  ('@bhatnaturally', 2),
#  ('@ArjunVagale', 2),
#  ('@Outlookindia', 2),
#  ('@6', 2),
#  ('@SIRBLOFELD', 2),
#  ('@ashkronos', 2),
#  ('@uddhavthackeray', 2),
#  ('@rockingramola', 2),
#  ('@BJP4Bengal', 2),
#  ('@pbhushan1', 2),
#  ('@SrikantKumarGh1', 2),
#  ('@moneycontrolcom', 2),
#  ('@WithCongress', 2),
#  ('@journalistreyaz', 2),
#  ('@RISHIKUMSAGAR', 2),
#  ('@BuddySolar', 2),
#  ('@hdfcbank_cares', 2),
#  ('@airtelindia', 2),
#  ('@sutirtharoy', 2),
#  ('@delhi_lawyer', 2),
#  ('@ParinSays', 2),
#  ('@nawinraja', 2),
#  ('@IamNAVED', 2),
#  ('@thej', 2),
#  ('@Vivekchandan', 2),
#  ('@nistula', 2),
#  ('@HomeLoansByHDFC', 2),
#  ('@DIFC', 2),
#  ('@brakoo', 2),
#  ('@AskAnshul', 2),
#  ('@singhvarun', 2),
#  ('@Dev2Girish', 2),
#  ('@anuragkumarlko', 2),
#  ('@MumbaiPolice', 2),
#  ('@RelianceMobile', 2),
#  ('@raja_sen', 2),
#  ('@YuvaSambalpur', 2),
#  ('@commoner_lawyer', 2),
#  ('@TRAI', 2),
#  ('@bihar_police', 2),
#  ('@ayush_dzire', 2),
#  ('@theofficialSBI', 2),
#  ('@321ynnus', 2),
#  ('@MobiKwik', 2),
#  ('@rajanvichare', 2),
#  ('@indianbanksorg', 2),
#  ('@indianbankers', 2),
#  ('@indianbanks', 2),
#  ('@vikasbha', 2),
#  ('@ICICIBANK', 2),
#  ('@iamChetanSinha', 2),
#  ('@gujjugabbar', 2),
#  ('@ajantriks', 2),
#  ('@CitibankIN', 2),
#  ('@ls2008', 2),
#  ('@AxisBankOffers', 2),
#  ('@heeraman98', 2),
#  ('@sushilizzat', 2),
#  ('@varunkrish', 2),
#  ('@icicibank_care', 2),
#  ('@rameem81', 2),
#  ('@AamAadmiParty', 2),
#  ('@_swaroop', 2),
#  ('@bomrochd', 2),
#  ('@VishweshwarBhat', 2),
#  ('@northern', 2),
#  ('@SimplyHimanshuR', 2),
#  ('@Sarthakviews', 2),
#  ('@javeeddgpup', 2),
#  ('@Uppolice', 2),
#  ('@dudeitsaalok', 2),
#  ('@abpnewshindi', 2),
#  ('@SuratPolice', 2),
#  ('@RajivMessage', 2),
#  ('@MVenkaiahNaidu', 2),
#  ('@sureshpprabhu', 2),
#  ('@strawsInTheWind', 2),
#  ('@ankushmn', 2),
#  ('@AAamireta', 2),
#  ('@drharshvardhan', 2),
#  ('@Jha__Pooja', 2),
#  ('@SBIBanks', 2),
#  ('@devangdream', 2),
#  ('@manojsinhabjp', 2),
#  ('@MrCollarOutfits', 2),
#  ('@CMMadhyaPradesh', 2),
#  ('@sanjoyb17', 2),
#  ('@iSushilPandey', 2),
#  ('@PBidasar', 2),
#  ('@agarwal_malvika', 2),
#  ('@klalgurnani', 2),
#  ('@ANINewsUP', 2),
#  ('@GauravSingal', 2),
#  ('@giveawayvimax', 2),
#  ('@rajeshkalra', 2),
#  ('@RajeshTamret', 2),
#  ('@ArunbajpaiRajan', 2),
#  ('@sachin_0707', 2),
#  ('@RajatSharmaLive', 2),
#  ('@Yadu4ever', 2),
#  ('@STATEBANK_CARES', 2),
#  ('@sec', 2),
#  ('@subrataiam', 2),
#  ('@allahabadbank4u', 2),
#  ('@waquaralamkhan', 2),
#  ('@ramachandra1047', 2),
#  ('@GACL', 2),
#  ('@Truth4win', 2),
#  ('@anilkohli54', 2),
#  ('@FreeChargeCares', 2),
#  ('@BBCWorld', 2),
#  ('@CNNnews18', 2),
#  ('@RatanSharda55', 2),
#  ('@PPSINGH5736', 2),
#  ('@Allahabad_Bank', 2),
#  ('@swachhbharat', 2),
#  ('@priyashmita', 2),
#  ('@RaviKrTomar', 2),
#  ('@RumanaNazarali', 2),
#  ('@divyanshuu', 2),
#  ('@paritosh2608', 2),
#  ('@ukyrem', 2),
#  ('@TCS', 2),
#  ('@DY365', 2),
#  ('@ankit1534', 2),
#  ('@StaffoAceFerns', 2),
#  ('@robinkansara', 2),
#  ('@AshishSBhardwaj', 2),
#  ('@OneindiaKannada', 2),
#  ('@mgnayak5', 2),
#  ('@pmoindia', 2),
#  ('@shwetajha_', 2),
#  ('@AcmatixJoshi', 2),
#  ('@nsitharaman', 2),
#  ('@sanatm', 1),
#  ('@ajitsinghs', 1),
#  ('@Pankushjindal', 1),
#  ('@saket71', 1),
#  ('@Shehla_Rashid', 1),
#  ('@tejujoshi31', 1),
#  ('@Tarun260', 1),
#  ('@Aryanwarlord', 1),
#  ('@kapadwanj', 1),
#  ('@MindSphere_IN', 1),
#  ('@AmhiDombivlikar', 1),
#  ('@DnsBank', 1),
#  ('@vineetjaintimes', 1),
#  ('@axisbank275', 1),
#  ('@EnggJourno', 1),
#  ('@indian8money', 1),
#  ('@n', 1),
#  ('@peekayteee', 1),
#  ('@alhaz_sidhva', 1),
#  ('@imVkohli', 1),
#  ('@AskCiti', 1),
#  ('@Kashmir_Monitor', 1),
#  ('@parikshitkmr', 1),
#  ('@thehindubiz', 1),
#  ('@DipakKhuthia', 1),
#  ('@naren', 1),
#  ('@faizanshaikh4u', 1),
#  ('@Khoslarajat10', 1),
#  ('@rituraj_prht', 1),
#  ('@ArunArungupta05', 1),
#  ('@Sn3haAgrawal', 1),
#  ('@narendramodisbi', 1),
#  ('@Max_Gupta', 1),
#  ('@pandeypankaj20', 1),
#  ('@Jinaymodi', 1),
#  ('@ikhan0784', 1),
#  ('@lagerfortwo', 1),
#  ('@SMahankali', 1),
#  ('@tejinderbagga', 1),
#  ('@mildwave', 1),
#  ('@romanaisarkhan', 1),
#  ('@c0nvey', 1),
#  ('@rokade_rahul', 1),
#  ('@prernatutors', 1),
#  ('@ajavgal', 1),
#  ('@YeshwanthKini', 1),
#  ('@ETVMadhyaprades', 1),
#  ('@paavanshukla', 1),
#  ('@kiran_patniak', 1),
#  ('@ndtvindiaDeposit', 1),
#  ('@krunalhp', 1),
#  ('@KotakBankL', 1),
#  ('@AuthorNilesh', 1),
#  ('@akota', 1),
#  ('@SANDIPC08579182', 1),
#  ('@parthshah88', 1),
#  ('@Bangaloremirror', 1),
#  ('@HDFC', 1),
#  ('@RanjitsinhKase1', 1),
#  ('@shilpitewari', 1),
#  ('@hashPune', 1),
#  ('@karandeep1', 1),
#  ('@ashprak', 1),
#  ('@digibank', 1),
#  ('@sbicareers', 1),
#  ('@vishalgondal', 1),
#  ('@rajeevdubey', 1),
#  ('@ThereyouG', 1),
#  ('@WilliamVJacob', 1),
#  ('@sunilsharma161', 1),
#  ('@Uday846845', 1),
#  ('@Jiggy_wan21', 1),
#  ('@vish107', 1),
#  ('@ragunathwg', 1),
#  ('@dir_ed', 1),
#  ('@sangitamehtaET', 1),
#  ('@royab', 1),
#  ('@bhakat_m', 1),
#  ('@Bharat_Putra', 1),
#  ('@upadh', 1),
#  ('@iimudpr', 1),
#  ('@NewspointTv', 1),
#  ('@aniruddhg1', 1),
#  ('@kotakbankltd', 1),
#  ('@currentu', 1),
#  ('@TheVijayMallya', 1),
#  ('@jeremycorbyn', 1),
#  ('@EU', 1),
#  ('@MyLoveNamo', 1),
#  ('@arunjaitl', 1),
#  ('@20Sheenu', 1),
#  ('@theburugula', 1),
#  ('@UCOBANKHO', 1),
#  ('@Gaddadaari', 1),
#  ('@gautamsohoni', 1),
#  ('@dipunair', 1),
#  ('@andnkmtr', 1),
#  ('@ravihanda', 1),
#  ('@themucktalif', 1),
#  ('@rashmibansal', 1),
#  ('@naveenk_vin', 1),
#  ('@DrMahi89', 1),
#  ('@chennai', 1),
#  ('@masala_chaas', 1),
#  ('@pune', 1),
#  ('@littleyums', 1),
#  ('@sabbir_india', 1),
#  ('@gouravgv', 1),
#  ('@GenomicKarma', 1),
#  ('@write2kill', 1),
#  ('@ad9820', 1),
#  ('@CareSBI', 1),
#  ('@prasannasb1', 1),
#  ('@maktrixster', 1),
#  ('@HSBC', 1),
#  ('@chandanbeta1487', 1),
#  ('@sharanpoovanna', 1),
#  ('@mallik_muzammil', 1),
#  ('@patilbrij', 1),
#  ('@iamchetansinha', 1),
#  ('@sureshkpujari', 1),
#  ('@Singham_Bhavani', 1),
#  ('@realDonaldTrump', 1),
#  ('@HemantM78454623', 1),
#  ('@kmgnath', 1),
#  ('@sardanarohit', 1),
#  ('@nandita_zee', 1),
#  ('@anuraagmuskaan', 1),
#  ('@innocentlyloud', 1),
#  ('@nikhilaj', 1),
#  ('@vishalathink', 1),
#  ('@vijaygup', 1),
#  ('@ktkbankltd', 1),
#  ('@deepakmsharma1', 1),
#  ('@Efma_news', 1),
#  ('@orphean_warbler', 1),
#  ('@cash', 1),
#  ('@Shilpiisinghh', 1),
#  ('@sheetal_walia', 1),
#  ('@shaykhar', 1),
#  ('@CNN', 1),
#  ('@schmmuck', 1),
#  ('@thomson_v', 1),
#  ('@waseem0761', 1),
#  ('@IASassociation', 1),
#  ('@IPS_Association', 1),
#  ('@dhruvrastogi04', 1),
#  ('@15mohit', 1),
#  ('@RuchaPatkar', 1),
#  ('@mazhyasarkhime', 1),
#  ('@SURJAYAKKI', 1),
#  ('@BirsaDasgupta', 1),
#  ('@KameeniChhori', 1),
#  ('@advantej_', 1),
#  ('@sandipmangukiy4', 1),
#  ('@Daniel1235gd', 1),
#  ('@ankurmodi5491', 1),
#  ('@kunalkamra88', 1),
#  ('@s0ulbuzz', 1),
#  ('@SUBHASKUMAR', 1),
#  ('@LocalCircles', 1),
#  ('@Amit_sri1912', 1),
#  ('@kuntalpanja', 1),
#  ('@Rashtravadi007', 1),
#  ('@siddhan97108044', 1),
#  ('@colorsherlock', 1),
#  ('@CoffeePenCamera', 1),
#  ('@Manoj1108Manoj', 1),
#  ('@harpreetsubhi', 1),
#  ('@HDFCBank_Offers', 1),
#  ('@anksumads', 1),
#  ('@yashwecan', 1),
#  ('@PrabhuChawla', 1),
#  ('@gogarkrish', 1),
#  ('@BankMysore', 1),
#  ('@Mitalishah121', 1),
#  ('@1ab6b0199324490', 1),
#  ('@GauravGogoiAsm', 1),
#  ('@arwa_husain', 1),
#  ('@ajayiyer15', 1),
#  ('@missuniversedb', 1),
#  ('@UnifSpirit', 1),
#  ('@swetsarika', 1),
#  ('@jha_siddhus94', 1),
#  ('@i', 1),
#  ('@monsun14', 1),
#  ('@RajnishTuli', 1),
#  ('@AKohli03', 1),
#  ('@Adidev2394', 1),
#  ('@MyIndusIn', 1),
#  ('@sumeetgupta1971', 1),
#  ('@shabbarvhora', 1),
#  ('@chandankr', 1),
#  ('@AmitAryans1', 1),
#  ('@jntd11', 1),
#  ('@asheeshchawla', 1),
#  ('@new', 1),
#  ('@TrustingINDIA', 1),
#  ('@ShreeLaxmiArt', 1),
#  ('@sharalayanandan', 1),
#  ('@FarhanNadaf', 1),
#  ('@ishan_vipul', 1),
#  ('@ssnehra101015', 1),
#  ('@vardh4377', 1),
#  ('@kelekachilka', 1),
#  ('@scroll_in', 1),
#  ('@cakeaberry1', 1),
#  ('@chinmaytrivedi', 1),
#  ('@tallstories', 1),
#  ('@HSBC_IN', 1),
#  ('@kabandisaikia', 1),
#  ('@Why', 1),
#  ('@SMungantiwar', 1),
#  ('@Aryavarta_', 1),
#  ('@chuenchenliu', 1),
#  ('@TheRahulMehra', 1),
#  ('@VaidyaPriyam', 1),
#  ('@rajthakre', 1),
#  ('@AnupamPkher', 1),
#  ('@Paritos007', 1),
#  ('@lady_naarad', 1),
#  ('@_Murali', 1),
#  ('@palashgoorha', 1),
#  ('@jetairways', 1),
#  ('@abhay_runwal', 1),
#  ('@KetanDialani', 1),
#  ('@Ppanks_G', 1),
#  ('@Mayank1551984', 1),
#  ('@sadiqueanj', 1),
#  ('@rjraunac', 1),
#  ('@RajivranjanjJha', 1),
#  ('@sonal_31559', 1),
#  ('@vadapoche', 1),
#  ('@rajeshn22', 1),
#  ('@karan1407', 1),
#  ('@jgdaditya', 1),
#  ('@PrannoyRoyNDTV', 1),
#  ('@Vedmishra9', 1),
#  ('@Piyush26490275', 1),
#  ('@8527672044', 1),
#  ('@BeingReva', 1),
#  ('@nakulsaxena786', 1),
#  ('@MamataOfficial', 1),
#  ('@mvslsv', 1),
#  ('@ashirwadmittal', 1),
#  ('@hardik9900', 1),
#  ('@binodpks', 1),
#  ('@Reliance_MF', 1),
#  ('@hussainq11', 1),
#  ('@PrashantmET', 1),
#  ('@ADHVAYAM', 1),
#  ('@viralv1', 1),
#  ('@kittumaheshwari', 1),
#  ('@bibhasdn', 1),
#  ('@nawiedj', 1),
#  ('@Circle_India', 1),
#  ('@swamiram96', 1),
#  ('@sjsrathore', 1),
#  ('@banksyndicate', 1),
#  ('@sureshkkedia', 1),
#  ('@mid_day', 1),
#  ('@Only_Chirag', 1),
#  ('@Ssuujjaayy11', 1),
#  ('@Sachzzz', 1),
#  ('@IndianEmbassyUS', 1),
#  ('@naukarshah', 1),
#  ('@kiranruled', 1),
#  ('@travellerAmit', 1),
#  ('@DhruvSonagra', 1),
#  ('@akshaypandt', 1),
#  ('@ICICIBan', 1),
#  ('@linganikhil8', 1),
#  ('@uttara66', 1),
#  ('@drshraddha16', 1),
#  ('@dna', 1),
#  ('@jagograhakjago', 1),
#  ('@VikasDatta', 1),
#  ('@amazonIN', 1),
#  ('@me_indian', 1),
#  ('@indiatvnews', 1),
#  ('@HinduHangout', 1),
#  ('@sunandavashisht', 1),
#  ('@mantraventures', 1),
#  ('@gauravvkchawla', 1),
#  ('@rohansippy', 1),
#  ('@SaraswatBank', 1),
#  ('@SVC_Bank', 1),
#  ('@sajid70143', 1),
#  ('@VaibhavWrites', 1),
#  ('@AnupamSSaroj', 1),
#  ('@manjunathreddys', 1),
#  ('@pnb', 1),
#  ('@raveendrakumaar', 1),
#  ('@Imtiyaz46799784', 1),
#  ('@sagar13d', 1),
#  ('@tistathinks', 1),
#  ('@AxisDirect_In', 1),
#  ('@spbhattacharya', 1),
#  ('@reply', 1),
#  ('@mayankpratap773', 1),
#  ('@AxisBan', 1),
#  ('@TOIMumbai', 1),
#  ('@h_s1ngh', 1),
#  ('@h_boob1', 1),
#  ('@keshri_niraj', 1),
#  ('@kirantare', 1),
#  ('@mehralovey', 1),
#  ('@BadServiceNews', 1),
#  ('@srikanthgadgay', 1),
#  ('@abndrkmtr', 1),
#  ('@nthiru28', 1),
#  ('@therealakbarr', 1),
#  ('@samyagdrsti', 1),
#  ('@aniltewatia', 1),
#  ('@nigam_shishir', 1),
#  ('@MengiKuldip', 1),
#  ('@CNBCTV18News', 1),
#  ('@followme_ParagP', 1),
#  ('@nambiarmahesh', 1),
#  ('@naweliprachi', 1),
#  ('@Maharashtra1tv', 1),
#  ('@MahaPolice', 1),
#  ('@kznair', 1),
#  ('@saritanarang01', 1),
#  ('@SAnju_ShoorA', 1),
#  ('@Mayankshl47', 1),
#  ('@godfatherrohin', 1),
#  ('@hingane', 1),
#  ('@mrsfunnybones', 1),
#  ('@devduttmyth', 1),
#  ('@avirooksen', 1),
#  ('@ashwinsanghi', 1),
#  ('@agranpapilot3', 1),
#  ('@Soumitradas1991', 1),
#  ('@RBenjaminips1', 1),
#  ('@rushdiexplains', 1),
#  ('@KAMALsSUTRA', 1),
#  ('@RitaG74', 1),
#  ('@Umashankar35', 1),
#  ('@somnath1978', 1),
#  ('@venuvakeel', 1),
#  ('@I_yam_nendu', 1),
#  ('@ashokkmrsingh', 1),
#  ('@Praveenksh', 1),
#  ('@godavar', 1),
#  ('@abidbakshi', 1),
#  ('@paritoshchoubey', 1),
#  ('@dilshad', 1),
#  ('@aschauhan26', 1),
#  ('@periyakulam', 1),
#  ('@PNBMetlife1', 1),
#  ('@AmitVaani', 1),
#  ('@Rjkartik', 1),
#  ('@StinkiestBrain', 1),
#  ('@harshalkar', 1),
#  ('@tourismgoi', 1),
#  ('@PostOfficeIndia', 1),
#  ('@incredibleindia', 1),
#  ('@dr_maheshsharma', 1),
#  ('@my_rajasthan', 1),
#  ('@IMFNews', 1),
#  ('@Digamber', 1),
#  ('@ishq1010', 1),
#  ('@KaustubhRedkar', 1),
#  ('@skv_india', 1),
#  ('@financialombuds', 1),
#  ('@ipravinn', 1),
#  ('@thesandeepm', 1),
#  ('@pankajjha_', 1),
#  ('@vdube82', 1),
#  ('@anvil67978', 1),
#  ('@Write2Manmohan', 1),
#  ('@AskRaushan', 1),
#  ('@salonishuklaET', 1),
#  ('@kapsology', 1),
#  ('@gautam_adani', 1),
#  ('@bank_ofindia', 1),
#  ('@manjunath_mc', 1),
#  ('@kshitijladia', 1),
#  ('@shubh_pittu', 1),
#  ('@VocesNihili', 1),
#  ('@ETVUPLIVE', 1),
#  ('@SumitSsksh', 1),
#  ('@DrYash_Sonawane', 1),
#  ('@animesh1870', 1),
#  ('@adapaavi', 1),
#  ('@AnupamSaraph', 1),
#  ('@VenuSpeak', 1),
#  ('@Stupidosaur', 1),
#  ('@IndianOilcl', 1),
#  ('@JhaSanjay', 1),
#  ('@Bharat_Lohani', 1),
#  ('@ArvindKejriwalYou', 1),
#  ('@rajivanand', 1),
#  ('@NewshoundPoonam', 1),
#  ('@ajitkdubey', 1),
#  ('@macharajarao', 1),
#  ('@Eenadu_English', 1),
#  ('@Kr_Divyaprakash', 1),
#  ('@makemytripcare', 1),
#  ('@AmazonIN', 1),
#  ('@MVayeda', 1),
#  ('@sanjeetguru', 1),
#  ('@AndhraPradeshCM', 1),
#  ('@JaiTDP', 1),
#  ('@AvinashaSharma', 1),
#  ('@rabkabanda101', 1),
#  ('@dailyo_', 1),
#  ('@AKMODI11', 1),
#  ('@ashishcool1988', 1),
#  ('@prashantsriv1', 1),
#  ('@jitu_01324', 1),
#  ('@narendram', 1),
#  ('@helmetgirlbndra', 1),
#  ('@BlueDart_Help', 1),
#  ('@vinayprakash58', 1),
#  ('@Netra', 1),
#  ('@OmanObserver', 1),
#  ('@avinav2712', 1),
#  ('@ICICIPruMF', 1),
#  ('@iMac_too', 1),
#  ('@OhYesAsh4U', 1),
#  ('@ProAMTraider', 1),
#  ('@beingneerajrana', 1),
#  ('@amitaryans1', 1),
#  ('@kkumarkg', 1),
#  ('@ShamanOfJava', 1),
#  ('@niraj_mishra1', 1),
#  ('@DrKumarVishwas', 1),
#  ('@ersawankumar', 1),
#  ('@myasheen', 1),
#  ('@Mdsabedbhuyan', 1),
#  ('@ImMegafan', 1),
#  ('@poojamakhija', 1),
#  ('@sbiINTOUCH', 1),
#  ('@ArtofLiving', 1),
#  ('@snobfielder', 1),
#  ('@anshu_nitrkl', 1),
#  ('@thakkargopal', 1),
#  ('@nynmohanty', 1),
#  ('@21century_kant', 1),
#  ('@ranwijay', 1),
#  ('@The', 1),
#  ('@kalkihprashar', 1),
#  ('@NativeThoughts', 1),
#  ('@MRVChennai', 1),
#  ('@Geniustweeet', 1),
#  ('@kutchikamikaze', 1),
#  ('@Babluooo28312', 1),
#  ('@Embassy', 1),
#  ('@venkatchandu55', 1),
#  ('@PMO_India', 1),
#  ('@hariprasadholla', 1),
#  ('@vnbohra', 1),
#  ('@j0shiG', 1),
#  ('@Hina80819981', 1),
#  ('@Kavit4', 1),
#  ('@RKUMAR198011', 1),
#  ('@kuldeep_vermas', 1),
#  ('@afsanacutie', 1),
#  ('@nainitalbank', 1),
#  ('@Eaglesiar', 1),
#  ('@Ramesh673S', 1),
#  ('@AceofSpades_001', 1),
#  ('@kimchemicals', 1),
#  ('@mojorojo', 1),
#  ('@Bengaluruitebiz', 1),
#  ('@DeepXP', 1),
#  ('@anubhavdas', 1),
#  ('@AshTheWiz', 1),
#  ('@RCommCare', 1),
#  ('@rockykumar62', 1),
#  ('@gargpankaj2002', 1),
#  ('@PranavDate', 1),
#  ('@KannadaGrahaka', 1),
#  ('@narsingh_ptl', 1),
#  ('@TheOfficialSBi', 1),
#  ('@smriti_k17', 1),
#  ('@kottayimavoor', 1),
#  ('@AakashP72776330', 1),
#  ('@ICICIBank_Car', 1),
#  ('@MEmaaduddin', 1),
#  ('@haripra03373147', 1),
#  ('@diamondantoo', 1),
#  ('@TRA_Research', 1),
#  ('@Axi', 1),
#  ('@shreyishere', 1),
#  ('@GauravKPaul', 1),
#  ('@pshrivastava_tw', 1),
#  ('@99acresIndia', 1),
#  ('@CMOGuj', 1),
#  ('@calmchandan', 1),
#  ('@dhavalgandhi007', 1),
#  ('@BT_India', 1),
#  ('@iamniteshj', 1),
#  ('@AvnishAxis', 1),
#  ('@dilipkpandey', 1),
#  ('@sarikajohari', 1),
#  ('@GKanudawala', 1),
#  ('@makeperceptions', 1),
#  ('@MissFurioso', 1),
#  ('@Bankofbaroda', 1),
#  ('@Mimansa_Zee', 1),
#  ('@avasthiaditi', 1),
#  ('@prakjham', 1),
#  ('@TopGear534', 1),
#  ('@bankingombusman', 1),
#  ('@sanjaybaboo', 1),
#  ('@psinhajha', 1),
#  ('@finminindia', 1),
#  ('@SunilRGowda16', 1),
#  ('@IndiathinkOrg', 1),
#  ('@rishibagree', 1),
#  ('@Techtrail', 1),
#  ('@akanksharedhu', 1),
#  ('@11nov2016', 1),
#  ('@skyunleased', 1),
#  ('@Subhajit_K9472', 1),
#  ('@Vicky_291989', 1),
#  ('@AdvancedBharat', 1),
#  ('@ishu03', 1),
#  ('@zanbamn', 1),
#  ('@nilavachowdhury', 1),
#  ('@flyingvikas129', 1),
#  ('@llManishll', 1),
#  ('@Newalipore', 1),
#  ('@akhileshsharma1', 1),
#  ('@DrGPradhan', 1),
#  ('@ashishbadshah', 1),
#  ('@joy_dutta1', 1),
#  ('@AK_Bhosale', 1),
#  ('@sunshine_chat', 1),
#  ('@Jjo_Mojo', 1),
#  ('@SohoRoadBID', 1),
#  ('@NidhiChib', 1),
#  ('@KotakIndia', 1),
#  ('@chaitanya21688', 1),
#  ('@iswara1984', 1),
#  ('@Mahipalpur_branch', 1),
#  ('@arunishas', 1),
#  ('@ankit_abpnews', 1),
#  ('@_DigitalIndia', 1),
#  ('@imarun_11', 1),
#  ('@NPCI_NPCI', 1),
#  ('@nitin_sarohival', 1),
#  ('@vgiroti', 1),
#  ('@drsanjaysoni', 1),
#  ('@ashuvaani', 1),
#  ('@frittzeegirl', 1),
#  ('@Pratik_Bhartia', 1),
#  ('@debayanc3', 1),
#  ('@kaw_shivani', 1),
#  ('@ukkuru', 1),
#  ('@sandip_rail', 1),
#  ('@UttarandhraNow', 1),
#  ('@diparashar', 1),
#  ('@pmenviro', 1),
#  ('@PRATIMA_03', 1),
#  ('@DevelopedSurat', 1),
#  ('@PMOInd', 1),
#  ('@1', 1),
#  ('@Hungry_Old_Man', 1),
#  ('@RaviMohanSriva7', 1),
#  ('@vaibhav_vyas', 1),
#  ('@Gravim71', 1),
#  ('@SANDHUHARKIRAT', 1),
#  ('@ShahnawazBJP', 1),
#  ('@shuchi_modi', 1),
#  ('@bond_aj', 1),
#  ('@SureshGkumar88', 1),
#  ('@shaswatidas', 1),
#  ('@WreckdFx', 1),
#  ('@giddyja', 1),
#  ('@arunjait', 1),
#  ('@SurbhiJain03', 1),
#  ('@Nsel_Victim', 1),
#  ('@bimal_pr', 1),
#  ('@sbi_india', 1),
#  ('@Narendramodi_PM', 1),
#  ('@Vicky_Digitech', 1),
#  ('@join2tarun', 1),
#  ('@vikasdh', 1),
#  ('@ankurdpathak', 1),
#  ('@rajanbatra7765', 1),
#  ('@yesbank4', 1),
#  ('@Firki_', 1),
#  ('@kamessubbaraman', 1),
#  ('@RA', 1),
#  ('@harshaperla', 1),
#  ('@madhumachi', 1),
#  ('@onilaraj', 1),
#  ('@vikcse59', 1),
#  ('@KARUNASHANKEROJ', 1),
#  ('@Visa_IND', 1),
#  ('@andhrabank', 1),
#  ('@airvistara', 1),
#  ('@raju777_praveen', 1),
#  ('@gagkumar', 1),
#  ('@bishu57', 1),
#  ('@MePiyush', 1),
#  ('@ShantonilNag', 1),
#  ('@kaushkrahul', 1),
#  ('@AnilSha88355475', 1),
#  ('@fabcars', 1),
#  ('@AbheekHDFCBank', 1),
#  ('@ishantanujoshi', 1),
#  ('@socialepfo', 1),
#  ('@sejaljobanputra', 1),
#  ...]

# %%
#removing punctuation and converting to lower case
def rmvpuct_lower(text):
    text_lc = "".join([word.lower() for word in text if word not in string.punctuation]) # remove puntuation
    text_rc = re.sub('[0-9]+', '', text_lc)
    return text_rc

df['Tweet_str'] = df['tweet'].apply(lambda x:rmvpuct_lower(x))
df.head()
# Out:
#                                                tweet      sentiment bank  \
# 0  @AxisBankSupport 18..233.... is permanently bu...    displeasure  NaN
# 1  @TheOfficialSBI 3 hours in line,still waiting....    displeasure  NaN
# 2  @HDFCBank_Cares Both the ATM machines here in ...    displeasure  NaN
# 3  @ICICIBank Thanks icici bank I got case in you...  miscellaneous  NaN
# 4  @RBI In Assam all banks are exchanging 4000/- ...    displeasure  NaN
#
#                                @  \
# 0             [@AxisBankSupport]
# 1              [@TheOfficialSBI]
# 2     [@HDFCBank_Cares, @sanatm]
# 3  [@ICICIBank, @TheOfficialSBI]
# 4        [@RBI, @TheOfficialSBI]
#
#                                            Tweet_str
# 0  axisbanksupport  is permanently busy  amp  can...
# 1  theofficialsbi  hours in linestill waiting wis...
# 2  hdfcbankcares both the atm machines here in ti...
# 3  icicibank thanks icici bank i got case in your...
# 4  rbi in assam all banks are exchanging  once on...

# %%
#finding bank associated with each tweet
def find_bank(text):
    bnk=re.findall(r"hdfc|axis|sbi|icici|kotak",text)
    return bnk
df['bank'] = (df['Tweet_str']).apply(lambda x: find_bank(x))
df.head()
# Out:
#                                                tweet      sentiment  \
# 0  @AxisBankSupport 18..233.... is permanently bu...    displeasure
# 1  @TheOfficialSBI 3 hours in line,still waiting....    displeasure
# 2  @HDFCBank_Cares Both the ATM machines here in ...    displeasure
# 3  @ICICIBank Thanks icici bank I got case in you...  miscellaneous
# 4  @RBI In Assam all banks are exchanging 4000/- ...    displeasure
#
#                   bank                              @  \
# 0               [axis]             [@AxisBankSupport]
# 1                [sbi]              [@TheOfficialSBI]
# 2               [hdfc]     [@HDFCBank_Cares, @sanatm]
# 3  [icici, icici, sbi]  [@ICICIBank, @TheOfficialSBI]
# 4                [sbi]        [@RBI, @TheOfficialSBI]
#
#                                            Tweet_str
# 0  axisbanksupport  is permanently busy  amp  can...
# 1  theofficialsbi  hours in linestill waiting wis...
# 2  hdfcbankcares both the atm machines here in ti...
# 3  icicibank thanks icici bank i got case in your...
# 4  rbi in assam all banks are exchanging  once on...

# %%
def clean_text(text):
    text_lc = "".join([word.lower() for word in text if word not in string.punctuation]) # remove puntuation
    text_rc = re.sub('[0-9]+', '', text_lc)
    tokens = re.split('\W+', text_rc)    # tokenization
    text = [word for word in tokens if word not in stopword]  # remove stopwords and stemming
    return text
df['Tweet_cleaned'] = df['tweet'].apply(lambda x: clean_text(x))

# %%
def stemming(text):
    text = [ps.stem(word) for word in text]
    return text

df['Tweet_stemmed'] = df['Tweet_cleaned'].apply(lambda x: stemming(x))

def lemmatizer(text):
    text = [wn.lemmatize(word) for word in text]
    return text
df['Tweet_lemmatized_stemmed'] = df['Tweet_stemmed'].apply(lambda x: lemmatizer(x))
df.head()
# Out:
#                                                tweet      sentiment  \
# 0  @AxisBankSupport 18..233.... is permanently bu...    displeasure
# 1  @TheOfficialSBI 3 hours in line,still waiting....    displeasure
# 2  @HDFCBank_Cares Both the ATM machines here in ...    displeasure
# 3  @ICICIBank Thanks icici bank I got case in you...  miscellaneous
# 4  @RBI In Assam all banks are exchanging 4000/- ...    displeasure
#
#                   bank                              @  \
# 0               [axis]             [@AxisBankSupport]
# 1                [sbi]              [@TheOfficialSBI]
# 2               [hdfc]     [@HDFCBank_Cares, @sanatm]
# 3  [icici, icici, sbi]  [@ICICIBank, @TheOfficialSBI]
# 4                [sbi]        [@RBI, @TheOfficialSBI]
#
#                                            Tweet_str  \
# 0  axisbanksupport  is permanently busy  amp  can...
# 1  theofficialsbi  hours in linestill waiting wis...
# 2  hdfcbankcares both the atm machines here in ti...
# 3  icicibank thanks icici bank i got case in your...
# 4  rbi in assam all banks are exchanging  once on...
#
#                                        Tweet_cleaned  \
# 0  [axisbanksupport, permanently, busy, amp, cann...
# 1  [theofficialsbi, hours, linestill, waiting, wi...
# 2  [hdfcbankcares, atm, machines, times, india, n...
# 3  [icicibank, thanks, icici, bank, got, case, at...
# 4  [rbi, assam, banks, exchanging, exchanged, yes...
#
#                                        Tweet_stemmed  \
# 0  [axisbanksupport, perman, busi, amp, cannot, g...
# 1  [theofficialsbi, hour, linestil, wait, wish, u...
# 2  [hdfcbankcar, atm, machin, time, india, noida,...
# 3  [icicibank, thank, icici, bank, got, case, atm...
# 4  [rbi, assam, bank, exchang, exchang, yesterday...
#
#                             Tweet_lemmatized_stemmed
# 0  [axisbanksupport, perman, busi, amp, cannot, g...
# 1  [theofficialsbi, hour, linestil, wait, wish, u...
# 2  [hdfcbankcar, atm, machin, time, india, noida,...
# 3  [icicibank, thank, icici, bank, got, case, atm...
# 4  [rbi, assam, bank, exchang, exchang, yesterday...

# %%
hdfc=df[df.apply(lambda x: 'hdfc' in x['bank'],axis=1)]
axis=df[df.apply(lambda x: 'axis' in x['bank'],axis=1)]
sbi=df[df.apply(lambda x: 'sbi' in x['bank'],axis=1)]
kotak=df[df.apply(lambda x: 'kotak' in x['bank'],axis=1)]
icici=df[df.apply(lambda x: 'icici' in x['bank'],axis=1)]

# %%
hdfc_test =hdfc.iloc[0:500]
hdfc_train=hdfc.iloc[500:]
axis_test =axis.iloc[0:500]
axis_train=axis.iloc[500:]
sbi_test =sbi.iloc[0:500]
sbi_train=sbi.iloc[500:]
kotak_test =kotak.iloc[0:500]
kotak_train=kotak.iloc[500:]
icici_test =icici.iloc[0:500]
icici_train=icici.iloc[500:]

# %%
train_data = pd.concat([hdfc_train,axis_train,sbi_train,kotak_train,icici_train])

# %%
ft_sent=train_data[['Tweet_stemmed','sentiment']]
ft_sent.rename(columns = {'Tweet_stemmed':'features'}, inplace = True) 
ft_sent
# Out:
# C:\Users\KIRHIKAGURUMURTHY\anaconda3\lib\site-packages\pandas\core\frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                                                features      sentiment
# 2551  [hdfcbankcar, mojorojo, dear, hdfc, round, clo...    displeasure
# 2559             [hdfcbankcar, rbi, still, wait, repli]    displeasure
# 2564  [icicibank, theofficialsbi, axisbank, hdfcbank...  miscellaneous
# 2569  [hdfcbankcar, idtw, cbl, spent, min, exec, man...    displeasure
# 2575                          [hdfcbankcar, done, need]     compliment
# ...                                                 ...            ...
# 5671  [icicibank, icicibankcar, get, procedur, n, bu...    displeasure
# 5673  [icicibankcar, care, bank, staff, shout, poor,...    displeasure
# 5678           [pankajbbaviskar, icicibankcar, start, ]  miscellaneous
# 5682  [kkbhalla, narendramodi, pleas, pass, tip, may...    displeasure
# 5689  [icicibankcar, epay, slip, system, work, sec, ...    displeasure
#
# [3586 rows x 2 columns]

# %%
def extract_features(tweet):
    tweet_words = set(tweet)
    features = {}
    for word in featureList:
        features['contains(%s)' % word] = (word in tweet_words)
    return features

# %%
lis=ft_sent['features'].to_list()
flat_ft = [y for x in lis for y in x]
# Remove featureList duplicates
featureList = list(set(flat_ft))
#featureList
from gensim.models import KeyedVectors
from gensim.models import Word2Vec
word2vec_path = 'word2vec_100.model'
word2vec = KeyedVectors.load(word2vec_path)
word2vec_features=[]
#for word in flat_ft:
    #word2vec_features.append(np.average(word2vec[word]))

print(len(word2vec_features))
#word2vec_df=pd.DataFrame(word2vec_features)
#ft_sent=ft_sent.reset_index()
w2v_s=ft_sent['sentiment'].values.tolist()
len(w2v_s)
#word2vec_df['sentiment']=w2v_s
#word2vec_df'''
# Out:
# 0
# 3586

# %%
tweets=[]
for index, row in ft_sent.iterrows(): 
    sentiment = row['sentiment']
    featureVector = row['features']
    tweets.append((featureVector, sentiment));
tweets
# Out:
# [(['hdfcbankcar',
#    'mojorojo',
#    'dear',
#    'hdfc',
#    'round',
#    'clock',
#    'narr',
#    'seem',
#    'mere',
#    'pr',
#    'statement'],
#   'displeasure'),
#  (['hdfcbankcar', 'rbi', 'still', 'wait', 'repli'], 'displeasure'),
#  (['icicibank',
#    'theofficialsbi',
#    'axisbank',
#    'hdfcbank',
#    'citibank',
#    'pleas',
#    'distribut',
#    'cash',
#    'multipl',
#    'atm',
#    'easi',
#    'custom'],
#   'miscellaneous'),
#  (['hdfcbankcar',
#    'idtw',
#    'cbl',
#    'spent',
#    'min',
#    'exec',
#    'manag',
#    'bad',
#    'servic'],
#   'displeasure'),
#  (['hdfcbankcar', 'done', 'need'], 'compliment'),
#  (['transact',
#    'fail',
#    'day',
#    'hdfcbankcar',
#    'send',
#    'msg',
#    'creditedrevers',
#    'cc',
#    'ask',
#    'wait',
#    'day'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'u',
#    'respon',
#    'way',
#    'back',
#    'kindli',
#    'updat',
#    'today',
#    'statu'],
#   'miscellaneous'),
#  (['hdfcbankcar',
#    'hdfcbank',
#    'adityapuri',
#    'hdfcbank',
#    'disgust',
#    'ur',
#    'custom',
#    'servic',
#    'disgust',
#    'respons',
#    'emi',
#    'offer',
#    'activ'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'visit',
#    'branch',
#    'ghatkopar',
#    'east',
#    'told',
#    'dont',
#    'handl',
#    'credit',
#    'card',
#    'queri',
#    'phone',
#    'bank',
#    'option'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'plea',
#    'provid',
#    'hdfc',
#    'md',
#    'email',
#    'id',
#    'want',
#    'rais',
#    'voic'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'rbi',
#    'guidelin',
#    'fli',
#    'mbr',
#    'travel',
#    'unless',
#    'back',
#    'cannot',
#    'take',
#    'author',
#    'ask',
#    ''],
#   'displeasure'),
#  (['hdfcbank',
#    'hdfcbankcar',
#    'day',
#    'still',
#    'get',
#    'respons',
#    'credit',
#    'card',
#    'disput',
#    'complaint',
#    'either',
#    'mail',
#    'custcar'],
#   'displeasure'),
#  (['unfortun',
#    'queue',
#    'need',
#    'cash',
#    'hdfcbank',
#    'icicibankcar',
#    'ideacar',
#    'vodafonein',
#    'bigbazaar',
#    'nashiknew',
#    'timesofindia'],
#   'miscellaneous'),
#  (['citi',
#    'hdfcbankcar',
#    'pleas',
#    'look',
#    'fraudalert',
#    'confirm',
#    'httpstcorugjrcfveg'],
#   'displeasure'),
#  (['hdfcbankcar', 'one', 'day', 'end'], 'displeasure'),
#  (['hdfcbankcar',
#    'thank',
#    'let',
#    'us',
#    'know',
#    'cc',
#    'dc',
#    'use',
#    'small',
#    'valu',
#    'transact',
#    'dont',
#    'u',
#    'also',
#    'send',
#    'tampc'],
#   'compliment'),
#  (['rt',
#    'hdfcbankcar',
#    'memaaduddin',
#    'thank',
#    'kind',
#    'word',
#    'realli',
#    'appreci',
#    'acknowledg',
#    'natasha'],
#   'compliment'),
#  (['hdfcbankcar', 'ok', 'pl', 'ask', 'spam'], 'miscellaneous'),
#  (['rt',
#    'diamondantoo',
#    'meaindia',
#    'hdfcbank',
#    'theofficialsbi',
#    'good',
#    'intent',
#    'modi',
#    'sarkar',
#    'impact',
#    'indian',
#    'travel',
#    'abroad',
#    'lim'],
#   'miscellaneous'),
#  (['hdfcbankcar', 'time', 'open'], 'miscellaneous'),
#  (['rt',
#    'traresearch',
#    'bank',
#    'dont',
#    'attract',
#    'money',
#    'hdfcbankcar',
#    'open',
#    'account',
#    'posit',
#    'follow',
#    'icicibank',
#    'amp',
#    'axi'],
#   'miscellaneous'),
#  (['rt',
#    'sushilizzat',
#    'hdfcbankcar',
#    'uftery',
#    'hdfc',
#    'busi',
#    'count',
#    'note',
#    'pmoindia',
#    'allow',
#    'play',
#    'soldier',
#    'money'],
#   'displeasure'),
#  (['rt',
#    'shreyisher',
#    'thank',
#    'hdfcbankcar',
#    'facil',
#    'got',
#    'lower',
#    'denomin',
#    'well',
#    'demonetis',
#    'indiafightsblackmoney'],
#   'compliment'),
#  (['shaival',
#    'paldi',
#    'branch',
#    'great',
#    'staffgreat',
#    'support',
#    'right',
#    'inform',
#    'staff',
#    'member',
#    'guid',
#    'situat',
#    'hdfcbankcar'],
#   'compliment'),
#  (['hdfcbankcar', 'hidetail', 'sentpl', 'chk', 'revert'], 'miscellaneous'),
#  (['rbi',
#    'hdfcbankcar',
#    'hdfcbank',
#    'pmoindia',
#    'physic',
#    'challeng',
#    'personno',
#    'chequ',
#    'leafturn',
#    'away',
#    'bank',
#    'work',
#    'cash',
#    'hand',
#    ''],
#   'displeasure'),
#  (['hdfcbankcar',
#    'hi',
#    'pleas',
#    'provid',
#    'complet',
#    'address',
#    'credit',
#    'card',
#    'divis',
#    'thiruvanmiyur',
#    'chennai',
#    'need',
#    'visit',
#    'cc',
#    'issu'],
#   'miscellaneous'),
#  (['hdfcbankcar',
#    'address',
#    'chang',
#    'ask',
#    'go',
#    'home',
#    'branch',
#    'like',
#    'km',
#    'live'],
#   'displeasure'),
#  (['avnishaxi',
#    'victoryfornamo',
#    'hdfcbankcar',
#    'pmoindia',
#    'dilipkpandey',
#    'excus',
#    'develop',
#    'dont',
#    'mind',
#    'solv',
#    'problem'],
#   'miscellaneous'),
#  (['happi',
#    'see',
#    'hdfcbankcar',
#    'bank',
#    'personnel',
#    'manag',
#    'paymentsexchangewithdraw',
#    'well'],
#   'compliment'),
#  (['hdfcbankcar',
#    'deposit',
#    'cash',
#    'atm',
#    'machin',
#    'earlier',
#    'much',
#    'deposit',
#    'hdfcbank'],
#   'miscellaneous'),
#  (['hdfcbankcar',
#    'mr',
#    'summit',
#    'upper',
#    'pay',
#    'attent',
#    'issu',
#    'pleas',
#    'give',
#    'case',
#    'bonafid',
#    'offic'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'tri',
#    'call',
#    'custom',
#    'support',
#    'day',
#    'procedur',
#    'doesnt',
#    'even',
#    'complet',
#    'nobodi',
#    'repli'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'hell',
#    'r',
#    'run',
#    'cash',
#    'r',
#    'actual',
#    'cash',
#    'sinc',
#    'last',
#    'day',
#    'mukherje',
#    'nagar',
#    'delhi'],
#   'miscellaneous'),
#  (['hdfcbankcar', 'plz', 'needful', 'asap'], 'miscellaneous'),
#  (['rbi',
#    'theofficialsbi',
#    'hdfcbank',
#    'hdfcbankcar',
#    'guy',
#    'pleas',
#    'refil',
#    'atm',
#    'even',
#    'well',
#    'work',
#    'w',
#    'httpstcomvxpfxzkw'],
#   'miscellaneous'),
#  (['rt',
#    'smritimoy',
#    'hdfcbankcar',
#    'singl',
#    'atm',
#    'work',
#    'near',
#    'kolkata',
#    'hardship',
#    'galor',
#    ''],
#   'displeasure'),
#  (['rt',
#    'prakjham',
#    'dearicicibanktheofficialsbiaxisbankhdfcbank',
#    'rqst',
#    'separ',
#    'que',
#    'senior',
#    'citizen',
#    'avoid',
#    'inconveni',
#    ''],
#   'compliment'),
#  (['pleas',
#    'provid',
#    'detail',
#    'account',
#    'holder',
#    'atm',
#    'machin',
#    'work',
#    'respctv',
#    'locat',
#    'icicibank',
#    'axisbank',
#    'theofficialsbi',
#    'hdfcbank'],
#   'miscellaneous'),
#  (['hdfcbankcar',
#    'peopl',
#    'take',
#    'eadhaar',
#    'card',
#    'staff',
#    'humili',
#    'give',
#    'digit',
#    'gener',
#    'adhaar',
#    'card',
#    'digitalindia'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'secondli',
#    'point',
#    'credit',
#    'card',
#    'smaller',
#    'larger',
#    'transact',
#    'cannot',
#    'convert',
#    'emi'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'hdfcbank',
#    'much',
#    'time',
#    'take',
#    'cash',
#    'deposit',
#    'done',
#    'today',
#    'reflect',
#    'account'],
#   'miscellaneous'),
#  (['rt',
#    'hdfcbankcar',
#    'sanjaybaboo',
#    'request',
#    'provid',
#    'us',
#    'ur',
#    'custom',
#    'id',
#    'card',
#    'number',
#    'issu',
#    'dtl',
#    'amp',
#    'regist',
#    'contact',
#    'detail',
#    'write'],
#   'miscellaneous'),
#  (['pawandurani',
#    'rbi',
#    'hdfcbank',
#    'arunjaitley',
#    'hdfcbankcar',
#    'check',
#    'bank',
#    'prioriti',
#    'transact'],
#   'miscellaneous'),
#  (['hdfcbankcar', 'custom', 'id', ''], 'miscellaneous'),
#  (['hdfcbankcar',
#    'prepar',
#    'guy',
#    'talk',
#    'btw',
#    'got',
#    'bank',
#    'promo',
#    'msg',
#    'stand'],
#   'miscellaneous'),
#  (['cashcleanup',
#    'hdfcbank',
#    'hdfcbankcar',
#    'hdfcbanknew',
#    'liluah',
#    'branch',
#    'play',
#    'game',
#    'caus',
#    'high',
#    'inconveni',
#    'harass',
#    'king'],
#   'displeasure'),
#  (['techtrail',
#    'hdfcbankcar',
#    'blame',
#    'cai',
#    'cant',
#    'miss',
#    'entri',
#    'account',
#    'credit',
#    'debitbut',
#    'hdfcbankcar',
#    'practic',
#    'hurt'],
#   'displeasure'),
#  (['hdfcbankcar', 'share', 'email'], 'miscellaneous'),
#  (['narendramodi',
#    'aajtak',
#    'hdfcbankcar',
#    'stock',
#    'money',
#    'finish',
#    'half',
#    'hour'],
#   'displeasure'),
#  (['cashcleanup',
#    'hdfcbank',
#    'hdfcbankcar',
#    'hdfcbanknew',
#    'liluah',
#    'branch',
#    'play',
#    'game',
#    'caus',
#    'high',
#    'inconveni',
#    'even',
#    'exist',
#    'custom'],
#   'displeasure'),
#  (['rt',
#    'vicki',
#    'ranjank',
#    'hdfcbank',
#    'theofficialsbi',
#    'haha',
#    'didnt',
#    'even',
#    'bother',
#    'enter',
#    'sbi',
#    'branch'],
#   'miscellaneous'),
#  (['hdfcbankcar',
#    'close',
#    'account',
#    'sinc',
#    'nd',
#    'nov',
#    'yet',
#    'close',
#    'instead',
#    'charg',
#    'penalti',
#    'plz',
#    'help',
#    'httpstcofayvuboutv'],
#   'displeasure'),
#  (['hey', 'hdfcbankcar', 'what', 'process', 'close', 'account'],
#   'miscellaneous'),
#  (['icicibank',
#    'hdfcbank',
#    'theofficialsbi',
#    'atm',
#    'could',
#    'start',
#    'later',
#    'part',
#    'day',
#    'spread',
#    'custom',
#    'even',
#    'night'],
#   'miscellaneous'),
#  (['hdfcbankcar',
#    'pleas',
#    'let',
#    'know',
#    'statu',
#    'credit',
#    'card',
#    'applic',
#    'httpstcoddmdtxep',
#    'month',
#    'appli',
#    'cc'],
#   'displeasure'),
#  (['aninew',
#    'kudo',
#    'indiapnb',
#    'bank',
#    'like',
#    'theofficialsbi',
#    'bankofbaroda',
#    'axisbank',
#    'hdfcbankcar',
#    'icicibankcar',
#    'also',
#    'wake'],
#   'displeasure'),
#  (['rt',
#    'bantasavrait',
#    'hdfcbankcar',
#    'bluedarttweet',
#    'call',
#    'time',
#    'even',
#    'gonna',
#    'answer',
#    'phone',
#    'dont',
#    'call'],
#   'displeasure'),
#  (['hdfcbankcar', 'email', 'sent', 'u', 'pl', 'check'], 'miscellaneous'),
#  (['one',
#    'atm',
#    'work',
#    'lower',
#    'parel',
#    'icicibankcar',
#    'branch',
#    'say',
#    'cash',
#    'overwher',
#    'get',
#    'cash',
#    'axisbank',
#    'hdfcbankcar',
#    'theofficialsbi'],
#   'displeasure'),
#  (['axisbank',
#    'hdfcbank',
#    'icicibank',
#    'idbibank',
#    'idfcbank',
#    'theofficialsbi',
#    'yesbank',
#    'rbi',
#    'timesnow',
#    'big',
#    'thank',
#    'bank',
#    'peopl',
#    'hatsoff'],
#   'miscellaneous'),
#  (['hdfcbankcar',
#    'per',
#    'guidelin',
#    'branch',
#    'suppos',
#    'work',
#    'xtra',
#    'hour',
#    'ive',
#    'stand',
#    'queue',
#    'hr'],
#   'displeasure'),
#  (['hdfcbankcar', 'sent', 'mail', 'let', 'know', 'requir', 'anyth', 'els'],
#   'miscellaneous'),
#  (['hdfcbankcar',
#    'hdfcbank',
#    'guy',
#    'best',
#    'servic',
#    'jst',
#    'done',
#    'wid',
#    'transact',
#    'smooth',
#    'amp',
#    'well',
#    'manag',
#    'love',
#    'u',
#    'guy',
#    ''],
#   'compliment'),
#  (['hdfcbankcar',
#    'guy',
#    'time',
#    'branch',
#    'open',
#    'today',
#    'tomorrow',
#    'hdfcbank'],
#   'miscellaneous'),
#  (['hdfcbankcar',
#    'cash',
#    'sinc',
#    'morn',
#    'cyber',
#    'green',
#    'cyber',
#    'citi',
#    'gurgaon',
#    'yesterday'],
#   'displeasure'),
#  (['rbi',
#    'finminindia',
#    'theofficialsbi',
#    'axisbank',
#    'hdfcbank',
#    'pmoindia',
#    'pse',
#    'set',
#    'portabl',
#    'po',
#    'atm',
#    'site',
#    'two',
#    'day',
#    ''],
#   'miscellaneous'),
#  (['hdfcbankcar',
#    'pm',
#    'ist',
#    'amp',
#    'intern',
#    'number',
#    'would',
#    'unlik',
#    'help',
#    'distress',
#    'custom',
#    'foreign',
#    'land'],
#   'miscellaneous'),
#  (['hdfcbankcar', 'bank', 'open', 'yet', 'br', 'hdfc', 'nit', 'faridabad'],
#   'displeasure'),
#  (['narendramodi',
#    'pmoindia',
#    'ndtv',
#    'cmofkarnataka',
#    'httweet',
#    'rbi',
#    'hdfcbankcar',
#    'hdfcbank',
#    'plz',
#    'act',
#    'bank',
#    'fail',
#    'httpstcoxfswitm'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'impress',
#    'staff',
#    'versova',
#    'link',
#    'rd',
#    'mumbai',
#    'staff',
#    'well',
#    'organis',
#    'courteou',
#    'help'],
#   'compliment'),
#  (['hey', 'hdfcbank', 'hdfcbankcar', 'atm', 'vasant', 'vihar', 'close'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'well',
#    'organis',
#    'well',
#    'plan',
#    'activ',
#    'currenc',
#    'exchang',
#    'vijayanagar',
#    'branch',
#    'blr',
#    'would',
#    'like',
#    'thank',
#    'team'],
#   'compliment'),
#  (['hdfcbank',
#    'hdfcbankcar',
#    'sec',
#    'branch',
#    'dwarka',
#    'close',
#    'pm',
#    'caus',
#    'inconveni',
#    'extend',
#    'wrkin',
#    'hr',
#    'demonet'],
#   'displeasure'),
#  (['hdfcbankcar', 'ye', 'much', 'pay', 'willb', 'limit', 'save', 'acnt'],
#   'miscellaneous'),
#  (['hdfcbankcar',
#    'koteshwar',
#    'ahmedabad',
#    'branch',
#    'refus',
#    'enrti',
#    'us',
#    'arunjaitley',
#    'pmoindia',
#    'narendramodi',
#    'bank',
#    'help',
#    'us',
#    'hdfcbank'],
#   'displeasure'),
#  (['hdfcbankcar', 'pleas', 'revert'], 'displeasure'),
#  (['hdfcbankcar',
#    'deposit',
#    'cancel',
#    'note',
#    'rupe',
#    'save',
#    'account',
#    'everyday'],
#   'miscellaneous'),
#  (['hdfcbankcar',
#    'today',
#    'got',
#    'bill',
#    'includ',
#    'disput',
#    'amount',
#    'financi',
#    'charg',
#    'even',
#    'pay',
#    'remain',
#    'amount'],
#   'displeasure'),
#  (['hdfcbankcar', 'could', 'pleas', 'tell', 'bank', 'time', 'tomorrow'],
#   'miscellaneous'),
#  (['hdfcbank',
#    'hdfcbankcar',
#    'hdfc',
#    'tinsukia',
#    'assam',
#    'branch',
#    'refus',
#    'encash',
#    'self',
#    'chq',
#    'co',
#    'current',
#    'acsam',
#    'scene',
#    'yesterday',
#    'amp',
#    'today'],
#   'displeasure'),
#  (['vgiroti',
#    'hdfcbankcar',
#    'hdfcbank',
#    'surpris',
#    'u',
#    'still',
#    'appli',
#    'reject',
#    'twice'],
#   'displeasure'),
#  (['hey', 'hdfcbankcar', 'hdfcbank', 'per', 'rule', 'httpstcolrqdldcxo'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'r',
#    'u',
#    'peopl',
#    'asham',
#    'poor',
#    'servic',
#    'commit',
#    'level',
#    'close',
#    'account',
#    'get',
#    'rid',
#    'hdfc'],
#   'displeasure'),
#  (['appreci',
#    'servic',
#    'axisbanksupportcontinuosli',
#    'refil',
#    'atm',
#    'wen',
#    'cald',
#    'largst',
#    'bkshdfcbankcar',
#    'theofficialsbi',
#    'havent',
#    'opnd',
#    'atm'],
#   'compliment'),
#  (['hdfcbankcar',
#    'crowd',
#    'westmambalam',
#    'branch',
#    'chennai',
#    'kudo',
#    'staff',
#    'branch',
#    'handl',
#    'quir',
#    'httpstcobxizeun'],
#   'compliment'),
#  (['hdfcbank',
#    'axisbank',
#    'theofficialsbi',
#    'look',
#    'like',
#    'ur',
#    'bank',
#    'manag',
#    'xchang',
#    'higher',
#    'valu',
#    'currenc',
#    'commissionrbi'],
#   'displeasure'),
#  (['small',
#    'atm',
#    'room',
#    'equip',
#    'ac',
#    'tubelight',
#    'ask',
#    'print',
#    'receipt',
#    'save',
#    'environ',
#    'hdfcbankcar'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'need',
#    'swift',
#    'code',
#    'intern',
#    'rout',
#    'code',
#    'wire',
#    'transfer',
#    'branch',
#    'road',
#    'banjara',
#    'hill',
#    'hyderabad',
#    'thank'],
#   'miscellaneous'),
#  (['hdfcbankcar',
#    'dear',
#    'manoj',
#    'kindli',
#    'pleas',
#    'dont',
#    'take',
#    'step',
#    'queri'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'call',
#    'sever',
#    'time',
#    'one',
#    'give',
#    'proper',
#    'inform',
#    'feel',
#    'ravag',
#    'helpless',
#    'hdfc',
#    'customerservic',
#    'bank',
#    'help'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'plz',
#    'let',
#    'know',
#    'mani',
#    'day',
#    'u',
#    'want',
#    'check',
#    'almost',
#    'day',
#    'gone',
#    'proper',
#    'respons',
#    'provid'],
#   'displeasure'),
#  (['hdfcbankcar', 'much', 'day', 'take', 'refund', 'amount'], 'displeasure'),
#  (['hdfcbankcar', 'took', 'min', 'atm', 'siddhach', 'thane'], 'compliment'),
#  (['hdfcbankcar',
#    'sent',
#    'u',
#    'latter',
#    'got',
#    'assur',
#    'mail',
#    'within',
#    'month',
#    'u',
#    'close',
#    'still',
#    'wait',
#    'month'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'request',
#    'given',
#    'replac',
#    'normal',
#    'edc',
#    'machin',
#    'gpr',
#    'edc',
#    'machin',
#    'almost',
#    'day',
#    'pass',
#    'till',
#    'yet',
#    'receiv'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'deposit',
#    'money',
#    'due',
#    'bad',
#    'servic',
#    'ac',
#    'branch',
#    'noida',
#    'sec',
#    'upther',
#    'monopoli',
#    'bank',
#    'staff'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'hdfclife',
#    'take',
#    'three',
#    'work',
#    'day',
#    'get',
#    'credit',
#    'stoneag',
#    'regalia',
#    'notverypremium'],
#   'displeasure'),
#  (['theofficialsbi',
#    'icicibank',
#    'hdfcbankcar',
#    'finminindia',
#    'rbi',
#    'atm',
#    'transact',
#    'waiv',
#    'till',
#    'decemb',
#    'true'],
#   'miscellaneous'),
#  (['think',
#    'everywher',
#    'hdfcbankcar',
#    'doesnt',
#    'exchang',
#    'money',
#    'non',
#    'account',
#    'holder',
#    'demonetis',
#    'pmoindia',
#    'httpstcoolnpjngq'],
#   'miscellaneous'),
#  (['hdfcbankcar',
#    'deposit',
#    'cash',
#    'hdfc',
#    'branch',
#    'nonhom',
#    'attract',
#    'charg'],
#   'miscellaneous'),
#  (['rt',
#    'developedsurat',
#    'salut',
#    'bank',
#    'postoffic',
#    'amp',
#    'suratpolic',
#    'staff',
#    'theofficialsbi',
#    'icicibank',
#    'hdfcbank',
#    'kotakbankltd',
#    'yesbank',
#    'pmoind'],
#   'compliment'),
#  (['long',
#    'qs',
#    'bank',
#    'hope',
#    'priorit',
#    'famili',
#    'patient',
#    'document',
#    'narendramodi',
#    'theofficialsbi',
#    'icicibankcar',
#    'hdfcbank',
#    'axisbank'],
#   'miscellaneous'),
#  (['hdfcbankcar',
#    'kammanh',
#    'branch',
#    'extrem',
#    'friendli',
#    'profession',
#    'courteou',
#    'bunch',
#    'staff',
#    'httpstcoatghuekp'],
#   'compliment'),
#  (['rt',
#    'shiladitya',
#    'went',
#    'branch',
#    'idbibank',
#    'hdfcbank',
#    'icicibank',
#    'kotakbankltd',
#    'stanchart',
#    'yesbank',
#    'huge',
#    'line',
#    'way'],
#   'miscellaneous'),
#  (['appreci',
#    'unrel',
#    'work',
#    'hdfcbankcar',
#    'icicibankcar',
#    'axisbanksupport',
#    'theofficialsbi',
#    'way',
#    'long',
#    'go',
#    'rbi',
#    'pmoindia'],
#   'compliment'),
#  (['hdfcbankcar', 'long', 'u', 'guy', 'take', 'small', 'thing', ''],
#   'displeasure'),
#  (['ranjank', 'hdfcbank', 'theofficialsbi', 'psb', 'usual', 'letharg', 'mode'],
#   'displeasure'),
#  (['rt',
#    'vaibhavvya',
#    'hdfcbankcar',
#    'ref',
#    'id',
#    'tw',
#    'loan',
#    'applic',
#    'wish',
#    'take',
#    'life',
#    'insur'],
#   'miscellaneous'),
#  (['rt',
#    'shuchimodi',
#    'narendramodi',
#    'pmoindia',
#    'arunjaitley',
#    'finminindia',
#    'rbi',
#    'hdfcbank',
#    'hdfcbankcar',
#    'icicibankcar',
#    'stop',
#    'provid',
#    'privil'],
#   'displeasure'),
#  (['nice',
#    'hope',
#    'bank',
#    'follow',
#    'suit',
#    'wit',
#    'hdfcbankcar',
#    'rep',
#    'shout',
#    'senior',
#    'citizen',
#    'get',
#    'li',
#    'httpstcoyjgwyfid'],
#   'compliment'),
#  (['rbi',
#    'hdfcbankcar',
#    'fyi',
#    'instruct',
#    'follow',
#    'compens',
#    'extra',
#    'hr',
#    'next',
#    'day',
#    'httpstcoyjbajskl'],
#   'miscellaneous'),
#  (['yet',
#    'receiv',
#    'cashback',
#    'amazon',
#    'purchas',
#    'pleas',
#    'help',
#    'hdfcbankcar'],
#   'displeasure'),
#  (['rt',
#    'pawandurani',
#    'dear',
#    'hdfcbankcar',
#    'hdfcbank',
#    'branch',
#    'charmwood',
#    'villag',
#    'refus',
#    'oper',
#    'beyond',
#    'pm',
#    'arunjait'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'aprciat',
#    'effort',
#    'bank',
#    'addrsng',
#    'crisisju',
#    'wish',
#    'govt',
#    'equpd',
#    'u',
#    'amp',
#    'gvn',
#    'u',
#    'ampl',
#    'time',
#    'prepar',
#    'di',
#    'storn'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'hdfc',
#    'say',
#    'nobodi',
#    'rajajinagar',
#    'coop',
#    'bank',
#    'contact',
#    'use',
#    'contact',
#    'person'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'hat',
#    'hdfc',
#    'bank',
#    'amp',
#    'team',
#    'behind',
#    'wonder',
#    'bank',
#    'thank',
#    'u',
#    'keep',
#    'us',
#    'happi',
#    'amp',
#    'pamper',
#    'love',
#    'hdfc',
#    'bank'],
#   'compliment'),
#  (['hdfcbankcar',
#    'rcp',
#    'navi',
#    'mumbai',
#    'hasnt',
#    'bank',
#    'put',
#    'note',
#    'atm',
#    'sinc',
#    'yesterday',
#    'help',
#    'increas',
#    'problem'],
#   'displeasure'),
#  (['today',
#    'singl',
#    'new',
#    'money',
#    'bank',
#    'atm',
#    'palam',
#    'new',
#    'delhi',
#    'icicibank',
#    'axisbank',
#    'mdpnb',
#    'hdfcbank',
#    'theofficialsbi'],
#   'displeasure'),
#  (['hdfcbankcar', 'given', 'number', 'write', 'mail', 'frustat', 'ivr'],
#   'displeasure'),
#  (['hdfcbank',
#    'hdfcbankcar',
#    'hdfcbanknew',
#    'stop',
#    'send',
#    'prefer',
#    'custom',
#    'msg',
#    'also',
#    'ask',
#    'stand',
#    'queue',
#    'transact'],
#   'displeasure'),
#  (['differ',
#    'normal',
#    'account',
#    'holder',
#    'imperiapref',
#    'custom',
#    'branch',
#    'hdfcbankcar'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'prefer',
#    'made',
#    'stand',
#    'gener',
#    'queue',
#    'stubborn',
#    'bank',
#    'manag',
#    'ahura',
#    'andheri',
#    'decid',
#    'give',
#    'prefer',
#    'statu'],
#   'displeasure'),
#  (['rajanbatra',
#    'udaykotak',
#    'myindusindbank',
#    'icicibank',
#    'hdfcbankcar',
#    'think',
#    'money',
#    'got',
#    'print',
#    'modiji',
#    'speech'],
#   'miscellaneous'),
#  (['rbi',
#    'yesbank',
#    'axisbank',
#    'hdfcbank',
#    'kotakbankltd',
#    'none',
#    'atm',
#    'work',
#    'sinc',
#    'morn',
#    'adhichini',
#    'new',
#    'delhi',
#    'nomoney',
#    'contd'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'cid',
#    'rais',
#    'variou',
#    'complaint',
#    'sinc',
#    'juli',
#    'none',
#    'resolv',
#    'home',
#    'branch'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'r',
#    'time',
#    'bank',
#    'hour',
#    'today',
#    'ur',
#    'gr',
#    'noida',
#    'omega',
#    'br',
#    'servic',
#    'custom',
#    'pm'],
#   'miscellaneous'),
#  (['hdfcbankcar',
#    'atm',
#    'still',
#    'oper',
#    'shahapur',
#    'taluka',
#    'yadgir',
#    'district',
#    'karnataka',
#    'pleas',
#    'look',
#    'asap',
#    'thank'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'provid',
#    'soil',
#    'note',
#    'exchangeand',
#    'write',
#    'dat',
#    'uve',
#    'given',
#    'k',
#    'note',
#    'nd',
#    'say',
#    'dat',
#    'u',
#    'dont',
#    'hv',
#    'stock'],
#   'displeasure'),
#  (['suchetadal', 'rtripathi', 'hdfcbankcar', 'bopal', 'ahmedabad'],
#   'miscellaneous'),
#  (['rt',
#    'anuyeaah',
#    'must',
#    'say',
#    'hdfcbankcar',
#    'easi',
#    'navig',
#    'today',
#    'deposit',
#    'chequ',
#    'also',
#    'chair',
#    'peopl',
#    'stand'],
#   'compliment'),
#  (['hdfcbankcar',
#    'dsi',
#    'earlier',
#    'proud',
#    'account',
#    'holder',
#    'hdfc',
#    'sure',
#    'say',
#    'call',
#    'center',
#    'worst'],
#   'displeasure'),
#  (['atm',
#    'shutter',
#    'yelahanka',
#    'bangalor',
#    'demonet',
#    'need',
#    'fix',
#    'asap',
#    'hdfcbankcar',
#    'theofficialsbi',
#    'icicibank'],
#   'displeasure'),
#  (['hdfcbankcar', 'poor', 'servic'], 'displeasure'),
#  (['hdfcbank',
#    'hdfcbankcar',
#    'answer',
#    'govt',
#    'must',
#    'interven',
#    'pmoindia',
#    'arunjaitley',
#    'httpstcoqbhuzpx'],
#   'displeasure'),
#  (['salut',
#    'bank',
#    'postoffic',
#    'amp',
#    'suratpolic',
#    'staff',
#    'theofficialsbi',
#    'icicibank',
#    'hdfcbank',
#    'kotakbankltd',
#    'yesbank',
#    'httpstcoejoetsqv'],
#   'compliment'),
#  (['hdfcbankcar',
#    'hdfcbank',
#    'visaind',
#    'got',
#    'respons',
#    'hdfc',
#    'bank',
#    'kindli',
#    'check',
#    'revert',
#    'visa',
#    'india',
#    'u',
#    'also',
#    'revert',
#    'money'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'day',
#    'think',
#    'day',
#    'remain',
#    'actuallli',
#    'respond',
#    'question',
#    'huh',
#    'ridicul'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'deposit',
#    'money',
#    'hr',
#    'ago',
#    'still',
#    'nit',
#    'show',
#    'account',
#    'net',
#    'phone',
#    'bank',
#    'httpstcokvawhdfu'],
#   'displeasure'),
#  (['kotakbankltd',
#    'icicibank',
#    'hdfcbank',
#    'theofficialsbi',
#    'axisbank',
#    'webdevlpr',
#    'makin',
#    'tool',
#    'social',
#    'caus',
#    'amp',
#    'free',
#    'reduc',
#    'deposit',
#    'queue',
#    'welcmd'],
#   'miscellaneous'),
#  (['hdfcbankcar',
#    'bank',
#    'dwarka',
#    'sec',
#    'close',
#    'hr',
#    'staff',
#    'entertain',
#    'frndsrel',
#    'good',
#    'servic',
#    'rbi',
#    'urjitpatelrbi'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'understood',
#    'first',
#    'attempt',
#    'anyway',
#    'got',
#    'u',
#    'r',
#    'go',
#    'ke',
#    'sme',
#    'time',
#    'irrespct',
#    'sveriti',
#    'issu'],
#   'miscellaneous'),
#  (['karmendrakumar',
#    'dont',
#    'readi',
#    'yet',
#    'deal',
#    'situat',
#    'hdfcbank',
#    'icicibank',
#    'theofficialsbi',
#    'kotakbankltd',
#    'idbibank'],
#   'displeasure'),
#  (['hdfcbank',
#    'hdfcbankcar',
#    'hdfcbanknew',
#    'atm',
#    'aparnasarovar',
#    'nallagandla',
#    'hyderabad',
#    'fill',
#    'cash',
#    'resid',
#    'suffer'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'tri',
#    'upi',
#    'transact',
#    'hdfc',
#    'mobil',
#    'app',
#    'abl',
#    'get',
#    'success',
#    'yesterday'],
#   'displeasure'),
#  (['sorri',
#    'state',
#    'narendramodi',
#    'gagkumar',
#    'bishu',
#    'hdfcbankcar',
#    'timesofindia',
#    'timesnow',
#    'hdfcbanknew',
#    'httpstcoxvihkbhiqm'],
#   'miscellaneous'),
#  (['hdfcbankcar', 'atm', 'httpstcofdbhukol'], 'miscellaneous'),
#  (['hdfcbankcar',
#    'great',
#    'job',
#    'hdfcbank',
#    'annapurna',
#    'road',
#    'branch',
#    'indor',
#    'staff',
#    'handl',
#    'cash',
#    'deposit',
#    'withdraw',
#    'exchang'],
#   'compliment'),
#  (['rt',
#    'hdfcbankcar',
#    'finelychop',
#    'unclear',
#    'queri',
#    'request',
#    'kindli',
#    'elabor',
#    'queri',
#    'assist'],
#   'miscellaneous'),
#  (['hdfcbankcar',
#    'absolut',
#    'mismanag',
#    'branch',
#    'shop',
#    'malldlf',
#    'phase',
#    'gurgaonrud',
#    'behaviour',
#    'toward',
#    'everybodi',
#    ''],
#   'displeasure'),
#  (['hdfcbankcar',
#    'hi',
#    'appli',
#    'credit',
#    'card',
#    'diwali',
#    'havent',
#    'got',
#    'updat',
#    'till',
#    'pleas',
#    'help'],
#   'miscellaneous'),
#  (['pmoindia',
#    'icicibankcar',
#    'hdfcbank',
#    'theofficialsbi',
#    'great',
#    'move',
#    'poorli',
#    'plannedno',
#    'cash',
#    'atm',
#    'veget',
#    'guy',
#    'dont',
#    'accept',
#    'cc',
#    'chequ'],
#   'displeasure'),
#  (['theofficialsbi',
#    'myindusindbank',
#    'citibank',
#    'hdfcbank',
#    'atm',
#    'near',
#    'suraj',
#    'water',
#    'park',
#    'thane',
#    'arent',
#    'work'],
#   'displeasure'),
#  (['hdfcbankcar', 'tommarow', 'bank', 'open', ''], 'miscellaneous'),
#  (['worst',
#    'servic',
#    'experi',
#    'hdfcbankcar',
#    'hdfcbank',
#    'neerajhdfcbank',
#    'abheekhdfcbank',
#    'rbi',
#    'lost',
#    'employe',
#    'bank',
#    'account',
#    'form',
#    'respons'],
#   'displeasure'),
#  (['rt',
#    'ishantanujoshi',
#    'hdfcbankcar',
#    'tri',
#    'get',
#    'touch',
#    'custom',
#    'care',
#    'sinc',
#    'age',
#    'pleas',
#    'let',
#    'know',
#    'addr'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'pl',
#    'repli',
#    'publicli',
#    'dont',
#    'make',
#    'fals',
#    'promis',
#    'dont',
#    'u',
#    'credit',
#    'cash',
#    'back',
#    'promis'],
#   'displeasure'),
#  (['bank',
#    'dont',
#    'attract',
#    'money',
#    'hdfcbankcar',
#    'open',
#    'account',
#    'posit',
#    'follow',
#    'icicibank',
#    'httpstcochxiahhzi'],
#   'compliment'),
#  (['hdfcbankcar',
#    'modihel',
#    'jaitley',
#    'rbishutt',
#    'bokaro',
#    'httpstcovzuyjdsqdr'],
#   'displeasure'),
#  (['ramin',
#    'concept',
#    'passbook',
#    'r',
#    'outdat',
#    'wonder',
#    'mani',
#    'even',
#    'notic',
#    'charg',
#    'debit',
#    'ac',
#    'hdfcbankcar'],
#   'compliment'),
#  (['axisbank',
#    'awesom',
#    'custom',
#    'servic',
#    'text',
#    'custom',
#    'long',
#    'work',
#    'hour',
#    'weekend',
#    'servic',
#    'wish',
#    'hdfcbankcar',
#    'could',
#    'learn'],
#   'compliment'),
#  (['singsuman',
#    'hdfcbankcar',
#    'hdfcbank',
#    'wow',
#    'great',
#    'job',
#    'especi',
#    'privat',
#    'bank',
#    'ill',
#    'treat',
#    'custom',
#    'outright'],
#   'compliment'),
#  (['icicibank',
#    'theofficialsbi',
#    'mdpnb',
#    'idbibank',
#    'rbi',
#    'hdfcbank',
#    'axisbank',
#    'cheer',
#    'bank',
#    'tirelessli',
#    'help',
#    'custom',
#    ''],
#   'compliment'),
#  (['hdfcbankcar',
#    'smooth',
#    'deposit',
#    'amp',
#    'exchang',
#    'money',
#    'secror',
#    'gurgaon',
#    'branch',
#    'cooper',
#    'staffsalut'],
#   'compliment'),
#  (['hdfcbankcar',
#    'hdfcbank',
#    'hat',
#    'hdfc',
#    'bank',
#    'staff',
#    'kothrud',
#    'pune',
#    'everi',
#    'bit',
#    'help',
#    'custom',
#    'deposit',
#    'amp',
#    'exchang',
#    'currenc'],
#   'compliment'),
#  (['hdfcbank',
#    'hdfcbankcar',
#    'hv',
#    'submit',
#    'xerox',
#    'id',
#    'cash',
#    'deposit',
#    'k',
#    'fyi',
#    'kyc',
#    'upto',
#    'date',
#    'system'],
#   'displeasure'),
#  (['icicibank',
#    'icicibankcar',
#    'hdfcbankcar',
#    'theofficialsbi',
#    'rbi',
#    'safeti',
#    'secur',
#    'money',
#    'bankhttpstcodehpusc'],
#   'miscellaneous'),
#  (['idiot',
#    'bank',
#    'ask',
#    'photocopi',
#    'id',
#    'proof',
#    'withdraw',
#    'account',
#    'brainless',
#    'banker',
#    'hdfcbank',
#    'hdfcbankcar'],
#   'displeasure'),
#  (['hdfcbank',
#    'hdfcbankcar',
#    'intern',
#    'number',
#    'credit',
#    'card',
#    'custom',
#    'call',
#    'work',
#    'fayedsouza'],
#   'miscellaneous'),
#  (['ranjank',
#    'hdfcbank',
#    'theofficialsbi',
#    'haha',
#    'didnt',
#    'even',
#    'bother',
#    'enter',
#    'sbi',
#    'branch'],
#   'miscellaneous'),
#  (['hat',
#    'bank',
#    'offici',
#    'r',
#    'manag',
#    'massiv',
#    'unplan',
#    'transactionshdfcbank',
#    'icicibank',
#    'theofficialsbi',
#    'axisbank',
#    'narendramodi'],
#   'compliment'),
#  (['hdfcbankcar',
#    'sent',
#    'mail',
#    'email',
#    'id',
#    'told',
#    'hope',
#    'atleast',
#    'hdfc',
#    'care'],
#   'miscellaneous'),
#  (['narendramodi',
#    'sir',
#    'hdfc',
#    'bank',
#    'readi',
#    'cash',
#    'deposit',
#    'account',
#    'run',
#    'new',
#    'currenc',
#    'rbi',
#    'httpstcoerasxdju'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'thank',
#    'support',
#    'sent',
#    'mail',
#    'id',
#    'detail',
#    'would',
#    'expect',
#    'repli'],
#   'compliment'),
#  (['latest',
#    'statu',
#    'atm',
#    'jangpura',
#    'new',
#    'delhi',
#    'theofficialsbi',
#    'hdfcbank',
#    'yesbank',
#    'icicibankcar',
#    'kotakbankltd',
#    'server',
#    'cardswip'],
#   'miscellaneous'),
#  (['hdfcbankcar', 'uftery', 'still', 'repli', 'wrong', 'guy'], 'displeasure'),
#  (['hdfcbank',
#    'hdfcbankcar',
#    'finminindia',
#    'abpnewstv',
#    'cashier',
#    'deposit',
#    'moni',
#    'ac',
#    'without',
#    'aadhar',
#    'chequ',
#    'bounc',
#    'respnsbl'],
#   'displeasure'),
#  (['dear',
#    'hdfcbankcar',
#    'atm',
#    'kolkata',
#    'gc',
#    'avenu',
#    'branch',
#    'still',
#    'work'],
#   'displeasure'),
#  (['hdfcbankcar', 'differ', 'transact'], 'displeasure'),
#  (['icicibank',
#    'hdfcbankcar',
#    'myindusindbank',
#    'finminindia',
#    'collect',
#    'depart',
#    'bank',
#    'co',
#    'oper',
#    'dont',
#    'n'],
#   'displeasure'),
#  (['hdfcbank',
#    'hdfcbankcar',
#    'hdfcergog',
#    'pl',
#    'confirm',
#    'hdfc',
#    'mediclaim',
#    'polici',
#    'taken',
#    'dn',
#    'time',
#    'renew',
#    'si',
#    'doubl',
#    'prem'],
#   'miscellaneous'),
#  (['hdfcbankcar',
#    'ill',
#    'give',
#    'yall',
#    'tip',
#    'spend',
#    'money',
#    'train',
#    'call',
#    'center',
#    'team',
#    'useless',
#    'fool'],
#   'displeasure'),
#  (['hdfcbankcar', 'dm', 'detail'], 'miscellaneous'),
#  (['hdfcbank',
#    'hdfcbankcar',
#    'hdfcbanknew',
#    'icicibank',
#    'icicibankcar',
#    'icicibank',
#    'open',
#    'counter',
#    'exchang',
#    'note',
#    'aparna',
#    'sarovarhyderabad'],
#   'miscellaneous'),
#  (['aaravmeanspeac',
#    'businesslin',
#    'icicibank',
#    'hdfcbankcar',
#    'senior',
#    'citizen',
#    'justifi',
#    'icici',
#    'bank',
#    'best'],
#   'compliment'),
#  (['hdfcbankcar',
#    'otherwis',
#    'provid',
#    'loan',
#    'statement',
#    'email',
#    'id',
#    'pujachoudharygmailcom',
#    'would',
#    'great',
#    'help'],
#   'miscellaneous'),
#  (['hdfcbankcar', 'u', 'repli'], 'displeasure'),
#  (['hdfcbank', 'hdfcbankcar', 'forc', 'agre', 'panchali', 'httpstcoasvnwvxxx'],
#   'miscellaneous'),
#  (['hdfcbank',
#    'hdfcbankcar',
#    'howrah',
#    'exchang',
#    'rs',
#    'rbi',
#    'narendramodi',
#    'arunjaitley',
#    'timesnow',
#    'aajtak'],
#   'displeasure'),
#  (['rbi',
#    'icicibank',
#    'vijayabankindia',
#    'theofficialsbi',
#    'hdfcbank',
#    'may',
#    'happen',
#    'take',
#    'step',
#    'red',
#    'httpstconmnqchlv'],
#   'miscellaneous'),
#  (['hdfcbankcar',
#    'atm',
#    'work',
#    'mulund',
#    'east',
#    'neelam',
#    'nagar',
#    'httpstcooxqtkdozxn'],
#   'displeasure'),
#  (['call',
#    'custom',
#    'care',
#    'amp',
#    'everytim',
#    'complet',
#    'give',
#    'inform',
#    'phone',
#    'disconnect',
#    'pleas',
#    'help',
#    'hdfcbankcar'],
#   'displeasure'),
#  (['hdfcbankcar', 'custid', 'pleas', 'call', ''], 'miscellaneous'),
#  (['hdfcbankcar',
#    'manag',
#    'get',
#    'done',
#    'pleas',
#    'ask',
#    'sudhir',
#    'gaur',
#    'amp',
#    'team',
#    'see',
#    'fail',
#    'httpstcorivxzkyc'],
#   'miscellaneous'),
#  (['hdfcbankcar', 'debit', 'card', 'work', 'could', 'pl', 'need'],
#   'miscellaneous'),
#  (['rt',
#    'klalgurnani',
#    'pawandurani',
#    'hdfcbankcar',
#    'hdfcbank',
#    'arunjaitley',
#    'zeenewshindi',
#    'newsx',
#    'manakgupta',
#    'aninewsup',
#    'media',
#    'take',
#    'issu'],
#   'miscellaneous'),
#  (['kotakbankltd',
#    'icicibank',
#    'hdfcbank',
#    'yesbank',
#    'axisbank',
#    'pleas',
#    'separ',
#    'queue',
#    'senior',
#    'citizen',
#    'handicap',
#    'branch'],
#   'miscellaneous'),
#  (['hdfcbankcar',
#    'ask',
#    'date',
#    'account',
#    'balanc',
#    'neg',
#    'till',
#    'date',
#    'havent',
#    'receiv',
#    'updat',
#    'hbl',
#    ''],
#   'displeasure'),
#  (['rt',
#    'hdfcbankcar',
#    'regret',
#    'inconveni',
#    'thank',
#    'patienc',
#    'urg',
#    'use',
#    'n'],
#   'miscellaneous'),
#  (['hdfcbankcar', 'sent', 'email'], 'miscellaneous'),
#  (['hdfcbankcar',
#    'get',
#    'messag',
#    'credit',
#    'card',
#    'payment',
#    'someon',
#    'els',
#    'bug',
#    'system'],
#   'miscellaneous'),
#  (['funni',
#    'video',
#    'make',
#    'n',
#    'import',
#    'point',
#    'abt',
#    'currenc',
#    'carecurr',
#    'hdfcbank',
#    'axisbank',
#    'icicibank',
#    'kotakbankltd',
#    'httpstcowkpywlaeit'],
#   'miscellaneous'),
#  (['sowmyarao',
#    'also',
#    'suffr',
#    'lot',
#    'hdfcbankcar',
#    'bank',
#    'charg',
#    'non',
#    'balanc',
#    'violat',
#    'rbi',
#    'norm',
#    'httpstcobrzlfysc'],
#   'displeasure'),
#  (['theofficialsbi',
#    'thank',
#    'atm',
#    'shutter',
#    'wowgood',
#    'support',
#    'finminindia',
#    'similar',
#    'stori',
#    'hdfcbankcar'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'hdfcbank',
#    'pmoindia',
#    'fill',
#    'empti',
#    'hour',
#    'get',
#    'turn',
#    'pleas',
#    'fill',
#    'frequent',
#    'statebankcar'],
#   'displeasure'),
#  (['call',
#    'custom',
#    'care',
#    'amp',
#    'everytim',
#    'complet',
#    'give',
#    'inform',
#    'phone',
#    'disconnect',
#    'pleas',
#    'help',
#    'hdfcbankcar'],
#   'displeasure'),
#  (['hdfcbankcar', 'custid', 'pleas', 'call', ''], 'miscellaneous'),
#  (['hdfcbankcar',
#    'manag',
#    'get',
#    'done',
#    'pleas',
#    'ask',
#    'sudhir',
#    'gaur',
#    'amp',
#    'team',
#    'see',
#    'fail',
#    'httpstcorivxzkyc'],
#   'miscellaneous'),
#  (['hdfcbankcar', 'debit', 'card', 'work', 'could', 'pl', 'need'],
#   'miscellaneous'),
#  (['rt',
#    'klalgurnani',
#    'pawandurani',
#    'hdfcbankcar',
#    'hdfcbank',
#    'arunjaitley',
#    'zeenewshindi',
#    'newsx',
#    'manakgupta',
#    'aninewsup',
#    'media',
#    'take',
#    'issu'],
#   'miscellaneous'),
#  (['kotakbankltd',
#    'icicibank',
#    'hdfcbank',
#    'yesbank',
#    'axisbank',
#    'pleas',
#    'separ',
#    'queue',
#    'senior',
#    'citizen',
#    'handicap',
#    'branch'],
#   'miscellaneous'),
#  (['hdfcbankcar',
#    'ask',
#    'date',
#    'account',
#    'balanc',
#    'neg',
#    'till',
#    'date',
#    'havent',
#    'receiv',
#    'updat',
#    'hbl',
#    ''],
#   'displeasure'),
#  (['rt',
#    'hdfcbankcar',
#    'regret',
#    'inconveni',
#    'thank',
#    'patienc',
#    'urg',
#    'use',
#    'n'],
#   'miscellaneous'),
#  (['hdfcbankcar', 'sent', 'email'], 'miscellaneous'),
#  (['hdfcbankcar',
#    'get',
#    'messag',
#    'credit',
#    'card',
#    'payment',
#    'someon',
#    'els',
#    'bug',
#    'system'],
#   'miscellaneous'),
#  (['funni',
#    'video',
#    'make',
#    'n',
#    'import',
#    'point',
#    'abt',
#    'currenc',
#    'carecurr',
#    'hdfcbank',
#    'axisbank',
#    'icicibank',
#    'kotakbankltd',
#    'httpstcowkpywlaeit'],
#   'miscellaneous'),
#  (['sowmyarao',
#    'also',
#    'suffr',
#    'lot',
#    'hdfcbankcar',
#    'bank',
#    'charg',
#    'non',
#    'balanc',
#    'violat',
#    'rbi',
#    'norm',
#    'httpstcobrzlfysc'],
#   'displeasure'),
#  (['theofficialsbi',
#    'thank',
#    'atm',
#    'shutter',
#    'wowgood',
#    'support',
#    'finminindia',
#    'similar',
#    'stori',
#    'hdfcbankcar'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'hdfcbank',
#    'pmoindia',
#    'fill',
#    'empti',
#    'hour',
#    'get',
#    'turn',
#    'pleas',
#    'fill',
#    'frequent',
#    'statebankcar'],
#   'displeasure'),
#  (['arjunvagal', 'hdfcbank', 'hdfcbankcar', 'mostli', 'atm', 'close'],
#   'miscellaneous'),
#  (['anyon',
#    'els',
#    'hdfcbank',
#    'upi',
#    'vpa',
#    'registr',
#    'stuck',
#    'loop',
#    'everytim',
#    'tri',
#    'regist',
#    'pop',
#    'httpstcookoyzcgn'],
#   'miscellaneous'),
#  (['hdfcbankcar',
#    'rbi',
#    'need',
#    'send',
#    'trail',
#    'mail',
#    'requir',
#    'detail',
#    'pl',
#    'somethingthi',
#    'happen',
#    'twice',
#    'within',
#    'month'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'hdfclife',
#    'hdfcbank',
#    'pleas',
#    'contact',
#    'full',
#    'address',
#    ''],
#   'miscellaneous'),
#  (['hdfcbankcar', 'poor', 'servic', ''], 'displeasure'),
#  (['hdfcbankcar',
#    'alrdi',
#    'sent',
#    'requir',
#    'detail',
#    'gmail',
#    'respons',
#    'side'],
#   'miscellaneous'),
#  (['quit',
#    'sweet',
#    'hdfcbankcar',
#    'let',
#    'senior',
#    'citizen',
#    'expect',
#    'mother',
#    'jump',
#    'queue',
#    'depositsexchang',
#    'currenc',
#    'notesban'],
#   'compliment'),
#  (['today', 'queue', 'outsid', 'hdfcbankcar', 'httpstcojpcdrbvwvu'],
#   'miscellaneous'),
#  (['hdfcbankcar',
#    'even',
#    'follow',
#    'timelin',
#    'naraina',
#    'branch',
#    'everyon',
#    'stand',
#    'singl',
#    'line',
#    'exchangedeposit',
#    'withdraw'],
#   'displeasure'),
#  (['hdfcbank',
#    'icicibank',
#    'axisbank',
#    'theofficialsbi',
#    'would',
#    'finminindia',
#    'ask',
#    'bank',
#    'display',
#    'live',
#    'statu',
#    'atm',
#    'demonit'],
#   'displeasure'),
#  (['hdfcbankcaresmultipl',
#    'peopl',
#    'call',
#    'mei',
#    'went',
#    'ur',
#    'raniganj',
#    'offic',
#    'amp',
#    'told',
#    'mgr',
#    'start',
#    'repay',
#    'loan',
#    'get',
#    'job',
#    'amp',
#    'pay'],
#   'miscellaneous'),
#  (['hdfcbankcar',
#    'one',
#    'counter',
#    'oper',
#    'hdfc',
#    'bank',
#    'jeewan',
#    'nagar',
#    'branch',
#    'delhi',
#    'pleas',
#    'increas',
#    'number',
#    'counter'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'get',
#    'kg',
#    'potato',
#    'lt',
#    'cow',
#    'milk',
#    'egg',
#    'tomorrow',
#    'meal',
#    'get',
#    'payment',
#    'via',
#    'net',
#    'bank',
#    'deliv',
#    'ndtv'],
#   'miscellaneous'),
#  (['hdfcbankcar', 'axi', 'best', 'fastest', 'httpstcoheagkqaiy'],
#   'compliment'),
#  (['hdfcbank', 'hdfcbankcar', 'pmoindia', 'mr', 'prime', 'minist'],
#   'miscellaneous'),
#  (['theofficialsbi',
#    'sbi',
#    'cgroad',
#    'branch',
#    'poor',
#    'worst',
#    'answer',
#    'employe',
#    'given',
#    'custom',
#    'sbi',
#    'boi',
#    'axi',
#    'bank',
#    'hdfc',
#    'icici',
#    'pnb'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'dont',
#    'keep',
#    'repeat',
#    'word',
#    'noth',
#    'doesnt',
#    'mean',
#    'customercar',
#    'customerservic',
#    'mean',
#    'parrot'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'hdfc',
#    'never',
#    'fail',
#    'dissapoint',
#    'close',
#    'account',
#    'month',
#    'back',
#    'yet',
#    'receiv',
#    'amount',
#    'badcustomerservic'],
#   'displeasure'),
#  (['hdfcbank',
#    'hdfcbankcar',
#    'made',
#    'hdfc',
#    'credit',
#    'card',
#    'payment',
#    'hdfc',
#    'bank',
#    'netbank',
#    'credit',
#    'show',
#    'credit',
#    'card'],
#   'miscellaneous'),
#  (['hdfcbankcar',
#    'hdfcbank',
#    'narendramodi',
#    'excel',
#    'arrang',
#    'hdfc',
#    'bank',
#    'snr',
#    'citizen',
#    'separ',
#    'line',
#    'seat',
#    'area'],
#   'compliment'),
#  (['hdfcbankcar', 'go', 'refer', 'number', ''], 'miscellaneous'),
#  (['hdfcbankcar',
#    'atm',
#    'openinclud',
#    'bank',
#    'atmgiv',
#    'opportun',
#    'transact',
#    'atm'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'amount',
#    'deduct',
#    'account',
#    'merchant',
#    'claim',
#    'receiv',
#    'payment',
#    'pleas',
#    'help',
#    'revers'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'imerg',
#    'want',
#    'onlin',
#    'hdfc',
#    'bank',
#    'statement',
#    'kindli',
#    'help'],
#   'miscellaneous'),
#  (['hdfcbankcar',
#    'im',
#    'hdfc',
#    'ac',
#    'holder',
#    'complet',
#    'support',
#    'amp',
#    'govt',
#    'decis',
#    'whatev',
#    'support',
#    'bank',
#    'employe',
#    'thank'],
#   'compliment'),
#  (['hdfcbankcar',
#    'pleas',
#    'tell',
#    'u',
#    'fill',
#    'cash',
#    'atm',
#    'sector',
#    'faridabad',
#    ''],
#   'miscellaneous'),
#  (['hdfcbankcar',
#    'hi',
#    'sent',
#    'support',
#    'request',
#    'ticket',
#    'hbl',
#    'pleas',
#    'look'],
#   'miscellaneous'),
#  (['hdfcbankcar', 'allreadi', 'sent', 'yesterday', 'sinc', 'repli'],
#   'displeasure'),
#  (['hdfcbank',
#    'hdfcbankcar',
#    'shame',
#    'high',
#    'net',
#    'worth',
#    'prefer',
#    'custom',
#    'stand',
#    'que',
#    'hour',
#    'prefer',
#    'faciliy',
#    'seem',
#    'useless'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'stand',
#    'queue',
#    'hdfcbank',
#    'domjur',
#    'hwh',
#    'branch',
#    'cci',
#    'xchang',
#    'may',
#    'know',
#    'offici',
#    'time',
#    'tday',
#    'n',
#    'tmrw'],
#   'miscellaneous'),
#  (['hdfcbankcar',
#    'poor',
#    'serviceun',
#    'neft',
#    'nre',
#    'accountand',
#    'help',
#    'one'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'dont',
#    'want',
#    'keep',
#    'argu',
#    'everi',
#    'month',
#    'use',
#    'pay',
#    'bill',
#    'wo',
#    'check',
#    'statement',
#    'dont',
#    'trust'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'long',
#    'queue',
#    'karapakkam',
#    'hdfc',
#    'transact',
#    'still',
#    'adjac',
#    'atm',
#    'counter',
#    'didnt',
#    'open',
#    'mrng'],
#   'displeasure'),
#  (['arunjaitley',
#    'pmoindia',
#    'rbi',
#    'ucobankcar',
#    'hdfcbankcar',
#    'theofficialsbi',
#    'bank',
#    'open',
#    'yesterday',
#    'amp',
#    'close',
#    'nagda',
#    'mp'],
#   'displeasure'),
#  (['hdfcbank',
#    'hdfcbankcar',
#    'isnt',
#    'fantast',
#    'opportun',
#    'show',
#    'imperia',
#    'custom',
#    'realli',
#    'special',
#    'gestur',
#    'matter'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'peopl',
#    'account',
#    'without',
#    'consent',
#    'take',
#    'money',
#    ''],
#   'displeasure'),
#  (['hdfcbankcar', 'care', 'remot', 'locat', 'peopl', 'also'], 'miscellaneous'),
#  (['hdfcbankcar',
#    'bank',
#    'open',
#    'custom',
#    'bt',
#    'hdfcbank',
#    'close',
#    'custom',
#    'wt',
#    'nonsens',
#    'happi',
#    'bday',
#    'modibintughlaq',
#    'thank',
#    'gift'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'thank',
#    'lot',
#    'great',
#    'help',
#    'support',
#    'make',
#    'countri',
#    'blackmoney',
#    'free',
#    'may',
#    'god',
#    'bless',
#    'pm',
#    'modi',
#    'jee'],
#   'compliment'),
#  (['narendramodi',
#    'bank',
#    'deni',
#    'transact',
#    'hdfcbankcar',
#    'sec',
#    'rkpuram'],
#   'miscellaneous'),
#  (['hdfcbankcar',
#    'staff',
#    'realli',
#    'great',
#    'warj',
#    'malwadi',
#    'branch',
#    'keep',
#    'httpstcorvzpnsex'],
#   'compliment'),
#  (['rbi',
#    'hdfcbank',
#    'kotakbankltd',
#    'atm',
#    'bank',
#    'work',
#    'lower',
#    'parel',
#    'mumbai',
#    ''],
#   'displeasure'),
#  (['atm',
#    'charg',
#    'waiv',
#    'possibl',
#    'atm',
#    'usag',
#    'per',
#    'month',
#    'abolish',
#    'yet',
#    'confirm',
#    'indiafightscorrupt',
#    'theofficialsbi',
#    'rbi',
#    'hdfcbank'],
#   'miscellaneous'),
#  (['hdfcbankcar',
#    'rais',
#    'voic',
#    'sinc',
#    'ur',
#    'custom',
#    'care',
#    'execut',
#    'take',
#    'properlyjust',
#    'confirm',
#    'credit'],
#   'displeasure'),
#  (['reaction',
#    'bank',
#    'balanc',
#    'goe',
#    'minimum',
#    'amount',
#    'hdfcbankcar',
#    'hdfcbank',
#    'httpstcomoeahtjk'],
#   'miscellaneous'),
#  (['subrataiam',
#    'rvaidya',
#    'hdfcbankcar',
#    'alreadi',
#    'start',
#    'polic',
#    'take',
#    'mamool',
#    'crowd',
#    'control'],
#   'displeasure'),
#  (['hdfc',
#    'atm',
#    'oper',
#    'santoshpur',
#    'area',
#    'kol',
#    'hdfcbankcar',
#    'hdfcbank'],
#   'miscellaneous'),
#  (['hdfcbankcar', 'anay', 'good', 'luck', 'w', 'nodal', 'offic', ''],
#   'miscellaneous'),
#  (['hdfcbankcar', 'thank'], 'compliment'),
#  (['theofficialsbi',
#    'becom',
#    'th',
#    'valuabl',
#    'firm',
#    'beat',
#    'market',
#    'valuat',
#    'infosi',
#    'amp',
#    'hdfc',
#    'httpstcormgxilqr'],
#   'miscellaneous'),
#  (['hdfcbankcar',
#    'mine',
#    'error',
#    'much',
#    'lesser',
#    'amount',
#    'deposit',
#    'said',
#    'realli',
#    'correct',
#    'email',
#    'commun',
#    'amp',
#    'rbi'],
#   'miscellaneous'),
#  (['hdfcbankcar',
#    'hdfc',
#    'hsr',
#    'layout',
#    'bangalor',
#    'branch',
#    'close',
#    'pm',
#    'refus',
#    'cash',
#    'withdraw',
#    'branch'],
#   'miscellaneous'),
#  (['rbi', 'yesbank', 'axisbank', 'hdfcbank', 'kotakbankltd', 'fill', 'atm'],
#   'displeasure'),
#  (['goyalsanjeev',
#    'narendramodi',
#    'arunjaitley',
#    'rbi',
#    'finminindia',
#    'theofficialsbi',
#    'hdfcbank',
#    'midnight',
#    'oper',
#    'advis',
#    'robberi',
#    'issu'],
#   'miscellaneous'),
#  (['hdfcbankcar',
#    'employe',
#    'hdfc',
#    'shakarpur',
#    'branch',
#    'delhi',
#    'say',
#    'dat',
#    'onlin',
#    'adhar',
#    'applic',
#    'xchang',
#    'old',
#    'notesi'],
#   'miscellaneous'),
#  (['none',
#    'atm',
#    'r',
#    'wrkngthere',
#    'cash',
#    'whthr',
#    'hdfcbank',
#    'icicibank',
#    'theofficialsbi',
#    'fals',
#    'promis',
#    'made',
#    'bank',
#    'sad',
#    'abpnewstv'],
#   'displeasure'),
#  (['hdfcbankcar', 'hi', 'u', 'plz', 'increas', 'swipe', 'limit'],
#   'miscellaneous'),
#  (['hdfcbankcar',
#    'check',
#    'see',
#    'print',
#    'form',
#    'home',
#    'fill',
#    'tri',
#    'save',
#    'trip',
#    'bank'],
#   'miscellaneous'),
#  (['hdfcbankcar',
#    'anybodi',
#    'bother',
#    'repli',
#    'move',
#    'bank',
#    'ombudsman',
#    'month',
#    'sinc',
#    'gave',
#    'letter',
#    'branch'],
#   'displeasure'),
#  (['hdfcbankcar', 'still', 'hdfc', 'branch', 'pinjor', 'work'], 'displeasure'),
#  (['hdfcbankcar', 'hdfcbank', 'feedback', 'manoj'], 'miscellaneous'),
#  (['theofficialsbi',
#    'icicibank',
#    'allahabadbanku',
#    'hdfcbank',
#    'rbi',
#    'salut',
#    'employe',
#    'extend',
#    'servic',
#    'nation'],
#   'compliment'),
#  (['rbi',
#    'yesbank',
#    'axisbank',
#    'hdfcbank',
#    'kotakbankltd',
#    'travel',
#    'today',
#    'marriag',
#    'rel',
#    'amp',
#    'money',
#    'nomoney',
#    'contd'],
#   'displeasure'),
#  (['hdfcbank',
#    'hdfcbankcar',
#    'lane',
#    'cash',
#    'deposit',
#    'exchangeamp',
#    'withdraw',
#    'reason',
#    'long',
#    'wait',
#    'poddar',
#    'arcad',
#    'surat'],
#   'miscellaneous'),
#  (['rt',
#    'hdfcbankcar',
#    'atm',
#    'transact',
#    'made',
#    'hdfc',
#    'bank',
#    'atm',
#    'hdfc',
#    'bank',
#    'custom',
#    'n'],
#   'miscellaneous'),
#  (['hdfcbankcar',
#    'hdfcbank',
#    'rbi',
#    'delhipolic',
#    'cybercrimecid',
#    'heard',
#    'back',
#    'fro',
#    'youll',
#    'youll',
#    'taken',
#    'action',
#    'stop',
#    'ppl'],
#   'miscellaneous'),
#  (['rt',
#    'waquaralamkhan',
#    'hdfcbank',
#    'icicibank',
#    'theofficialsbi',
#    'bad',
#    'servic',
#    'bank',
#    'crise',
#    'accept',
#    'httpstcolc'],
#   'displeasure'),
#  (['rt',
#    'smritimoy',
#    'hardli',
#    'atm',
#    'work',
#    'kolkata',
#    'theofficialsbi',
#    'hdfcbank',
#    'icicibank',
#    'rbi',
#    'pleas',
#    'help'],
#   'displeasure'),
#  (['acquaint',
#    'went',
#    'hdfcbank',
#    'withdrew',
#    'kexchang',
#    'k',
#    'minsi',
#    'went',
#    'theofficialsbi',
#    'gate',
#    'lockedchaoscam',
#    'back',
#    ''],
#   'displeasure'),
#  (['kotakbankltd',
#    'yesbank',
#    'hdfcbank',
#    'atm',
#    'work',
#    'acharya',
#    'niketan',
#    'market',
#    'mayur',
#    'vihar',
#    'ph',
#    'delhi'],
#   'displeasure'),
#  (['hdfcbankcar', 'thank', 'manoj', 'ill', 'wait', 'updat'], 'miscellaneous'),
#  (['problem',
#    'dear',
#    'hdfcbank',
#    'icicibankcar',
#    'ideacar',
#    'vodafonein',
#    'bigbazaar',
#    'get',
#    'bread',
#    'local',
#    'shop',
#    'nashiknew',
#    'timesofindia'],
#   'miscellaneous'),
#  (['hdfcbankcar',
#    'ok',
#    'guess',
#    'everyon',
#    'face',
#    'similar',
#    'issu',
#    'light',
#    'ongo',
#    'crisi',
#    'understand'],
#   'miscellaneous'),
#  (['kten',
#    'arr',
#    'exchang',
#    'note',
#    'anywher',
#    'na',
#    'account',
#    'need',
#    'idbibank',
#    'hdfcbank',
#    'icicibank',
#    'kotakbankltd',
#    'stanchart',
#    'yesbank'],
#   'miscellaneous'),
#  (['hdfcbankcar',
#    'hdfc',
#    'internet',
#    'bank',
#    'safe',
#    'worst',
#    'bank',
#    'cheat',
#    'common',
#    'peopl'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'realli',
#    'dont',
#    'know',
#    'manag',
#    'crowd',
#    'realli',
#    'frustrat',
#    'way',
#    'manag',
#    'passport',
#    'offic',
#    'branch',
#    'bangalor'],
#   'displeasure'),
#  (['hdfcbankcar',
#    'cant',
#    'get',
#    'car',
#    'loan',
#    'bank',
#    'insist',
#    'lakh',
#    'min',
#    'loan'],
#   'miscellaneous'),
#  (['hdfcbankcar',
#    'tx',
#    'yr',
#    'qik',
#    'respons',
#    'que',
#    'yesterday',
#    'min',
#    'today',
#    'hr',
#    'told',
#    'cash',
#    'withdraw',
#    'exch'],
#   'compliment'),
#  (['ankurrajswaroop',
#    'icicibankcar',
#    'icicibank',
#    'thank',
# ...
#    'nov',
#    'help'],
#   'displeasure'),
#  (['theofficialsbi', 'contact', 'number', ''], 'miscellaneous'),
#  (['theofficialsbi',
#    'light',
#    'bill',
#    'valid',
#    'document',
#    'per',
#    'juinagar',
#    'branch',
#    'manag',
#    'arrogantli',
#    'return',
#    'back',
#    'chang',
#    'httpstcogxjaycna'],
#   'displeasure'),
#  (['theofficialsbi',
#    'bank',
#    'staff',
#    'speak',
#    'local',
#    'languag',
#    'httpstcoxmkmrhcth'],
#   'displeasure'),
#  (['theofficialsbi', 'dont', 'stock', 'rs', 'note', ''], 'displeasure'),
#  (['theofficialsbi',
#    'problem',
#    'machin',
#    'one',
#    'button',
#    'still',
#    'dont',
#    'work',
#    'atm',
#    'continu',
#    'remain',
#    'defunct'],
#   'displeasure'),
#  (['vivekchandan',
#    'nistula',
#    'theofficialsbi',
#    'kittumaheshwari',
#    'trust',
#    'deficit',
#    'among',
#    'citizen',
#    'politiciansbut',
#    'awar',
#    'increas'],
#   'miscellaneous'),
#  (['theofficialsbi', 'love', 'sbi', 'alway', 'top'], 'compliment'),
#  (['theofficialsbi',
#    'bank',
#    'shut',
#    'pm',
#    'time',
#    'given',
#    'pm',
#    'peopl',
#    'wait',
#    'naigaon',
#    'dadar',
#    'mumbai',
#    'branchbad'],
#   'displeasure'),
#  (['theofficialsbi', 'day', 'lunchtim'], 'displeasure'),
#  (['digit',
#    'india',
#    'credit',
#    'card',
#    'transact',
#    'charg',
#    'even',
#    'hospit',
#    'narendramodi',
#    'devfadnavi',
#    'sbicardconnect',
#    'icicibankcar'],
#   'displeasure'),
#  (['theofficialsbi',
#    'an',
#    'z',
#    'justifi',
#    'charg',
#    'odd',
#    'rs',
#    'system',
#    'failur',
#    'n',
#    'nt',
#    'get',
#    'msg',
#    'tym',
#    'attempt',
#    'transact'],
#   'displeasure'),
#  (['rt',
#    'circleindia',
#    'nildeor',
#    'rbi',
#    'theofficialsbi',
#    'pl',
#    'print',
#    'back',
#    'page',
#    'hindi'],
#   'displeasure'),
#  (['theofficialsbi', 'tkank'], 'compliment'),
#  (['theofficialsbi',
#    'thank',
#    'ill',
#    'check',
#    'bank',
#    'hope',
#    'limit',
#    'psu',
#    'bank'],
#   'miscellaneous'),
#  (['pmoindia',
#    'narendramodi',
#    'arunjaitley',
#    'rbi',
#    'theofficialsbi',
#    'hdfcbank',
#    'kindli',
#    'ask',
#    'bank',
#    'fill',
#    'atm',
#    'frequent',
#    'next',
#    'day'],
#   'displeasure'),
#  (['rd',
#    'day',
#    'ban',
#    'atm',
#    'mahada',
#    'malad',
#    'w',
#    'didnt',
#    'cash',
#    'icicibank',
#    'bankofindiaboi',
#    'theofficialsbi',
#    'hdfcbank'],
#   'displeasure'),
#  (['theofficialsbi',
#    'alrdi',
#    'regist',
#    'solut',
#    'rcvd',
#    'far',
#    'evn',
#    'today',
#    'also',
#    'withdraw',
#    'deposit',
#    'allowedwhi',
#    'u',
#    'say',
#    ''],
#   'displeasure'),
#  (['theofficialsbi',
#    'abl',
#    'book',
#    'irctc',
#    'ticket',
#    'use',
#    'onlin',
#    'sbi',
#    'what',
#    'issu'],
#   'displeasure'),
#  (['theofficialsbi',
#    'rbi',
#    'finminindia',
#    'whn',
#    'atm',
#    'actual',
#    'function',
#    'demonetis',
#    'cashcleanup',
#    'rsr',
#    'cashrush'],
#   'displeasure'),
#  (['theofficialsbi',
#    'new',
#    'denomin',
#    'avail',
#    'yet',
#    'kolkata',
#    'branch',
#    'arunjaitley',
#    'narendramodi',
#    'finminindia'],
#   'displeasure'),
#  (['incindia',
#    'vp',
#    'officeofrg',
#    'theofficialsbi',
#    'bank',
#    'parliament',
#    'street',
#    'exchang',
#    'money',
#    'cash',
#    'counter',
#    'httpstcocbaotuh'],
#   'miscellaneous'),
#  (['theofficialsbi', 'saddam', ''], 'miscellaneous'),
#  (['rt',
#    'swamiram',
#    'theofficialsbi',
#    'right',
#    'plan',
#    'countri',
#    'u',
#    'deposit',
#    'money',
#    'atm',
#    'announc',
#    'currenc',
#    'chang',
#    'amp'],
#   'displeasure'),
#  (['theofficialsbi', 'pl', 'simeth', 'peopl', 'face', 'lot', 'problem'],
#   'displeasure'),
#  (['theofficialsbi',
#    'result',
#    'avail',
#    'career',
#    'page',
#    'link',
#    'other',
#    'see',
#    'resultreg',
#    'dob',
#    'sep',
#    ''],
#   'displeasure'),
#  (['theofficialsbi',
#    'rbi',
#    'sbicloningdebitcard',
#    'respons',
#    'common',
#    'man',
#    'money',
#    'launder',
#    'narendramodi'],
#   'displeasure'),
#  (['rt',
#    'theofficialsbi',
#    'sjsrathor',
#    'old',
#    'currenc',
#    'note',
#    'rs',
#    'rs',
#    'denomin',
#    'may',
#    'deposit',
#    'branch',
#    'cdm',
#    'till',
#    'decemb'],
#   'miscellaneous'),
#  (['pmoindia',
#    'narendramodi',
#    'arunjaitley',
#    'theofficialsbi',
#    'say',
#    'lack',
#    'implement',
#    ''],
#   'displeasure'),
#  (['theofficialsbi',
#    'forward',
#    'email',
#    'chain',
#    'id',
#    'u',
#    'see',
#    'entir',
#    'complaint',
#    'even',
#    'disappoint',
#    'inact',
#    'sbi',
#    'author'],
#   'displeasure'),
#  (['rt',
#    'midday',
#    'tragedi',
#    'mumbai',
#    'senior',
#    'citizen',
#    'die',
#    'stand',
#    'hour',
#    'theofficialsbi',
#    'atm',
#    'queue',
#    'httpstcoyqygjtau',
#    'midday'],
#   'displeasure'),
#  (['theofficialsbi',
#    'worst',
#    'servic',
#    'sbieven',
#    'delhi',
#    'r',
#    'provid',
#    'cash',
#    'pmoindia',
#    'httpstcozparaoy'],
#   'displeasure'),
#  (['rt',
#    'theofficialsbi',
#    'onlychirag',
#    'regret',
#    'inconveni',
#    'caus',
#    'pleas',
#    'share',
#    'specif',
#    'detail',
#    'grievanc',
#    'httpstcolvn'],
#   'miscellaneous'),
#  (['theofficialsbi',
#    'nobodi',
#    'revert',
#    'queri',
#    'forward',
#    'lengthi',
#    'requir',
#    'list',
#    'easi',
#    'deal',
#    'bank',
#    'pl',
#    'eas',
#    'work'],
#   'displeasure'),
#  (['rt',
#    'ssuujjaayi',
#    'theofficialsbi',
#    'sindanur',
#    'karnataka',
#    'ampkannada',
#    'offici',
#    'lang',
#    'f',
#    'karnataka',
#    'abndnkmtr',
#    'writ',
#    'oli',
#    'n',
#    'eng',
#    'r',
#    'hind'],
#   'displeasure'),
#  (['sudhirchaudhari',
#    'theofficialsbi',
#    'branch',
#    'pute',
#    'notic',
#    'bank',
#    'close',
#    'time',
#    'pmtodayamptimmrowampmonday',
#    'holiday',
#    'rbi',
#    'share',
#    'info'],
#   'miscellaneous'),
#  (['narendramodi',
#    'theofficialsbi',
#    'hdfcbank',
#    'axisbank',
#    'icicibank',
#    'thank',
#    'bank',
#    'employe',
#    'help',
#    'httpstcoeplsj'],
#   'compliment'),
#  (['theofficialsbi',
#    'wthdraw',
#    'money',
#    'sbi',
#    'branch',
#    'code',
#    'took',
#    'minut',
#    'great',
#    'pmoindia',
#    'narendramodi'],
#   'compliment'),
#  (['hoarder',
#    'r',
#    'use',
#    'benami',
#    'conert',
#    'black',
#    'money',
#    'rbi',
#    'arunjaitley',
#    'narendramodi',
#    'theofficialsbi',
#    'hdfcbank',
#    'icicibank',
#    'ampothr',
#    'need',
#    'hawk',
#    'eye'],
#   'miscellaneous'),
#  (['theofficialsbi',
#    'im',
#    'sbi',
#    'harauli',
#    'singl',
#    'offic',
#    'staff',
#    'close',
#    'theyr',
#    'dedic',
#    'toward',
#    'job'],
#   'displeasure'),
#  (['rbi',
#    'narendramodi',
#    'indianembassyu',
#    'icicibankcar',
#    'call',
#    'sbini',
#    'icicini',
#    'nro',
#    'acboth',
#    'said',
#    'recvd',
#    'instruct',
#    'rbi'],
#   'displeasure'),
#  (['sbi',
#    'midtown',
#    'curchorem',
#    'allow',
#    'enter',
#    'branch',
#    'pm',
#    'theofficialsbi',
#    'pm',
#    'come',
#    'aft',
#    'httpstcoqlrsnitdk'],
#   'displeasure'),
#  (['rt',
#    'naukarshah',
#    'gear',
#    'open',
#    'one',
#    'mobil',
#    'microatm',
#    'everi',
#    'villag',
#    'uniqu',
#    'tieup',
#    'theofficialsbi',
#    'amp',
#    'district',
#    'administrati'],
#   'miscellaneous'),
#  (['theofficialsbi',
#    'deposit',
#    'money',
#    'non',
#    'home',
#    'branch',
#    'dose',
#    'attract',
#    'penalti',
#    'situat',
#    'long',
#    'que',
#    'home',
#    'branch',
#    'rbi'],
#   'miscellaneous'),
#  (['theofficialsbi', 'thank', 'much', 'ill', 'look'], 'compliment'),
#  (['theofficialsbi',
#    'much',
#    'time',
#    'requir',
#    'receiv',
#    'ticket',
#    'number',
#    'indic',
#    'registr',
#    'complaint',
#    'done',
#    'cm',
#    'onlin'],
#   'displeasure'),
#  (['theofficialsbi',
#    'author',
#    'close',
#    'saketdelhi',
#    'sbi',
#    'branch',
#    'pm',
#    'pleas',
#    'look',
#    'inconveni',
#    'us'],
#   'displeasure'),
#  (['theofficialsbi',
#    'axisbank',
#    'staff',
#    'dont',
#    'keep',
#    'face',
#    'like',
#    'orangutan',
#    'dont',
#    'need',
#    'ur',
#    'money',
#    'want',
#    'human',
#    'be',
#    'keep',
#    'smile'],
#   'displeasure'),
#  (['cap',
#    'atm',
#    'transact',
#    'still',
#    'effect',
#    'theofficialsbi',
#    'hdfcbankcar',
#    'arunjaitley',
#    'rbi',
#    'narendramodi'],
#   'miscellaneous'),
#  (['pmoindia',
#    'theofficialsbi',
#    'saw',
#    'news',
#    'retire',
#    'deceas',
#    'member',
#    'provid',
#    'fund',
#    'money',
#    'settl',
#    'within',
#    'day',
#    'howev',
#    ''],
#   'miscellaneous'),
#  (['rt',
#    'theofficialsbi',
#    'travelleramit',
#    'new',
#    'pin',
#    'may',
#    'also',
#    'gener',
#    'call',
#    'toll',
#    'free'],
#   'miscellaneous'),
#  (['atm',
#    'major',
#    'bank',
#    'still',
#    'servic',
#    'bhiwandi',
#    'citysbicardconnect',
#    'hdfcbankcar',
#    'icicibank',
#    'axisbanksupport'],
#   'displeasure'),
#  (['rt',
#    'smritimoy',
#    'pin',
#    'code',
#    'cash',
#    'anywher',
#    'atm',
#    'sure',
#    'kolkata',
#    'west',
#    'bengalrbi',
#    'theofficialsbi',
#    'hdfcbank',
#    'iciciban'],
#   'miscellaneous'),
#  (['rt',
#    'theofficialsbi',
#    'withdraw',
#    'deposit',
#    'make',
#    'sure',
#    'custom',
#    'seamless',
#    'bank',
#    'experi',
#    'bankonsbi',
#    'httpst'],
#   'compliment'),
#  (['theofficialsbi', 'appreci', 'tat', 'take', 'less', 'time'], 'displeasure'),
#  (['theofficialsbi',
#    'q',
#    'standalon',
#    'net',
#    'profit',
#    'fall',
#    'percent',
#    'higher',
#    'badloan',
#    'provis',
#    'httpstcofywziao',
#    'httpstcowauea'],
#   'miscellaneous'),
#  (['aninew',
#    'theofficialsbi',
#    'lot',
#    'effort',
#    'put',
#    'staff',
#    'bank',
#    'across',
#    'nation',
#    'arunjaitley',
#    'askanshul',
#    'uttara',
#    'drshraddha',
#    'dna'],
#   'compliment'),
#  (['theofficialsbi', 'still', 'respons'], 'displeasure'),
#  (['rt',
#    'vikasdatta',
#    'narendramodi',
#    'pmoindia',
#    'theofficialsbi',
#    'sbi',
#    'atm',
#    'work',
#    'gurgaon',
#    'new',
#    'coloni',
#    'branch',
#    'sector',
#    'need',
#    'withdraw'],
#   'displeasure'),
#  (['newsx',
#    'officeofrg',
#    'theofficialsbi',
#    'incindia',
#    'bjpindia',
#    'misinform',
#    'sbi',
#    'swiss',
#    'bank',
#    'india'],
#   'miscellaneous'),
#  (['theofficialsbi', 'pl', 'check', 'everi', 'video', 'find', 'treat', 'way'],
#   'miscellaneous'),
#  (['hope',
#    'bank',
#    'find',
#    'solut',
#    'adopt',
#    'token',
#    'system',
#    'regul',
#    'long',
#    'queuesrbi',
#    'theofficialsbi',
#    'mdpnb',
#    'httpstcozcjmjlobr'],
#   'miscellaneous'),
#  (['theofficialsbi',
#    'sirmi',
#    'sister',
#    'marriag',
#    'nov',
#    'unabl',
#    'withdraw',
#    'huge',
#    'amnt',
#    'bankso',
#    'sprt',
#    'reqfor',
#    'withdraw',
#    'huge',
#    'amnt'],
#   'miscellaneous'),
#  (['mclr',
#    'interest',
#    'benefit',
#    'pass',
#    'old',
#    'base',
#    'rate',
#    'system',
#    'home',
#    'loan',
#    'without',
#    'penalti',
#    'pleas',
#    'help',
#    'guidelin',
#    'rbi',
#    'theofficialsbi'],
#   'miscellaneous'),
#  (['theofficialsbi',
#    'stll',
#    'cash',
#    'student',
#    'away',
#    'home',
#    'dehradun',
#    'hv',
#    'cash',
#    'wallet',
#    'httpstcobnbidiewyd'],
#   'displeasure'),
#  (['rt',
#    'meindian',
#    'icicibank',
#    'icicibankcar',
#    'theofficialsbi',
#    'bankofbaroda',
#    'hdfcbank',
#    'start',
#    'max',
#    'atm',
#    'note',
#    'repleni'],
#   'miscellaneous'),
#  (['rt',
#    'theofficialsbi',
#    'rajatguleria',
#    'chequebook',
#    'request',
#    'may',
#    'also',
#    'place',
#    'atm',
#    'mobil',
#    'bank',
#    'sbi',
#    'mingl',
#    ''],
#   'miscellaneous'),
#  (['theofficialsbi',
#    'payment',
#    'today',
#    'transact',
#    'done',
#    'onlin',
#    'site',
#    'give',
#    'error',
#    'today',
#    'onlin',
#    'payment',
#    'accept'],
#   'displeasure'),
#  (['theofficialsbi',
#    'cannot',
#    'im',
#    'view',
#    'right',
#    'submit',
#    'applic',
#    'full',
#    'transact',
#    'right',
#    'nee',
#    'httpstcocdehlr'],
#   'displeasure'),
#  (['arunjaitley',
#    'sir',
#    'seem',
#    'pvt',
#    'bank',
#    'like',
#    'hdfcbank',
#    'icicibank',
#    'r',
#    'smart',
#    'implmt',
#    'chng',
#    'bt',
#    'govt',
#    'like',
#    'theofficialsbi',
#    'lag',
#    'adopt',
#    'chng'],
#   'miscellaneous'),
#  (['statement',
#    'frm',
#    'theofficialsbi',
#    'chairperson',
#    'unaccept',
#    'reason',
#    'chao',
#    'sarkari',
#    'remain',
#    'sarkari',
#    'httpstcozicpmpep'],
#   'displeasure'),
#  (['cnbctvlive',
#    'theofficialsbi',
#    'crore',
#    'deposit',
#    'sbi',
#    'th',
#    'th',
#    'good'],
#   'compliment'),
#  (['rt',
#    'mediacrook',
#    'gt',
#    'theofficialsbi',
#    'icicibank',
#    'hdfcbank',
#    'amp',
#    'other',
#    'pleas',
#    'wo',
#    'instruct',
#    'httpstcoleckyjcv'],
#   'miscellaneous'),
#  (['theofficialsbi', 'thank', 'kind', 'consider'], 'compliment'),
#  (['demonetis',
#    'chao',
#    'theofficialsbi',
#    'bank',
#    'chandni',
#    'chowk',
#    'abpnewstv',
#    'indiatvnew',
#    'oh',
#    'man',
#    'httpstcomaoredolm'],
#   'displeasure'),
#  (['hinduhangout',
#    'hdfcbank',
#    'theofficialsbi',
#    'sunandavashisht',
#    'cash',
#    'crunch',
#    'permit',
#    'denomin',
#    'made',
#    'withdrawi',
#    'didnt',
#    'deposit'],
#   'miscellaneous'),
#  (['theofficialsbi',
#    'congratul',
#    'result',
#    'effort',
#    'amp',
#    'hardwork',
#    'sbi',
#    'team',
#    'hope',
#    'win',
#    'diwalimo',
#    'contest',
#    'effort'],
#   'compliment'),
#  (['pl',
#    'give',
#    'prioriti',
#    'sr',
#    'ctzn',
#    'theofficialsbi',
#    'axisbank',
#    'icicibank',
#    'hdfcbank',
#    'httpstcobuotfeo'],
#   'miscellaneous'),
#  (['rt',
#    'theofficialsbi',
#    'rajatguleria',
#    'may',
#    'appli',
#    'onlin',
#    'new',
#    'chequ',
#    'book',
#    'visit',
#    'httpstcoeockxfw',
#    'video',
#    'tutori',
#    ''],
#   'miscellaneous'),
#  (['theofficialsbi', 'atm', 'noida', 'close', 'currenc'], 'displeasure'),
#  (['note',
#    'r',
#    'chang',
#    'time',
#    'chang',
#    'amp',
#    'promis',
#    'carecurr',
#    'theofficialsbi',
#    'gauravvkchawla',
#    'rohansippi',
#    'httpstcouthwwqpmm'],
#   'miscellaneous'),
#  (['rbi',
#    'theofficialsbi',
#    'alreadybut',
#    'branch',
#    'sbi',
#    'still',
#    'closedi',
#    'thought',
#    'itll',
#    'open',
#    'hour',
#    'befor',
#    'httpstcocxywji'],
#   'displeasure'),
#  (['theofficialsbi', 'day', 'took', 'credit', 'amountveri', 'bad', 'servic'],
#   'displeasure'),
#  (['theofficialsbi',
#    'hi',
#    'hire',
#    'hr',
#    'manag',
#    'amp',
#    'hr',
#    'execut',
#    'chandigarh',
#    'interest',
#    'candid',
#    'contact',
#    'us',
#    ''],
#   'miscellaneous'),
#  (['theofficialsbi',
#    'hav',
#    'net',
#    'bank',
#    'facil',
#    'regd',
#    'home',
#    'branch',
#    'citi',
#    'cant',
#    'u',
#    'find',
#    'txn',
#    'id',
#    'provid',
#    'detail'],
#   'miscellaneous'),
#  (['theofficialsbi',
#    'aurangabad',
#    'big',
#    'trade',
#    'citi',
#    'rather',
#    'defens',
#    'plz',
#    'action'],
#   'displeasure'),
#  (['rt', 'susmita', 'theofficialsbi', 'hello', 'ask', 'someth'],
#   'miscellaneous'),
#  (['given',
#    'bank',
#    'experi',
#    'provid',
#    'hdfcbank',
#    'theofficialsbi',
#    'bank',
#    'understood',
#    'pay',
#    'remain',
#    'unbank'],
#   'displeasure'),
#  (['',
#    'rbi',
#    'theofficialsbi',
#    'sbi',
#    'deal',
#    'third',
#    'parti',
#    'accept',
#    'currenc',
#    'form',
#    ''],
#   'displeasure'),
#  (['theofficialsbi',
#    'need',
#    'know',
#    'wt',
#    'action',
#    'u',
#    'guy',
#    'gonna',
#    'take',
#    'mr',
#    'anil'],
#   'miscellaneous'),
#  (['mediacrook',
#    'icicibank',
#    'theofficialsbi',
#    'arunjaitley',
#    'u',
#    'state',
#    'banker',
#    'stfc',
#    'even',
#    'women',
#    'employe',
#    'httpstcotsifzrqq'],
#   'displeasure'),
#  (['seem',
#    'issu',
#    'theofficialsbi',
#    'websit',
#    'today',
#    'ie',
#    'httpstcofvmgoxzp',
#    'take',
#    'lot',
#    'time',
#    'load'],
#   'miscellaneous'),
#  (['theofficialsbi', 'sbicoin', 'contact', 'number', 'ac', ''],
#   'miscellaneous'),
#  (['theofficialsbi',
#    'written',
#    'letter',
#    'given',
#    'applic',
#    'branch',
#    'email',
#    'complaint',
#    'put',
#    'twitter',
#    'seem',
#    'sbi',
#    'sleep'],
#   'displeasure'),
#  (['theofficialsbi',
#    'kindli',
#    'teach',
#    'work',
#    'cultur',
#    'staff',
#    'imag',
#    'worst',
#    'bank',
#    'cultur',
#    'full',
#    'attitudeatm',
#    'withoutmoney'],
#   'displeasure'),
#  (['theofficialsbi', 'ye', 'worst', 'bank', 'date'], 'displeasure'),
#  (['long',
#    'queue',
#    'bank',
#    'ahmedabad',
#    'amp',
#    'indian',
#    'citi',
#    'cashcleanup',
#    'hdfcbank',
#    'icicibank',
#    'axisbank',
#    'kotakbankltd',
#    'theofficialsbi'],
#   'miscellaneous'),
#  ...]

# %%
training_set = nltk.classify.util.apply_features(extract_features, tweets)
training_set
# Out:
# [({'contains()': False, 'contains(foreign)': False, 'contains(branchsonkh)': False, 'contains(itali)': False, 'contains(privat)': False, 'contains(momentthink)': False, 'contains(worldkindnessday)': False, 'contains(access)': False, 'contains(sah)': False, 'contains(dna)': False, 'contains(bk)': False, 'contains(aw)': False, 'contains(nagerbazar)': False, 'contains(timesnow)': False, 'contains(sr)': False, 'contains(tip)': False, 'contains(truecal)': False, 'contains(slash)': False, 'contains(rebuild)': False, 'contains(hometown)': False, 'contains(httpstcopgeqbxxnv)': False, 'contains(kotakmahindrabank)': False, 'contains(crr)': False, 'contains(hdfcbanknew)': False, 'contains(shreyisher)': False, 'contains(rli)': False, 'contains(kalkihprashar)': False, 'contains(mismatch)': False, 'contains(httpstcobuotfeo)': False, 'contains(gdp)': False, 'contains(vvv)': False, 'contains(njoy)': False, 'contains(vicin)': False, 'contains(latter)': False, 'contains(vest)': False, 'contains(timesofindia)': False, 'contains(andheri)': False, 'contains(exch)': False, 'contains(httpstcolvn)': False, 'contains(clariti)': False, 'contains(modihel)': False, 'contains(bing)': False, 'contains(httpstcobfmaczci)': False, 'contains(punish)': False, 'contains(mgf)': False, 'contains(ranchi)': False, 'contains(mom)': False, 'contains(httpstconskrpkgku)': False, 'contains(gargpankaj)': False, 'contains(aurgho)': False, 'contains(churchgat)': False, 'contains(tw)': False, 'contains(coustmer)': False, 'contains(sirtoday)': False, 'contains(hasnt)': False, 'contains(medicin)': False, 'contains(strengthen)': False, 'contains(major)': False, 'contains(costum)': False, 'contains(enforc)': False, 'contains(anuyeaah)': False, 'contains(laheriasari)': False, 'contains(bono)': False, 'contains(anurag)': False, 'contains(kottara)': False, 'contains(indu)': False, 'contains(httpstcoqfacgjt)': False, 'contains(ipad)': False, 'contains(hall)': False, 'contains(mannerless)': False, 'contains(wrongli)': False, 'contains(hero)': False, 'contains(dint)': False, 'contains(maestro)': False, 'contains(gmail)': False, 'contains(spl)': False, 'contains(btw)': False, 'contains(tobe)': False, 'contains(control)': False, 'contains(harhar)': False, 'contains(oo)': False, 'contains(centralbankin)': False, 'contains(cashwhi)': False, 'contains(hosur)': False, 'contains(ndtvravishkumar)': False, 'contains(detail)': False, 'contains(equip)': False, 'contains(fix)': False, 'contains(httpstcoimbpdsvjo)': False, 'contains(prm)': False, 'contains(akbhosal)': False, 'contains(small)': False, 'contains(featur)': False, 'contains(need)': False, 'contains(tarun)': False, 'contains(spite)': False, 'contains(draft)': False, 'contains(wash)': False, 'contains(exchangeopen)': False, 'contains(neg)': False, 'contains(mission)': False, 'contains(directlywil)': False, 'contains(rahulgandhi)': False, 'contains(cannot)': False, 'contains(ghaziabad)': False, 'contains(httpstcozyoyixmw)': False, 'contains(wish)': False, 'contains(deleg)': False, 'contains(damag)': False, 'contains(tajinderbagga)': False, 'contains(nashdecosta)': False, 'contains(regist)': False, 'contains(bunknallagandla)': False, 'contains(state)': False, 'contains(pmoindia)': False, 'contains(httpstcoryilhcyv)': False, 'contains(doubl)': False, 'contains(got)': False, 'contains(iamchetansinha)': False, 'contains(suggest)': False, 'contains(ravikrtomar)': False, 'contains(printout)': False, 'contains(instal)': False, 'contains(httpstcohxfuucvq)': False, 'contains(center)': False, 'contains(arunjaitleyl)': False, 'contains(kexchang)': False, 'contains(prize)': False, 'contains(miser)': False, 'contains(thehindu)': False, 'contains(ca)': False, 'contains(came)': False, 'contains(mother)': False, 'contains(mera)': False, 'contains(vacat)': False, 'contains(no)': False, 'contains(clo)': False, 'contains(singhraviranja)': False, 'contains(httpstcogjprxqpp)': False, 'contains(kodak)': False, 'contains(ie)': False, 'contains(khangressi)': Fa ...

# %%
#Max Entropy Classifier
MaxEntClassifier = nltk.classify.maxent.MaxentClassifier.train(training_set, 'GIS', trace=3,encoding=None, labels=None, gaussian_prior_sigma=0, max_iter = 10)
# Out:
#   ==> Training (10 iterations)
#
#       Iteration    Log Likelihood    Accuracy
#       ---------------------------------------
#              1          -1.09861        0.400
#              2          -0.92126        0.470
#              3          -0.92069        0.470
#              4          -0.92019        0.470
#              5          -0.91968        0.470
#              6          -0.91917        0.470
#              7          -0.91867        0.470
#              8          -0.91816        0.470
#              9          -0.91766        0.470
#          Final          -0.91715        0.470

# %%
test_data = pd.concat([hdfc_test,axis_test,sbi_test,kotak_test,icici_test])
test_data
# Out:
#                                                   tweet      sentiment  \
# 2     @HDFCBank_Cares Both the ATM machines here in ...    displeasure
# 9     @HDFC_Bank @HDFCBank_Cares received an email s...     compliment
# 11    @HDFCBank_Cares the ATM at Sector-8, Charkop, ...    displeasure
# 16    @ICICIBank_Care @HDFCBank_Cares @AxisBank #nom...    displeasure
# 20    RT @Tarun260: Thanks to @HDFC_Bank @HDFCBank_C...     compliment
# ...                                                 ...            ...
# 2616   @ICICIBank_Care thanks. ATMs were working today.     compliment
# 2618  @ICICIBank_Care your Patna zonal office car lo...    displeasure
# 2620  Unfortunately 70% in queue do not need cash @H...  miscellaneous
# 2623  @ICICIBank_Care #chandakochar @ICICIBank dahis...     compliment
# 2626  @ICICIBank_Care In KPHB Area, all Atm's are cl...    displeasure
#
#                      bank                                                  @  \
# 2                  [hdfc]                         [@HDFCBank_Cares, @sanatm]
# 9      [hdfc, hdfc, hdfc]                      [@HDFC_Bank, @HDFCBank_Cares]
# 11                 [hdfc]                                  [@HDFCBank_Cares]
# 16    [icici, hdfc, axis]  [@ICICIBank_Care, @HDFCBank_Cares, @AxisBank, ...
# 20           [hdfc, hdfc]           [@Tarun260, @HDFC_Bank, @HDFCBank_Cares]
# ...                   ...                                                ...
# 2616              [icici]                                  [@ICICIBank_Care]
# 2618              [icici]                                  [@ICICIBank_Care]
# 2620        [hdfc, icici]  [@HDFC_Bank, @ICICIBank_Care, @idea_cares, @Vo...
# 2623       [icici, icici]           [@ICICIBank_Care, @ICICIBank, @PMOIndia]
# 2626              [icici]                                  [@ICICIBank_Care]
#
#                                               Tweet_str  \
# 2     hdfcbankcares both the atm machines here in ti...
# 9     hdfcbank hdfcbankcares received an email sayin...
# 11    hdfcbankcares the atm at sector charkop kandiv...
# 16    icicibankcare hdfcbankcares axisbank nomoney i...
# 20    rt tarun thanks to hdfcbank hdfcbankcares mgmt...
# ...                                                 ...
# 2616       icicibankcare thanks atms were working today
# 2618  icicibankcare your patna zonal office car loan...
# 2620  unfortunately  in queue do not need cash hdfcb...
# 2623  icicibankcare chandakochar icicibank dahisar w...
# 2626  icicibankcare in kphb area all atms are closed...
#
#                                           Tweet_cleaned  \
# 2     [hdfcbankcares, atm, machines, times, india, n...
# 9     [hdfcbank, hdfcbankcares, received, email, say...
# 11    [hdfcbankcares, atm, sector, charkop, kandival...
# 16    [icicibankcare, hdfcbankcares, axisbank, nomon...
# 20    [rt, tarun, thanks, hdfcbank, hdfcbankcares, m...
# ...                                                 ...
# 2616      [icicibankcare, thanks, atms, working, today]
# 2618  [icicibankcare, patna, zonal, office, car, loa...
# 2620  [unfortunately, queue, need, cash, hdfcbank, i...
# 2623  [icicibankcare, chandakochar, icicibank, dahis...
# 2626  [icicibankcare, kphb, area, atms, closed, plea...
#
#                                           Tweet_stemmed  \
# 2     [hdfcbankcar, atm, machin, time, india, noida,...
# 9     [hdfcbank, hdfcbankcar, receiv, email, say, at...
# 11    [hdfcbankcar, atm, sector, charkop, kandivaliw...
# 16    [icicibankcar, hdfcbankcar, axisbank, nomoney,...
# 20    [rt, tarun, thank, hdfcbank, hdfcbankcar, mgmt...
# ...                                                 ...
# 2616            [icicibankcar, thank, atm, work, today]
# 2618  [icicibankcar, patna, zonal, offic, car, loan,...
# 2620  [unfortun, queue, need, cash, hdfcbank, icicib...
# 2623  [icicibankcar, chandakochar, icicibank, dahisa...
# 2626  [icicibankcar, kphb, area, atm, close, pleas, ...
#
#                                Tweet_lemmatized_stemmed
# 2     [hdfcbankcar, atm, machin, time, india, noida,...
# 9     [hdfcbank, hdfcbankcar, receiv, email, say, at...
# 11    [hdfcbankcar, atm, sector, charkop, kandivaliw...
# 16    [icicibankcar, hdfcbankcar, axisbank, nomoney,...
# 20    [rt, tarun, thank, hdfcbank, hdfcbankcar, mgmt...
# ...                                                 ...
# 2616            [icicibankcar, thank, atm, work, today]
# 2618  [icicibankcar, patna, zonal, offic, car, loan,...
# 2620  [unfortun, queue, need, cash, hdfcbank, icicib...
# 2623  [icicibankcar, chandakochar, icicibank, dahisa...
# 2626  [icicibankcar, kphb, area, atm, close, plea, f...
#
# [2500 rows x 8 columns]

# %%
classifier_f = open("max.pickle", "rb") #loading the saved classifier
classifier = pickle.load(classifier_f)
classifier_f.close()

# %%
''''def dict
test_data['test_set_formatted'] = (test_data['Tweet_stemmed']).apply(lambda x: list_to_dict(x))
test_data_formatted=test_data['test_set_formatted']
res=[]
test_data_formatted=test_data_formatted.to_frame()
test_set_formatted=test_data_formatted.values.tolist()

''for index,row in test_data_formatted.iterrows():
    maxent_pred=classifier.classify(row['test_set_formatted'])
    res.append(maxent_pred)

""""for tweet in test_set_formatted:
        text = tweet[0]
        label = classifier.classify(extract_features(text))
        results.append( label)"""
        
classifier.classify(extract_features(test_set_formatted[0]))'''
        
test_data_final=test_data[['Tweet_stemmed','sentiment']]
test_data_final=test_data_final.values.tolist()

# %%
def list_to_dict(words_list):
    return dict([(word, True) for word in words_list])
test_set_formatted = [(list_to_dict(element[0]), element[1]) for element in test_data_final]
#test_set_formatted
tweet_id=0
results=[]
for review in test_set_formatted:
        text = review[0]
        label = classifier.classify(text)
        results.append(label)
        #tweet_id += int(1)
#test_set_formatted = [(list_to_dict(element[0]), element[1]) for element in test_data]
results

result=pd.DataFrame(results)
from sklearn.preprocessing import LabelEncoder 
from sklearn.preprocessing import OneHotEncoder
le = LabelEncoder() 
result[0]= le.fit_transform(result[0])
result
# Out:
#       0
# 0     1
# 1     2
# 2     1
# 3     1
# 4     1
# ...  ..
# 2495  1
# 2496  1
# 2497  2
# 2498  0
# 2499  1
#
# [2500 rows x 1 columns]

# %%
hdfc_sent_score_df=result[0:500]
hdfc_sent_score=hdfc_sent_score_df.sum()
print("HDFC Performance index score is :",hdfc_sent_score)
# Out:
# HDFC Performance index score is : 0    589
# dtype: int64

# %%
axis_sent_score_df=result.iloc[500:1000]
axis_sent_score=axis_sent_score_df.sum()
print("AXIS Performance index score is :",axis_sent_score)
# Out:
# AXIS Performance index score is : 0    693
# dtype: int64

# %%
sbi_sent_score_df=result.iloc[1000:1500]
sbi_sent_score=sbi_sent_score_df.sum()
print("SBI Performance index score is :",sbi_sent_score)
# Out:
# SBI Performance index score is : 0    631
# dtype: int64

# %%
kotak_sent_score_df=result.iloc[1500:2000]
kotak_sent_score=kotak_sent_score_df.sum()
print("HDFC Performance index score is :",kotak_sent_score)
# Out:
# HDFC Performance index score is : 0    546
# dtype: int64

# %%
icici_sent_score_df=result.iloc[2000:2500]
icici_sent_score=icici_sent_score_df.sum()
print("ICICI Performance index score is :",icici_sent_score)
# Out:
# ICICI Performance index score is : 0    571
# dtype: int64

# %%
classifier.show_most_informative_features()
# Out:
#   -0.001 ask==True and label is 'compliment'
#   -0.001 close==True and label is 'compliment'
#   -0.001 home==True and label is 'compliment'
#   -0.001 min==True and label is 'miscellaneous'
#   -0.001 receiv==True and label is 'compliment'
#   -0.001 call==True and label is 'compliment'
#   -0.001 back==True and label is 'compliment'
#   -0.001 say==True and label is 'compliment'
#   -0.001 still==True and label is 'compliment'
#   -0.001 onlin==True and label is 'compliment'
